# %% [markdown]
# # HomeWork

# %% [markdown]
# 과제는 다음과 같습니다.
#
# 1. 이미지 최종 embedding size 맞도록 계산 및 코드 수정하기
# 2. 좋은 성능이 나오도록 자유롭게 Resnet Fine tunning 실험해보기

# %% [markdown]
# ##1. Image Size 수정

# %% [markdown]
# 앞선 수업코드에서는 ResNet 본래의 input size인 224를 맞추기 위해 Resize와 Crop을 사용하였습니다.

# %% [markdown]
# 그러나 resize와 crop을 거친 이미지는 원본의 특징을 정확하게 반영하지 못할 가능성이 있습니다.

# %% [markdown]
# 따라서 아래의 식을 이용해 ResNet18이 우리의 input image size를 받고도 작동하도록 모델을 바꿔주세요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 즉, 224*224가 아닌,
#
#  우리의 이미지 크기 64*64가 ResNet으로 들어가
#
#  최종 layer에서 7*7의 차원을 갖도록 output size를 조절해가며 stride, padding 및 kernel size등을 조정해 보시면 됩니다.

# %% [markdown]
# **이 부분에 어떻게 stride, padding등을 바꿔서 최종 7*7을 만들었는지 서술 해 주세요**

# %% [markdown]
# 흠 너무 길어서

# %% [markdown]
# ## 2. 성능 높이기

# %% [markdown]
# Resnet의 layer4 부분까지 fine-tunning 해 주세요

# %% [markdown]
# 여러 hyperparameter들은 자유롭게 변경해가며 본인만의 ResNet을 만들어 보세요

# %% [markdown]
# ## 3. 코드 구현 부분

# %%
## 필요한 모듈 import

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision 
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation
# Out:
# /content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation

# %%
# !unzip -qq '/content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation/face_dataset-20220825T022545Z-001.zip'

# %%
## 데이터셋 로드 
from torchvision.datasets import ImageFolder
import os

data_dir = '/content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation/face_dataset/'
path = {x: os.path.join(data_dir,'facescrub_'+x) for x in ['train', 'test'] } # Train, Test 경로 지정
## local에 이미지를 저장했으면 저장한 경로만 찾아서 붙여넣어 주기
print(path)
train_data = ImageFolder(path['train'], transforms.Compose([transforms.ToTensor()]))
# Out:
# {'train': '/content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation/face_dataset/facescrub_train', 'test': '/content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation/face_dataset/facescrub_test'}

# %%
# Input Normalize 계산하는데 오래걸려서 미리 구해둠
avgR = 0.6565039 
avgG = 0.4843807
avgB = 0.4084822
stdR = 0.20245129
stdG = 0.17317267
stdB = 0.1622832

# %%
## 데이터 전처리를 위한 과정

data_transforms = {
    'facescrub_train': transforms.Compose([
        # 이미지 증강
        transforms.RandomHorizontalFlip(), # 수평으로 뒤집기
        transforms.RandomVerticalFlip(), # 수직으로 뒤집기
        # 이미지를 텐서로 변경
        transforms.ToTensor(),
        # Input 값 Normalize 해주기 ( 각 채널의 평균 값과 표준편차 값으로 정규화 해줌 )
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
    # 위와 동일한 과정 Test set에 대해 진행하기
    'facescrub_test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
}

# %%
## 앞서 정의한 data_transforms를 이용해 실제 train과 test 이미지셋을 만들어 준다
image_datasets = {x: datasets.ImageFolder(os.path.join('/content/drive/MyDrive/DSL/2022-2/220825 CNN Implementation/face_dataset/', x),
                                          data_transforms[x]) for x in ['facescrub_train', 'facescrub_test']}

# %%
## Train과 Testset의 크기 확인
data_sizes = {x: len(image_datasets[x]) for x in ['facescrub_train', 'facescrub_test']}
print(data_sizes['facescrub_train'])
print(data_sizes['facescrub_test'])
# Out:
# 4000
# 1000

# %%
## Dataloader를 설정해 준다
dataloaders = {x: torch.utils.data.DataLoader(
                       image_datasets[x], batch_size=16, # 이 부분에서 batch_size를 설정할 수 있음 
                       shuffle=True, # train data를 batch로 묶을 때 섞을 것인지 결정
                       num_workers=2) # Dataloader가 data를 읽어들일 때 사용할 스레드의 개수 (GPU 사용량을 결정)
                                            for x in ['facescrub_train', 'facescrub_test']}
## class 이름 설정 
class_names = image_datasets['facescrub_train'].classes 

## 어떤 device를 이용할 것인지 결정한다 (gpu 불가능하면 cpu)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
## 세 전이학습에 사용할 ResNet 각각 load
## Resnet을 불러와 주세요
Resnet = torchvision.models.resnet18(pretrained=True) # 해당 부분을 False로 바꾸면 구조만 가져온다
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
## Resnet의 output layer를 우리의 이미지에 맞도록 크기조정 해 주세요
## 단, kernel size를 바꿀 경우 가중치의 개수가 달라지므로 Fine-Tunning 시 해당 layer도 넣어서 해주셔야 합니다!
## stride를 조작해 보시는 것을 추천드립니다

# %%
# ResNet18의 layer이름을 확인 ( 이후 layer 고칠 때 찾기 쉬우라고 함 )
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) # 각 layer의 이름 확인
  print('Layer Info. : ',child) # 각 layer의 정보 확인
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=1000, bias=True)

# %%
Resnet.layer3[0].conv1.stride = (1, 1)

Resnet.layer3[0].downsample[0].stride = (1, 1)
Resnet.layer4[0].conv1.stride = (1,1) 
Resnet.layer4[0].downsample[0].stride= (1,1)

# %% [markdown]
# stride 를 조정하여 2 이미지차원의 크기를(8,8)으로 고정하도록 하습니다!

# %%
Resnet
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
Resnet.layer2= nn.Sequential( nn.Conv2d(64,64,kernel_size=(4,4), stride=(1, 1), padding=(1, 1)),Resnet.layer2  )

# %% [markdown]
# 이미지 차원을 8,8로 맞춘 후-> layer2에 conv2d 필터를 추가하여 이미지차원이 (7,7)이 되도록 레이어를 추가하였습니다. 따라서 인풋으로  (3,64,64)의 차원의 텐서가 들어왔을때, 단계별 Output shape를  Torchsummary Library를 통해 확인해보면, 다음과 같습니다 .

# %%
from torchsummary import summary

model= Resnet
model= model.to(device)
summary(model, input_size= (3,64 ,64) ) # Recall) Tensor는 C, H, W 순서로 이미지 가짐
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 64, 32, 32]           9,408
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#               ReLU-3           [-1, 64, 32, 32]               0
#          MaxPool2d-4           [-1, 64, 16, 16]               0
#             Conv2d-5           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-6           [-1, 64, 16, 16]             128
#               ReLU-7           [-1, 64, 16, 16]               0
#             Conv2d-8           [-1, 64, 16, 16]          36,864
#        BatchNorm2d-9           [-1, 64, 16, 16]             128
#              ReLU-10           [-1, 64, 16, 16]               0
#        BasicBlock-11           [-1, 64, 16, 16]               0
#            Conv2d-12           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-13           [-1, 64, 16, 16]             128
#              ReLU-14           [-1, 64, 16, 16]               0
#            Conv2d-15           [-1, 64, 16, 16]          36,864
#       BatchNorm2d-16           [-1, 64, 16, 16]             128
#              ReLU-17           [-1, 64, 16, 16]               0
#        BasicBlock-18           [-1, 64, 16, 16]               0
#            Conv2d-19           [-1, 64, 15, 15]          65,600
#            Conv2d-20            [-1, 128, 8, 8]          73,728
#       BatchNorm2d-21            [-1, 128, 8, 8]             256
#              ReLU-22            [-1, 128, 8, 8]               0
#            Conv2d-23            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-24            [-1, 128, 8, 8]             256
#            Conv2d-25            [-1, 128, 8, 8]           8,192
#       BatchNorm2d-26            [-1, 128, 8, 8]             256
#              ReLU-27            [-1, 128, 8, 8]               0
#        BasicBlock-28            [-1, 128, 8, 8]               0
#            Conv2d-29            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-30            [-1, 128, 8, 8]             256
#              ReLU-31            [-1, 128, 8, 8]               0
#            Conv2d-32            [-1, 128, 8, 8]         147,456
#       BatchNorm2d-33            [-1, 128, 8, 8]             256
#              ReLU-34            [-1, 128, 8, 8]               0
#        BasicBlock-35            [-1, 128, 8, 8]               0
#            Conv2d-36            [-1, 256, 8, 8]         294,912
#       BatchNorm2d-37            [-1, 256, 8, 8]             512
#              ReLU-38            [-1, 256, 8, 8]               0
#            Conv2d-39            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-40            [-1, 256, 8, 8]             512
#            Conv2d-41            [-1, 256, 8, 8]          32,768
#       BatchNorm2d-42            [-1, 256, 8, 8]             512
#              ReLU-43            [-1, 256, 8, 8]               0
#        BasicBlock-44            [-1, 256, 8, 8]               0
#            Conv2d-45            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-46            [-1, 256, 8, 8]             512
#              ReLU-47            [-1, 256, 8, 8]               0
#            Conv2d-48            [-1, 256, 8, 8]         589,824
#       BatchNorm2d-49            [-1, 256, 8, 8]             512
#              ReLU-50            [-1, 256, 8, 8]               0
#        BasicBlock-51            [-1, 256, 8, 8]               0
#            Conv2d-52            [-1, 512, 8, 8]       1,179,648
#       BatchNorm2d-53            [-1, 512, 8, 8]           1,024
#              ReLU-54            [-1, 512, 8, 8]               0
#            Conv2d-55            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-56            [-1, 512, 8, 8]           1,024
#            Conv2d-57            [-1, 512, 8, 8]         131,072
#       BatchNorm2d-58            [-1, 512, 8, 8]           1,024
#              ReLU-59            [-1, 512, 8, 8]               0
#        BasicBlock-60            [-1, 512, 8, 8]               0
#            Conv2d-61            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-62            [-1, 512, 8, 8]           1,024
#              ReLU-63            [-1, 512, 8, 8]               0
#            Conv2d-64            [-1, 512, 8, 8]       2,359,296
#       BatchNorm2d-65            [-1, 512, 8, 8]           1,024
#              ReLU-66            [-1, 512, 8, 8]               0
#        BasicBlock-67            [-1, 512, 8, 8]               0
# AdaptiveAvgPool2d-68            [-1, 512, 1, 1]               0
#            Linear-69                 [-1, 1000]         513,000
# ================================================================
# Total params: 11,755,112
# Trainable params: 11,755,112
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.05
# Forward/backward pass size (MB): 10.50
# Params size (MB): 44.84
# Estimated Total Size (MB): 55.39
# ----------------------------------------------------------------

# %%
# 변경된 정보를 확인해 보세요
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) 
  print('Layer Info. : ',child) 
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#   (1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=1000, bias=True)

# %%
seq_train_loss = []
seq_test_loss = []
seq_train_acc = []
seq_test_acc = []

# %%
## Train 함수 정의

def train(model,epoch,optimizer,criterion,scheduler=None,save_every=None):
    ## 각 단계의 loss 및 accuracy 저장할 list 생성

    print(f'\n[ Train epoch: {epoch+1} ]')

    model.train() # Train 단계임을 선업

    running_loss = 0.0
    batch_losses = []
    total = 0
    correct = 0

    for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_train']): # Train data 가져오기
        inputs, targets = inputs.to(device), targets.to(device) # dataloader의 input image와 label도 device에 넣어준다
      
        optimizer.zero_grad() # gradient 초기화
        outputs = model(inputs) # Prediction value 계산 (Output 계산)
        loss = criterion(outputs, targets) # outputs와 원래 label인 targets 사이 loss 계산
        loss.backward() # 계산한 loss 기반으로 gradient 값 계산
        optimizer.step() # weight parameter update
        if scheduler != None:
            if batch_idx in [80, 160, 200]:
                scheduler.step() # Scheduler update

        total += targets.size(0) # batch 데이터 개수 더하기
        running_loss += loss.item()
        batch_losses.append(loss.item())
        
        _, predicted = outputs.max(1) # 확률값 가장 높게 나타난 클래스
        correct += (predicted == targets).sum().item() # 현재 batch 내에서 알맞게 분류한 이미지 개수 더하기
        
        if batch_idx % 50 == 49:
            ## 학습 중간 성능 확인
            print(f'\nCurrent batch: {str(batch_idx+1)}')
            print(f'Average train loss of recent 50 batches: {running_loss / 50}') 
            running_loss = 0.0

        if save_every != None:
         if (batch_idx % save_every == 0): # 얼마만큼의 iteration마다 저장할 것인지를 설정
              directory = os.path.join(save_path, '/Resnet') # 경로 설정
              if not os.path.exists(directory): # 경로가 없다면 새로 만듦
                  os.makedirs(directory)
              torch.save({ 
                  # 학습 중간에 저장하려 하는 모든 것들을 dict로 서술
                  'epoch': epoch, 
                  'iteration': batch_idx,
                  'model': model.state_dict(),
                  'opt': optimizer.state_dict(),
                  'loss': loss
                  #,'sch': scheduler.state_dict()
                  }, os.path.join(directory, '{}ep_{}iter_{}.tar'.format(epoch,batch_idx,'checkpoint')))

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_train_loss.append(avg_loss)
    seq_train_acc.append(100*correct/total)
    print('\nTotal train accuarcy:', 100. * correct / total) # 전체 데이터 개수에서 맞게 예측한 비율
    print('Total train loss:', avg_loss)

# %%
def test(model,epoch,criterion):
    print(f'\n[ Test epoch: {epoch+1} ]')

    model.eval() # Test time임을 선언

    loss = 0
    batch_losses = []
    correct = 0
    total = 0

    with torch.no_grad(): # gradient update 안함 - eval과 torch.no_grad는 하나의 세트
        for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_test']):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)
            batch_losses.append(loss.item())

            total += targets.size(0)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_test_loss.append(avg_loss)
    seq_test_acc.append(100 * correct / total)
    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', avg_loss)

# %%
my_Model = Resnet

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
my_Model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     (1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
## fine-tunning 하고싶은 부분을 제외하고 update를 얼려 주세요
for name,child in my_Model.named_children():
  for param in child.parameters():
    if name not in ['fc']:   # 'fc' 이름의 layer만 제외
      param.requires_grad = False

# %%
## 지정한 device에 학습시킬 모델 얹어주기
Resnet.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): Conv2d(64, 64, kernel_size=(4, 4), stride=(1, 1), padding=(1, 1))
#     (1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
## Optimizer, Scheduler, Cost Function 등을 직접 설정해서 사용해 보세요
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(Resnet.parameters(), 
                         lr = 0.001,
                         momentum=0.9,
                         weight_decay=1e-4)
lmbda = lambda epoch: 0.98739
scheduler = optim.lr_scheduler.MultiplicativeLR(optimizer, lr_lambda=lmbda)

# %%
num_epochs =  40

# %%
import os

# %%
save_path = os.path.join('/content/drive')

# %%
## 학습을 진행해 주세요 (GPU로 돌려야 합니다 CPU는 너무 느려요)
for epoch in range(0,num_epochs):
  train(Resnet ,epoch,optimizer,criterion,save_every=10)
  test(Resnet ,epoch,criterion)
# Out:
# [ Train epoch: 1 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 6.5855614376068115
#
# Current batch: 100
# Average train loss of recent 50 batches: 5.666920928955078
#
# Current batch: 150
# Average train loss of recent 50 batches: 5.245739736557007
#
# Current batch: 200
# Average train loss of recent 50 batches: 5.030231847763061
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.914437017440796
#
# Total train accuarcy: 0.75
# Total train loss: 5.488578193664551
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 1.6
# Test average loss: 4.825207619439988
#
# [ Train epoch: 2 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.8322758293151855
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.7796819877624515
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.784506063461304
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.740826902389526
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.7208700847625735
#
# Total train accuarcy: 0.975
# Total train loss: 4.771632173538208
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 1.7
# Test average loss: 4.702481307680645
#
# [ Train epoch: 3 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.701450128555297
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.685821313858032
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.68951337814331
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.676726512908935
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.668687534332276
#
# Total train accuarcy: 1.5
# Total train loss: 4.68443977355957
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 1.7
# Test average loss: 4.663693836757115
#
# [ Train epoch: 4 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.6477225875854495
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.657871294021606
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.656880979537964
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.632743148803711
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.656157627105713
#
# Total train accuarcy: 1.275
# Total train loss: 4.650275127410889
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 1.4
# Test average loss: 4.61918970895192
#
# [ Train epoch: 5 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.6219221878051755
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.629959964752198
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.609060277938843
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.605171489715576
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.63335620880127
#
# Total train accuarcy: 1.65
# Total train loss: 4.619894025802612
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 2.4
# Test average loss: 4.611537600320483
#
# [ Train epoch: 6 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.590627288818359
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.60610447883606
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.610659770965576
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.5995402431488035
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.603808174133301
#
# Total train accuarcy: 1.725
# Total train loss: 4.60214799118042
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 1.6
# Test average loss: 4.601718637678358
#
# [ Train epoch: 7 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.582567396163941
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.608144598007202
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.574429216384888
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.591150102615356
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.579489450454712
#
# Total train accuarcy: 1.8
# Total train loss: 4.587156152725219
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 2.6
# Test average loss: 4.604880370790997
#
# [ Train epoch: 8 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.576523485183716
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.586102638244629
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.554986190795899
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.58652624130249
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.566546030044556
#
# Total train accuarcy: 2.3
# Total train loss: 4.574136917114258
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 2.2
# Test average loss: 4.597617898668561
#
# [ Train epoch: 9 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.5690409946441655
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.577184286117554
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.5386271572113035
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.552034139633179
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.576780366897583
#
# Total train accuarcy: 2.35
# Total train loss: 4.562733388900757
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 2.7
# Test average loss: 4.56948713272337
#
# [ Train epoch: 10 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.5370755290985105
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.5605465602874755
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.556390743255616
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.565609397888184
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.559297008514404
#
# Total train accuarcy: 2.275
# Total train loss: 4.555783847808838
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 2.0
# Test average loss: 4.584433767530653
#
# [ Train epoch: 11 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.536915340423584
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.539977416992188
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.542683200836182
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.562307720184326
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.534721946716308
#
# Total train accuarcy: 2.775
# Total train loss: 4.543321125030517
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 2.3
# Test average loss: 4.558612959725516
#
# [ Train epoch: 12 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.514259653091431
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.539926061630249
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.564542798995972
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.53487982749939
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.546507158279419
#
# Total train accuarcy: 2.75
# Total train loss: 4.540023099899292
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 2.6
# Test average loss: 4.554715686374241
#
# [ Train epoch: 13 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.518712177276611
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.54575834274292
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.508079204559326
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.54217493057251
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.523068914413452
#
# Total train accuarcy: 2.625
# Total train loss: 4.527558713912964
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 2.5
# Test average loss: 4.540841897328694
#
# [ Train epoch: 14 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.504008502960205
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.518665342330933
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.52525408744812
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.52286075592041
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.535623664855957
#
# Total train accuarcy: 2.775
# Total train loss: 4.521282470703125
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 3.4
# Test average loss: 4.539271982889327
#
# [ Train epoch: 15 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.501242961883545
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.521608619689942
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.512802495956421
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.510297079086303
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.527234401702881
#
# Total train accuarcy: 2.475
# Total train loss: 4.514637111663818
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 3.5
# Test average loss: 4.516353024376763
#
# [ Train epoch: 16 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.511493158340454
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.511386575698853
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4974704933166505
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.526154384613037
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.516438188552857
#
# Total train accuarcy: 2.625
# Total train loss: 4.51258856010437
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 2.6
# Test average loss: 4.526260277581593
#
# [ Train epoch: 17 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.480039777755738
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.500367021560669
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4860817813873295
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.532249841690064
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.478135824203491
#
# Total train accuarcy: 3.125
# Total train loss: 4.495374849319458
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 2.5
# Test average loss: 4.514763097914439
#
# [ Train epoch: 18 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.4714014434814455
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.504495534896851
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.462374324798584
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.496048278808594
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.488556060791016
#
# Total train accuarcy: 2.3
# Total train loss: 4.4845751285552975
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 2.6
# Test average loss: 4.520376780676464
#
# [ Train epoch: 19 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.4934131622314455
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.478197689056397
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4862635040283205
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.469263973236084
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.486768388748169
#
# Total train accuarcy: 3.575
# Total train loss: 4.482781343460083
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 3.7
# Test average loss: 4.490440489753844
#
# [ Train epoch: 20 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.479256553649902
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.483303203582763
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.483781509399414
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.456262674331665
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.486183958053589
#
# Total train accuarcy: 3.175
# Total train loss: 4.477757579803467
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 3.1
# Test average loss: 4.499646368480864
#
# [ Train epoch: 21 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.476954355239868
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.489715709686279
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.485283975601196
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.471459903717041
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.465323419570923
#
# Total train accuarcy: 3.0
# Total train loss: 4.4777474727630615
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 3.4
# Test average loss: 4.485143979390462
#
# [ Train epoch: 22 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.477513179779053
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.483217573165893
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.465275402069092
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.49352596282959
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.461796894073486
#
# Total train accuarcy: 3.025
# Total train loss: 4.4762658023834225
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 2.9
# Test average loss: 4.491582083323645
#
# [ Train epoch: 23 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.483173847198486
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.462162275314331
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4209903049468995
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.476158962249756
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.434960680007935
#
# Total train accuarcy: 3.2
# Total train loss: 4.455489213943482
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 3.8
# Test average loss: 4.496478239695231
#
# [ Train epoch: 24 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.443106527328491
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.454283313751221
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.46099401473999
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.4747335243225095
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.448925609588623
#
# Total train accuarcy: 3.65
# Total train loss: 4.456408597946167
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 3.3
# Test average loss: 4.481727796887594
#
# [ Train epoch: 25 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.42065396308899
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.423915538787842
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.460251522064209
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.456888933181762
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.467257795333862
#
# Total train accuarcy: 4.3
# Total train loss: 4.445793550491333
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 3.8
# Test average loss: 4.477233924562969
#
# [ Train epoch: 26 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.433037605285644
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.455065450668335
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.448287105560302
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.422492647171021
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.446727466583252
#
# Total train accuarcy: 3.8
# Total train loss: 4.441122055053711
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 4.4
# Test average loss: 4.457526063162183
#
# [ Train epoch: 27 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.451292161941528
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.425539541244507
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.443962831497192
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.448368921279907
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.426757230758667
#
# Total train accuarcy: 3.9
# Total train loss: 4.439184137344361
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 6.1
# Test average loss: 4.452116262345087
#
# [ Train epoch: 28 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.408811483383179
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.478029022216797
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.443468017578125
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.443294343948364
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.435101490020752
#
# Total train accuarcy: 3.6
# Total train loss: 4.4417408714294435
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 2.9
# Test average loss: 4.461641682518853
#
# [ Train epoch: 29 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.447708711624146
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.4387963676452635
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.401175756454467
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.430359439849854
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.419397201538086
#
# Total train accuarcy: 4.25
# Total train loss: 4.427487495422363
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 3.6
# Test average loss: 4.4585700035095215
#
# [ Train epoch: 30 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.430442686080933
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.447625579833985
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4274281311035155
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.399489402770996
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.406448583602906
#
# Total train accuarcy: 4.475
# Total train loss: 4.422286876678466
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 4.9
# Test average loss: 4.458363275679331
#
# [ Train epoch: 31 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.428982067108154
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.413523731231689
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.4407783889770505
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.431201066970825
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.4084482097625735
#
# Total train accuarcy: 4.15
# Total train loss: 4.424586692810059
#
# [ Test epoch: 31 ]
#
# Test accuarcy: 4.3
# Test average loss: 4.455747112395271
#
# [ Train epoch: 32 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.413561410903931
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.433493309020996
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.399726076126099
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.402377557754517
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.4088595008850096
#
# Total train accuarcy: 3.85
# Total train loss: 4.4116035709381105
#
# [ Test epoch: 32 ]
#
# Test accuarcy: 4.7
# Test average loss: 4.44759852545602
#
# [ Train epoch: 33 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.413201007843018
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.394468984603882
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.372699012756348
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.440335359573364
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.4137467098236085
#
# Total train accuarcy: 4.2
# Total train loss: 4.406890214920044
#
# [ Test epoch: 33 ]
#
# Test accuarcy: 3.4
# Test average loss: 4.4311362523881215
#
# [ Train epoch: 34 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.413074626922607
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.4051603412628175
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.40919490814209
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.400013113021851
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.377814893722534
#
# Total train accuarcy: 4.1
# Total train loss: 4.40105157661438
#
# [ Test epoch: 34 ]
#
# Test accuarcy: 4.9
# Test average loss: 4.432772356366354
#
# [ Train epoch: 35 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.400393362045288
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.40568452835083
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.359630451202393
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.3777718925476075
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.406640214920044
#
# Total train accuarcy: 4.175
# Total train loss: 4.390024089813233
#
# [ Test epoch: 35 ]
#
# Test accuarcy: 5.0
# Test average loss: 4.421904193030463
#
# [ Train epoch: 36 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.388087930679322
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.390032939910888
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.41699257850647
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     378             with _open_zipfile_writer(opened_file) as opened_zipfile:
# --> 379                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
#     380                 return
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol)
#     603         num_bytes = storage.nbytes()
# --> 604         zip_file.write_record(name, storage.data_ptr(), num_bytes)
#     605
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-63-9914a83cac26> in <module>
#       1 ## 학습을 진행해 주세요 (GPU로 돌려야 합니다 CPU는 너무 느려요)
#       2 for epoch in range(0,num_epochs):
# ----> 3   train(Resnet ,epoch,optimizer,criterion,save_every=10)
#       4   test(Resnet ,epoch,criterion)
#
# <ipython-input-51-601dec756525> in train(model, epoch, optimizer, criterion, scheduler, save_every)
#      51                   'loss': loss
#      52                   #,'sch': scheduler.state_dict()
# ---> 53                   }, os.path.join(directory, '{}ep_{}iter_{}.tar'.format(epoch,batch_idx,'checkpoint')))
#      54
#      55     avg_loss = sum(batch_losses) / len(batch_losses)
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization)
#     378             with _open_zipfile_writer(opened_file) as opened_zipfile:
#     379                 _save(obj, opened_zipfile, pickle_module, pickle_protocol)
# --> 380                 return
#     381         _legacy_save(obj, opened_file, pickle_module, pickle_protocol)
#     382
#
# /usr/local/lib/python3.7/dist-packages/torch/serialization.py in __exit__(self, *args)
#     257
#     258     def __exit__(self, *args) -> None:
# --> 259         self.file_like.write_end_of_file()
#     260         self.buffer.flush()
#     261
#
# RuntimeError: [enforce fail at inline_container.cc:319] . unexpected pos 596352 vs 596248

# %%
## 저장이 진행되었는지 확인해 보시고 성능 그래프를 그려주세요
plt.plot(range(num_epochs), seq_train_loss, label="Train loss")
plt.plot(range(num_epochs), seq_test_loss, label="Test loss")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(range(num_epochs), seq_train_acc, label="Train Accuracy")
plt.plot(range(num_epochs), seq_test_acc, label="Test Accuracy")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# 저장공간이 없어 학습이 취소됐고,.... 에폭 35에서 끊겼습니다.
# accuracy가 형편이 없어서 이유를 고민하여 보니, resnet의 구조만 가져왔기 때문에 (pretrained = False)
#
#
# pretrained = True를 바꿔서 전이학습으로 다시 학습을 진행하려 하였으나, GPU사용량이 너무 많아 연결이 끊겼습니다.. ㅜㅠ

# %% [markdown]
# ![Screen Shot 2022-08-31 at 11.25.47 AM.png](data:image/png;base64,...)

# %% [markdown]
# 수고하셨습니다!
