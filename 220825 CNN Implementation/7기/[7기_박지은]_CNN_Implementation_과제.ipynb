# %% [markdown]
# # HomeWork

# %% [markdown]
# 과제는 다음과 같습니다.
#
# 1. 이미지 최종 embedding size 맞도록 계산 및 코드 수정하기
# 2. 좋은 성능이 나오도록 자유롭게 Resnet Fine tunning 실험해보기

# %% [markdown]
# ##1. Image Size 수정

# %% [markdown]
# 앞선 수업코드에서는 ResNet 본래의 input size인 224를 맞추기 위해 Resize와 Crop을 사용하였습니다.

# %% [markdown]
# 그러나 resize와 crop을 거친 이미지는 원본의 특징을 정확하게 반영하지 못할 가능성이 있습니다.

# %% [markdown]
# 따라서 아래의 식을 이용해 ResNet18이 우리의 input image size를 받고도 작동하도록 모델을 바꿔주세요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 즉, 224*224가 아닌,
#
#  우리의 이미지 크기 64*64가 ResNet으로 들어가
#
#  최종 layer에서 7*7의 차원을 갖도록 output size를 조절해가며 stride, padding 및 kernel size등을 조정해 보시면 됩니다.

# %%
# 필요한 모듈 import

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision 
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
# 전이학습에 사용할 ResNet load
Resnet = torchvision.models.resnet18(pretrained=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
## Fine Tuning위해 ResNet model layer의 이름 확인
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name)
# Out:
# Layer Name :  conv1
# Layer Name :  bn1
# Layer Name :  relu
# Layer Name :  maxpool
# Layer Name :  layer1
# Layer Name :  layer2
# Layer Name :  layer3
# Layer Name :  layer4
# Layer Name :  avgpool
# Layer Name :  fc

# %%
# Fine Tuning

# conv1 stride: 2->1, padding: 3->1
Resnet.conv1.stride = (1, 1)
Resnet.conv1.padding = (1, 1)

# maxpool kernel: 3->7, stride: 2->1
Resnet.maxpool.kernel = (7, 7)
Resnet.maxpool.stride = (1, 1)

# %% [markdown]
# **이 부분에 어떻게 stride, padding등을 바꿔서 최종 7*7을 만들었는지 서술 해 주세요**
#
# 1. conv1에서 stride를 1로, padding을 1로 수정
# 2. 첫 번째 maxpool에서 kernel을 7로, padding을 1로 수정
# 3. 이후는 동일
# ![IMG_7E339A2845B2-1.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2. 성능 높이기

# %% [markdown]
# Resnet의 layer4 부분까지 fine-tunning 해 주세요

# %% [markdown]
# 여러 hyperparameter들은 자유롭게 변경해가며 본인만의 ResNet을 만들어 보세요

# %% [markdown]
# ## 3. 코드 구현 부분

# %%
## 필요한 모듈 import

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision 
from torchvision import datasets, models, transforms

import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
# ResNet18의 layer이름을 확인 (이후 layer 고칠 때 찾기 쉬우라고 함)
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) # 각 layer의 이름 확인
  print('Layer Info. : ',child) # 각 layer의 정보 확인
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=(1, 1), padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=1000, bias=True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# python에서 파일 관리해주는 라이브러리
import os
import glob
import shutil

# %%
# 압축 풀기
# !unzip -qq "/content/drive/MyDrive/[0825] CNN Implementation/face_dataset.zip"

# %%
# !ls
# Out:
# drive  face_dataset  sample_data

# %%
## 데이터셋 로드 
## 제공된 사람 얼굴 이미지를 사용할 것
from torchvision.datasets import ImageFolder
import os

data_dir = 'face_dataset'
path = {x: os.path.join('/content/',data_dir,'facescrub_'+x) for x in ['train', 'test'] } # Train, Test 경로 지정
## local에 이미지를 저장했으면 저장한 경로만 찾아서 붙여넣어 주기
print(path)
train_data = ImageFolder(path['train'], transforms.Compose([transforms.ToTensor()]))
# Out:
# {'train': '/content/face_dataset/facescrub_train', 'test': '/content/face_dataset/facescrub_test'}

# %%
# Input Normalize 계산하는데 오래걸려서 미리 구해둠
avgR = 0.6565039 
avgG = 0.4843807
avgB = 0.4084822
stdR = 0.20245129
stdG = 0.17317267
stdB = 0.1622832

# %%
## 데이터 전처리를 위한 과정

data_transforms = {
    'facescrub_train': transforms.Compose([
        # 이미지 증강
        transforms.RandomHorizontalFlip(), # 수평으로 뒤집기
        transforms.RandomVerticalFlip(), # 수직으로 뒤집기
        # 이미지를 텐서로 변경
        transforms.ToTensor(),
        # Input 값 Normalize 해주기 ( 각 채널의 평균 값과 표준편차 값으로 정규화 해줌 )
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
    # 위와 동일한 과정 Test set에 대해 진행하기
    'facescrub_test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
}

# %%
## 앞서 정의한 data_transforms를 이용해 실제 train과 test 이미지셋을 만들어 준다
image_datasets = {x: datasets.ImageFolder(os.path.join('/content/face_dataset/', x),
                                          data_transforms[x]) for x in ['facescrub_train', 'facescrub_test']}

# %%
## Train과 Testset의 크기 확인
data_sizes = {x: len(image_datasets[x]) for x in ['facescrub_train', 'facescrub_test']}
print(data_sizes['facescrub_train'])
print(data_sizes['facescrub_test'])
# Out:
# 4000
# 1000

# %%
## Dataloader를 설정해 준다
dataloaders = {x: torch.utils.data.DataLoader(
                       image_datasets[x], batch_size=16, # 이 부분에서 batch_size를 설정할 수 있음 
                       shuffle=True, # train data를 batch로 묶을 때 섞을 것인지 결정
                       num_workers=2) # Dataloader가 data를 읽어들일 때 사용할 스레드의 개수 (GPU 사용량을 결정)
                                            for x in ['facescrub_train', 'facescrub_test']}
## class 이름 설정 
class_names = image_datasets['facescrub_train'].classes 

## 어떤 device를 이용할 것인지 결정한다 (gpu 불가능하면 cpu)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
print(device)
# Out:
# cuda:0

# %%
## Resnet의 output layer를 우리의 이미지에 맞도록 크기조정 해 주세요
## 단, kernel size를 바꿀 경우 가중치의 개수가 달라지므로 Fine-Tunning 시 해당 layer도 넣어서 해주셔야 합니다!
## stride를 조작해 보시는 것을 추천드립니다

num_ftrs = Resnet.fc.in_features # ResNet의 'fc' 라는 layer에 들어오는 feature 확인
Resnet.fc = nn.Linear(num_ftrs,len(class_names))

# %%
## 해당 코드는 참조 코드입니다.
## 해당 cell을 실행시키면 Resnet 의 layer3의 conv1, downsample과 layer4의 conv1, downsample의 stride가 변경됩니다.
#Resnet.layer3[0].conv1.stride = (1, 1)
#Resnet.layer3[0].downsample[0].stride = (1, 1)
#Resnet.layer4[0].conv1.stride = (1, 1)
#Resnet.layer4[0].downsample[0].stride = (1, 1)

# %%
# 변경된 정보를 확인해 보세요
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) 
  print('Layer Info. : ',child) 
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=(1, 1), padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=100, bias=True)

# %%
seq_train_loss = []
seq_test_loss = []
seq_train_acc = []
seq_test_acc = []

# %%
## Train 함수 정의

def train(model,epoch,optimizer,criterion,scheduler=None,save_every=None):
    ## 각 단계의 loss 및 accuracy 저장할 list 생성

    print(f'\n[ Train epoch: {epoch+1} ]')

    model.train() # Train 단계임을 선업

    running_loss = 0.0
    batch_losses = []
    total = 0
    correct = 0

    for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_train']): # Train data 가져오기
        inputs, targets = inputs.to(device), targets.to(device) # dataloader의 input image와 label도 device에 넣어준다
      
        optimizer.zero_grad() # gradient 초기화
        outputs = model(inputs) # Prediction value 계산 (Output 계산)
        loss = criterion(outputs, targets) # outputs와 원래 label인 targets 사이 loss 계산
        loss.backward() # 계산한 loss 기반으로 gradient 값 계산
        optimizer.step() # weight parameter update
        if scheduler != None:
            if batch_idx in [80, 160, 200]:
                scheduler.step() # Scheduler update

        total += targets.size(0) # batch 데이터 개수 더하기
        running_loss += loss.item()
        batch_losses.append(loss.item())
        
        _, predicted = outputs.max(1) # 확률값 가장 높게 나타난 클래스
        correct += (predicted == targets).sum().item() # 현재 batch 내에서 알맞게 분류한 이미지 개수 더하기
        
        if batch_idx % 50 == 49:
            ## 학습 중간 성능 확인
            print(f'\nCurrent batch: {str(batch_idx+1)}')
            print(f'Average train loss of recent 50 batches: {running_loss / 50}') 
            running_loss = 0.0

        if save_every != None:
         if (batch_idx % save_every == 0): # 얼마만큼의 iteration마다 저장할 것인지를 설정
              directory = os.path.join(save_path, 'Resnet') # 경로 설정
              if not os.path.exists(directory): # 경로가 없다면 새로 만듦
                  os.makedirs(directory)
              torch.save({ 
                  # 학습 중간에 저장하려 하는 모든 것들을 dict로 서술
                  'epoch': epoch, 
                  'iteration': batch_idx,
                  'model': model.state_dict(),
                  'opt': optimizer.state_dict(),
                  'loss': loss
                  #,'sch': scheduler.state_dict()
                  }, os.path.join(directory, '{}ep_{}iter_{}.tar'.format(epoch,batch_idx,'checkpoint')))

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_train_loss.append(avg_loss)
    seq_train_acc.append(100*correct/total)
    print('\nTotal train accuarcy:', 100. * correct / total) # 전체 데이터 개수에서 맞게 예측한 비율
    print('Total train loss:', avg_loss)

# %%
def test(model,epoch,criterion):
    print(f'\n[ Test epoch: {epoch+1} ]')

    model.eval() # Test time임을 선언

    loss = 0
    batch_losses = []
    correct = 0
    total = 0

    with torch.no_grad(): # gradient update 안함 - eval과 torch.no_grad는 하나의 세트
        for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_test']):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)
            batch_losses.append(loss.item())

            total += targets.size(0)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_test_loss.append(avg_loss)
    seq_test_acc.append(100 * correct / total)
    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', avg_loss)

# %%
## fine-tunning 하고싶은 부분을 제외하고 update를 얼려 주세요
for name,child in Resnet.named_children():
  for param in child.parameters():
    if name not in ['fc']:   # 'fc' 이름의 layer만 제외
      param.requires_grad = False

# %%
## 지정한 device에 학습시킬 모델 얹어주기
Resnet.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=(1, 1), padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
## Optimizer, Scheduler, Cost Function 등을 직접 설정해서 사용해 보세요
optimizer = optim.Adam(Resnet.parameters(), lr=0.001)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
criterion = nn.CrossEntropyLoss()

# %%
num_epochs = 20

# %%
## Checkpoint를 저장할 경로를 설정해 주세요
save_path = '/content/drive/MyDrive/[0825] CNN Implementation/save'

# %%
## 학습을 진행해 주세요 (GPU로 돌려야 합니다 CPU는 너무 느려요)
for epoch in range(0,num_epochs):
  train(Resnet,epoch,optimizer,criterion,save_every=10)
  test(Resnet,epoch,criterion)
# Out:
# [ Train epoch: 1 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 5.021420269012451
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.718478269577027
#
# Current batch: 150
# Average train loss of recent 50 batches: 4.5588227558135985
#
# Current batch: 200
# Average train loss of recent 50 batches: 4.401028938293457
#
# Current batch: 250
# Average train loss of recent 50 batches: 4.280234661102295
#
# Total train accuarcy: 3.75
# Total train loss: 4.595996978759765
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 9.2
# Test average loss: 4.081436849775768
#
# [ Train epoch: 2 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.0024677276611325
#
# Current batch: 100
# Average train loss of recent 50 batches: 3.8646423912048338
#
# Current batch: 150
# Average train loss of recent 50 batches: 3.8527438402175904
#
# Current batch: 200
# Average train loss of recent 50 batches: 3.7949080991744997
#
# Current batch: 250
# Average train loss of recent 50 batches: 3.662088475227356
#
# Total train accuarcy: 14.875
# Total train loss: 3.8353701066970824
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 19.7
# Test average loss: 3.5723920965951588
#
# [ Train epoch: 3 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 3.476569619178772
#
# Current batch: 100
# Average train loss of recent 50 batches: 3.442140212059021
#
# Current batch: 150
# Average train loss of recent 50 batches: 3.3462587213516235
#
# Current batch: 200
# Average train loss of recent 50 batches: 3.2675351905822754
#
# Current batch: 250
# Average train loss of recent 50 batches: 3.2246592807769776
#
# Total train accuarcy: 25.075
# Total train loss: 3.351432604789734
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 25.1
# Test average loss: 3.3150248565371077
#
# [ Train epoch: 4 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 3.0670290994644165
#
# Current batch: 100
# Average train loss of recent 50 batches: 3.044544134140015
#
# Current batch: 150
# Average train loss of recent 50 batches: 3.0864387130737305
#
# Current batch: 200
# Average train loss of recent 50 batches: 3.0159054088592527
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.9533840465545653
#
# Total train accuarcy: 31.6
# Total train loss: 3.033460280418396
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 30.2
# Test average loss: 3.043550146950616
#
# [ Train epoch: 5 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.847973418235779
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.7936738777160643
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.772602951526642
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.755255641937256
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.6921827507019045
#
# Total train accuarcy: 37.425
# Total train loss: 2.772337728023529
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 36.3
# Test average loss: 2.8473264868297274
#
# [ Train epoch: 6 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.483587999343872
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.6119884204864503
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.5986579275131225
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.548192207813263
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.573230671882629
#
# Total train accuarcy: 42.3
# Total train loss: 2.5631314454078673
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 37.2
# Test average loss: 2.719011289732797
#
# [ Train epoch: 7 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.409331703186035
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.3184540176391604
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.420842025279999
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.4101157879829405
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.375558738708496
#
# Total train accuarcy: 45.6
# Total train loss: 2.386860454559326
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 39.8
# Test average loss: 2.5956134550155157
#
# [ Train epoch: 8 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.247291886806488
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.31107905626297
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.251305181980133
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.215929062366486
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.2002673411369322
#
# Total train accuarcy: 48.825
# Total train loss: 2.245174505710602
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 39.4
# Test average loss: 2.5882288879818387
#
# [ Train epoch: 9 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.1700204753875734
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.1300076985359193
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.177448525428772
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.117972767353058
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.2129429507255556
#
# Total train accuarcy: 49.9
# Total train loss: 2.1616784834861758
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 42.0
# Test average loss: 2.4842343424993847
#
# [ Train epoch: 10 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.179538061618805
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.0829977703094484
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.0192787051200867
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.9841804027557373
#
# Current batch: 250
# Average train loss of recent 50 batches: 2.0597220706939696
#
# Total train accuarcy: 51.8
# Total train loss: 2.0651434020996096
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 41.8
# Test average loss: 2.4496968662928023
#
# [ Train epoch: 11 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.9821023368835449
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.9479761362075805
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.9460341382026671
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.971934702396393
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.9710745644569396
#
# Total train accuarcy: 54.85
# Total train loss: 1.9638243756294251
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 42.8
# Test average loss: 2.3891441140856062
#
# [ Train epoch: 12 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.93119357585907
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.8915131068229676
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.9078578019142152
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.002709321975708
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.9301837825775146
#
# Total train accuarcy: 53.65
# Total train loss: 1.9326915178298951
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 46.4
# Test average loss: 2.33539426894415
#
# [ Train epoch: 13 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.794555492401123
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.8520482277870178
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.7971223568916321
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.9252145075798035
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.8527903413772584
#
# Total train accuarcy: 55.675
# Total train loss: 1.844346185207367
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 45.9
# Test average loss: 2.328323901645721
#
# [ Train epoch: 14 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.8677151131629943
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.847407772541046
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.797019612789154
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.7691032314300537
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.6905564308166503
#
# Total train accuarcy: 56.975
# Total train loss: 1.7943604321479798
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 45.7
# Test average loss: 2.30763136015998
#
# [ Train epoch: 15 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.8250599932670593
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.7374816155433654
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.7353842151165009
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.7081546902656555
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.6675451016426086
#
# Total train accuarcy: 58.175
# Total train loss: 1.734725123167038
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 43.8
# Test average loss: 2.295822675265963
#
# [ Train epoch: 16 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.739663758277893
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.6363586139678956
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.6745683670043945
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.691690366268158
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.7674070477485657
#
# Total train accuarcy: 58.325
# Total train loss: 1.7019376306533813
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 45.5
# Test average loss: 2.2856385688933116
#
# [ Train epoch: 17 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.5781125104427338
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.7347976899147033
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.5880796527862548
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.5993241369724274
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.6342112278938294
#
# Total train accuarcy: 61.025
# Total train loss: 1.6269050436019898
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 47.8
# Test average loss: 2.1774922211964927
#
# [ Train epoch: 18 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.5447035682201387
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.6183235943317413
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.6022028601169587
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.5911578845977783
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.65271821141243
#
# Total train accuarcy: 61.45
# Total train loss: 1.6018212237358094
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 46.4
# Test average loss: 2.228646172417535
#
# [ Train epoch: 19 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.5493537294864654
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.6113193321228028
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.6284751451015473
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.5644455289840697
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.581111215353012
#
# Total train accuarcy: 59.725
# Total train loss: 1.5869409902095795
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 45.4
# Test average loss: 2.2341763594793895
#
# [ Train epoch: 20 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.5020477867126465
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.4860634410381317
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.5570242917537689
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.5555707681179047
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.615218563079834
#
# Total train accuarcy: 62.325
# Total train loss: 1.5431849701404572
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 47.4
# Test average loss: 2.1663565938434903

# %%
## 저장이 진행되었는지 확인해 보시고 성능 그래프를 그려주세요
plt.plot(range(num_epochs), seq_train_loss, label="Train loss")
plt.plot(range(num_epochs), seq_test_loss, label="Test loss")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(range(num_epochs), seq_train_acc, label="Train Accuracy")
plt.plot(range(num_epochs), seq_test_acc, label="Test Accuracy")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# 수고하셨습니다!
