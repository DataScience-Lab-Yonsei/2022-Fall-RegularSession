# %% [markdown]
# # HomeWork

# %% [markdown]
# 과제는 다음과 같습니다.
#
# 1. 이미지 최종 embedding size 맞도록 계산 및 코드 수정하기
# 2. 좋은 성능이 나오도록 자유롭게 Resnet Fine tunning 실험해보기

# %% [markdown]
# ##1. Image Size 수정

# %% [markdown]
# 앞선 수업코드에서는 ResNet 본래의 input size인 224를 맞추기 위해 Resize와 Crop을 사용하였습니다.

# %% [markdown]
# 그러나 resize와 crop을 거친 이미지는 원본의 특징을 정확하게 반영하지 못할 가능성이 있습니다.

# %% [markdown]
# 따라서 아래의 식을 이용해 ResNet18이 우리의 input image size를 받고도 작동하도록 모델을 바꿔주세요

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 즉, 224*224가 아닌,
#
#  우리의 이미지 크기 64*64가 ResNet으로 들어가
#
#  최종 layer에서 7*7의 차원을 갖도록 output size를 조절해가며 stride, padding 및 kernel size등을 조정해 보시면 됩니다.

# %% [markdown]
# **이 부분에 어떻게 stride, padding등을 바꿔서 최종 7*7을 만들었는지 서술 해 주세요**

# %% [markdown]
# layer3의 stride 2 -> 1로 교체
# layer4의 stride 2- > 1로 교체

# %% [markdown]
# ## 2. 성능 높이기

# %% [markdown]
# Resnet의 layer4 부분까지 fine-tunning 해 주세요

# %% [markdown]
# 여러 hyperparameter들은 자유롭게 변경해가며 본인만의 ResNet을 만들어 보세요

# %% [markdown]
# ## 3. 코드 구현 부분

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/CNNimplementation
# Out:
# /content/drive/MyDrive/CNNimplementation

# %%
## 필요한 모듈 import

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torchvision 
from torchvision import datasets, models, transforms
from torchsummary import summary

import matplotlib.pyplot as plt
import numpy as np
import time
import copy

# %%
# Pre-trained ResNet 가져오기
Resnet = torchvision.models.resnet18(pretrained=True) # 해당 부분을 False로 바꾸면 구조만 가져온다
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
#   0%|          | 0.00/44.7M [00:00<?, ?B/s]

# %%
# ResNet18의 layer이름을 확인 ( 이후 layer 고칠 때 찾기 쉬우라고 함 )
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) # 각 layer의 이름 확인
  print('Layer Info. : ',child) # 각 layer의 정보 확인
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=1000, bias=True)

# %%
# !unzip -qq "face_dataset.zip"

# %%
## 데이터셋 로드 
from torchvision.datasets import ImageFolder
import os

data_dir = 'CNNimplementation/face_dataset'
path = {x: os.path.join('/content/drive/MyDrive/',data_dir,'facescrub_'+x) for x in ['train', 'test'] } # Train, Test 경로 지정
## local에 이미지를 저장했으면 저장한 경로만 찾아서 붙여넣어 주기
print(path)
train_data = ImageFolder(path['train'], transforms.Compose([transforms.ToTensor()]))
# Out:
# {'train': '/content/drive/MyDrive/CNNimplementation/face_dataset/facescrub_train', 'test': '/content/drive/MyDrive/CNNimplementation/face_dataset/facescrub_test'}

# %%
# Input Normalize 계산하는데 오래걸려서 미리 구해둠
avgR = 0.6565039 
avgG = 0.4843807
avgB = 0.4084822
stdR = 0.20245129
stdG = 0.17317267
stdB = 0.1622832

# %%
## 데이터 전처리를 위한 과정

data_transforms = {
    'facescrub_train': transforms.Compose([
        # 이미지 증강
        transforms.RandomHorizontalFlip(), # 수평으로 뒤집기
        transforms.RandomVerticalFlip(), # 수직으로 뒤집기
        # 이미지를 텐서로 변경
        transforms.ToTensor(),
        # Input 값 Normalize 해주기 ( 각 채널의 평균 값과 표준편차 값으로 정규화 해줌 )
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
    # 위와 동일한 과정 Test set에 대해 진행하기
    'facescrub_test': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize([avgR, avgG, avgB], [stdR, stdG, stdB])
    ]),
}

# %%
## 앞서 정의한 data_transforms를 이용해 실제 train과 test 이미지셋을 만들어 준다
image_datasets = {x: datasets.ImageFolder(os.path.join('/content/drive/MyDrive/CNNimplementation/face_dataset/', x),
                                          data_transforms[x]) for x in ['facescrub_train', 'facescrub_test']}

# %%
## Train과 Testset의 크기 확인
data_sizes = {x: len(image_datasets[x]) for x in ['facescrub_train', 'facescrub_test']}
print(data_sizes['facescrub_train'])
print(data_sizes['facescrub_test'])
# Out:
# 4000
# 1000

# %%
## Dataloader를 설정해 준다
dataloaders = {x: torch.utils.data.DataLoader(
                       image_datasets[x], batch_size=16, # 이 부분에서 batch_size를 설정할 수 있음 
                       shuffle=True, # train data를 batch로 묶을 때 섞을 것인지 결정
                       num_workers=2) # Dataloader가 data를 읽어들일 때 사용할 스레드의 개수 (GPU 사용량을 결정)
                                            for x in ['facescrub_train', 'facescrub_test']}
## class 이름 설정 
class_names = image_datasets['facescrub_train'].classes 

## 어떤 device를 이용할 것인지 결정한다 (gpu 불가능하면 cpu)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
## 세 전이학습에 사용할 ResNet 각각 load
## Resnet을 불러와 주세요
Resnet = torchvision.models.resnet18(pretrained = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
## Resnet의 output layer를 우리의 이미지에 맞도록 크기조정 해 주세요
## 단, kernel size를 바꿀 경우 가중치의 개수가 달라지므로 Fine-Tunning 시 해당 layer도 넣어서 해주셔야 합니다!
## stride를 조작해 보시는 것을 추천드립니다
Resnet.fc = nn.Linear(512, len(class_names))

# %%
## 해당 코드는 참조 코드입니다.
## 해당 cell을 실행시키면 Resnet 의 layer3의 conv1, downsample과 layer4의 conv1, downsample의 stride가 변경됩니다.
Resnet.layer3[0].conv1.stride = (1, 1)
Resnet.layer3[0].downsample[0].stride = (1, 1)
Resnet.layer4[0].conv1.stride = (1, 1)
Resnet.layer4[0].downsample[0].stride = (1, 1)

# %%
# 변경된 정보를 확인해 보세요
for name,child in Resnet.named_children(): 
  print('Layer Name : ',name) 
  print('Layer Info. : ',child) 
  print()
# Out:
# Layer Name :  conv1
# Layer Info. :  Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#
# Layer Name :  bn1
# Layer Info. :  BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#
# Layer Name :  relu
# Layer Info. :  ReLU(inplace=True)
#
# Layer Name :  maxpool
# Layer Info. :  MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#
# Layer Name :  layer1
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer2
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#       (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer3
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  layer4
# Layer Info. :  Sequential(
#   (0): BasicBlock(
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (downsample): Sequential(
#       (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (1): BasicBlock(
#     (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# )
#
# Layer Name :  avgpool
# Layer Info. :  AdaptiveAvgPool2d(output_size=(1, 1))
#
# Layer Name :  fc
# Layer Info. :  Linear(in_features=512, out_features=100, bias=True)

# %%
summary(Resnet, (3, 64, 64), batch_size = 64, device = 'cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [64, 64, 32, 32]           9,408
#        BatchNorm2d-2           [64, 64, 32, 32]             128
#               ReLU-3           [64, 64, 32, 32]               0
#          MaxPool2d-4           [64, 64, 16, 16]               0
#             Conv2d-5           [64, 64, 16, 16]          36,864
#        BatchNorm2d-6           [64, 64, 16, 16]             128
#               ReLU-7           [64, 64, 16, 16]               0
#             Conv2d-8           [64, 64, 16, 16]          36,864
#        BatchNorm2d-9           [64, 64, 16, 16]             128
#              ReLU-10           [64, 64, 16, 16]               0
#        BasicBlock-11           [64, 64, 16, 16]               0
#            Conv2d-12           [64, 64, 16, 16]          36,864
#       BatchNorm2d-13           [64, 64, 16, 16]             128
#              ReLU-14           [64, 64, 16, 16]               0
#            Conv2d-15           [64, 64, 16, 16]          36,864
#       BatchNorm2d-16           [64, 64, 16, 16]             128
#              ReLU-17           [64, 64, 16, 16]               0
#        BasicBlock-18           [64, 64, 16, 16]               0
#            Conv2d-19            [64, 128, 8, 8]          73,728
#       BatchNorm2d-20            [64, 128, 8, 8]             256
#              ReLU-21            [64, 128, 8, 8]               0
#            Conv2d-22            [64, 128, 8, 8]         147,456
#       BatchNorm2d-23            [64, 128, 8, 8]             256
#            Conv2d-24            [64, 128, 8, 8]           8,192
#       BatchNorm2d-25            [64, 128, 8, 8]             256
#              ReLU-26            [64, 128, 8, 8]               0
#        BasicBlock-27            [64, 128, 8, 8]               0
#            Conv2d-28            [64, 128, 8, 8]         147,456
#       BatchNorm2d-29            [64, 128, 8, 8]             256
#              ReLU-30            [64, 128, 8, 8]               0
#            Conv2d-31            [64, 128, 8, 8]         147,456
#       BatchNorm2d-32            [64, 128, 8, 8]             256
#              ReLU-33            [64, 128, 8, 8]               0
#        BasicBlock-34            [64, 128, 8, 8]               0
#            Conv2d-35            [64, 256, 8, 8]         294,912
#       BatchNorm2d-36            [64, 256, 8, 8]             512
#              ReLU-37            [64, 256, 8, 8]               0
#            Conv2d-38            [64, 256, 8, 8]         589,824
#       BatchNorm2d-39            [64, 256, 8, 8]             512
#            Conv2d-40            [64, 256, 8, 8]          32,768
#       BatchNorm2d-41            [64, 256, 8, 8]             512
#              ReLU-42            [64, 256, 8, 8]               0
#        BasicBlock-43            [64, 256, 8, 8]               0
#            Conv2d-44            [64, 256, 8, 8]         589,824
#       BatchNorm2d-45            [64, 256, 8, 8]             512
#              ReLU-46            [64, 256, 8, 8]               0
#            Conv2d-47            [64, 256, 8, 8]         589,824
#       BatchNorm2d-48            [64, 256, 8, 8]             512
#              ReLU-49            [64, 256, 8, 8]               0
#        BasicBlock-50            [64, 256, 8, 8]               0
#            Conv2d-51            [64, 512, 8, 8]       1,179,648
#       BatchNorm2d-52            [64, 512, 8, 8]           1,024
#              ReLU-53            [64, 512, 8, 8]               0
#            Conv2d-54            [64, 512, 8, 8]       2,359,296
#       BatchNorm2d-55            [64, 512, 8, 8]           1,024
#            Conv2d-56            [64, 512, 8, 8]         131,072
#       BatchNorm2d-57            [64, 512, 8, 8]           1,024
#              ReLU-58            [64, 512, 8, 8]               0
#        BasicBlock-59            [64, 512, 8, 8]               0
#            Conv2d-60            [64, 512, 8, 8]       2,359,296
#       BatchNorm2d-61            [64, 512, 8, 8]           1,024
#              ReLU-62            [64, 512, 8, 8]               0
#            Conv2d-63            [64, 512, 8, 8]       2,359,296
#       BatchNorm2d-64            [64, 512, 8, 8]           1,024
#              ReLU-65            [64, 512, 8, 8]               0
#        BasicBlock-66            [64, 512, 8, 8]               0
# AdaptiveAvgPool2d-67            [64, 512, 1, 1]               0
#            Linear-68                  [64, 100]          51,300
# ================================================================
# Total params: 11,227,812
# Trainable params: 11,227,812
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 3.00
# Forward/backward pass size (MB): 664.30
# Params size (MB): 42.83
# Estimated Total Size (MB): 710.13
# ----------------------------------------------------------------

# %%
seq_train_loss = []
seq_test_loss = []
seq_train_acc = []
seq_test_acc = []

# %%
## Train 함수 정의

def train(model,epoch,optimizer,criterion,scheduler=None,save_every=None):
    ## 각 단계의 loss 및 accuracy 저장할 list 생성

    print(f'\n[ Train epoch: {epoch+1} ]')

    model.train() # Train 단계임을 선업

    running_loss = 0.0
    batch_losses = []
    total = 0
    correct = 0

    for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_train']): # Train data 가져오기
        inputs, targets = inputs.to(device), targets.to(device) # dataloader의 input image와 label도 device에 넣어준다
      
        optimizer.zero_grad() # gradient 초기화
        outputs = model(inputs) # Prediction value 계산 (Output 계산)
        loss = criterion(outputs, targets) # outputs와 원래 label인 targets 사이 loss 계산
        loss.backward() # 계산한 loss 기반으로 gradient 값 계산
        optimizer.step() # weight parameter update
        if scheduler != None:
            if batch_idx in [80, 160, 200]:
                scheduler.step() # Scheduler update

        total += targets.size(0) # batch 데이터 개수 더하기
        running_loss += loss.item()
        batch_losses.append(loss.item())
        
        _, predicted = outputs.max(1) # 확률값 가장 높게 나타난 클래스
        correct += (predicted == targets).sum().item() # 현재 batch 내에서 알맞게 분류한 이미지 개수 더하기
        
        if batch_idx % 50 == 49:
            ## 학습 중간 성능 확인
            print(f'\nCurrent batch: {str(batch_idx+1)}')
            print(f'Average train loss of recent 50 batches: {running_loss / 50}') 
            running_loss = 0.0

        if save_every != None:
            if (batch_idx % save_every == 0): # 얼마만큼의 iteration마다 저장할 것인지를 설정
                directory = os.path.join(save_path, 'Resnet') # 경로 설정
                if not os.path.exists(directory): # 경로가 없다면 새로 만듦
                    os.makedirs(directory)
                torch.save({ 
                  # 학습 중간에 저장하려 하는 모든 것들을 dict로 서술
                  'epoch': epoch, 
                  'iteration': batch_idx,
                  'model': model.state_dict(),
                  'opt': optimizer.state_dict(),
                  'loss': loss
                  ,'sch': scheduler.state_dict()
                  }, os.path.join(directory, '{}ep_{}iter_{}.tar'.format(epoch,batch_idx,'checkpoint')))

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_train_loss.append(avg_loss)
    seq_train_acc.append(100*correct/total)
    print('\nTotal train accuarcy:', 100. * correct / total) # 전체 데이터 개수에서 맞게 예측한 비율
    print('Total train loss:', avg_loss)

# %%
def test(model,epoch,criterion):
    print(f'\n[ Test epoch: {epoch+1} ]')

    model.eval() # Test time임을 선언

    loss = 0
    batch_losses = []
    correct = 0
    total = 0

    with torch.no_grad(): # gradient update 안함 - eval과 torch.no_grad는 하나의 세트
        for batch_idx, (inputs, targets) in enumerate(dataloaders['facescrub_test']):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = model(inputs)
            loss = criterion(outputs, targets)
            batch_losses.append(loss.item())

            total += targets.size(0)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_test_loss.append(avg_loss)
    seq_test_acc.append(100 * correct / total)
    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', avg_loss)

# %%
## fine-tunning 하고싶은 부분을 제외하고 update를 얼려 주세요
for name,child in Resnet.named_children():
    for param in child.parameters():
        if name not in ['fc','layer3','layer4']:   # 'fc' 이름의 layer만 제외
            param.requires_grad = False

# %%
## 지정한 device에 학습시킬 모델 얹어주기
Resnet.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
## Optimizer, Scheduler, Cost Function 등을 직접 설정해서 사용해 보세요
optimizer = torch.optim.Adam(Resnet.parameters(), lr = 0.001, weight_decay = 0.0001)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max = 15)
criterion = nn.CrossEntropyLoss().to(device)

# %%
num_epochs = 15

# %%
## Checkpoint를 저장할 경로를 설정해 주세요
save_path = os.path.join(os.getcwd(), 'result')
save_path
# Out:
# '/content/drive/MyDrive/CNNimplementation/result'

# %%
## 학습을 진행해 주세요 (GPU로 돌려야 합니다 CPU는 너무 느려요)
for epoch in range(0,num_epochs):
    train(Resnet ,epoch,optimizer,criterion,scheduler, save_every=10)
    test(Resnet,epoch,criterion)
# Out:
# [ Train epoch: 1 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 4.860143957138061
#
# Current batch: 100
# Average train loss of recent 50 batches: 4.172734961509705
#
# Current batch: 150
# Average train loss of recent 50 batches: 3.754121403694153
#
# Current batch: 200
# Average train loss of recent 50 batches: 3.44822265625
#
# Current batch: 250
# Average train loss of recent 50 batches: 3.136839790344238
#
# Total train accuarcy: 11.45
# Total train loss: 3.8744125537872316
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 26.2
# Test average loss: 2.85910970067221
#
# [ Train epoch: 2 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 2.647569513320923
#
# Current batch: 100
# Average train loss of recent 50 batches: 2.5200263261795044
#
# Current batch: 150
# Average train loss of recent 50 batches: 2.4353347539901735
#
# Current batch: 200
# Average train loss of recent 50 batches: 2.197361922264099
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.9948172855377198
#
# Total train accuarcy: 38.6
# Total train loss: 2.359021960258484
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 51.1
# Test average loss: 1.8761515636292716
#
# [ Train epoch: 3 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.6357570886611938
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.7099023830890656
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.4807427608966828
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.358823343515396
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.358535178899765
#
# Total train accuarcy: 60.775
# Total train loss: 1.5087521510124207
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 71.1
# Test average loss: 1.2008843942294045
#
# [ Train epoch: 4 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.0090123629570007
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.9715416884422302
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.9492796969413757
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.9140458762645721
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.8331136244535446
#
# Total train accuarcy: 77.45
# Total train loss: 0.9353986498117447
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 75.7
# Test average loss: 0.9669498976260896
#
# [ Train epoch: 5 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.6577220439910889
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.6687910163402557
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.6233720356225967
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.7254357182979584
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.6802607220411301
#
# Total train accuarcy: 84.95
# Total train loss: 0.6711163072586059
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 76.6
# Test average loss: 0.9020869542681982
#
# [ Train epoch: 6 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.6798955500125885
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.6381093680858612
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.6230260649323464
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.6139557394385338
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.6632432150840759
#
# Total train accuarcy: 85.175
# Total train loss: 0.6436459875106811
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 77.5
# Test average loss: 0.8935061362054613
#
# [ Train epoch: 7 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.6139530953764916
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.6123749041557311
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.6655421048402786
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.6935843914747238
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.8297985154390335
#
# Total train accuarcy: 83.55
# Total train loss: 0.6830506022572518
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 73.3
# Test average loss: 1.0910714427157053
#
# [ Train epoch: 8 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.7511868423223496
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.7316593199968338
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.8542044335603713
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.8838504159450531
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.0793417799472809
#
# Total train accuarcy: 77.375
# Total train loss: 0.8600485583543778
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 65.9
# Test average loss: 1.323628510747637
#
# [ Train epoch: 9 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 1.043467971086502
#
# Current batch: 100
# Average train loss of recent 50 batches: 1.0049943846464158
#
# Current batch: 150
# Average train loss of recent 50 batches: 1.0411940693855286
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.098426389694214
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.186757334470749
#
# Total train accuarcy: 69.7
# Total train loss: 1.0749680298566817
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 59.5
# Test average loss: 1.5753875299105569
#
# [ Train epoch: 10 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.9829240828752518
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.9040683299303055
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.9951187407970429
#
# Current batch: 200
# Average train loss of recent 50 batches: 1.1035330319404602
#
# Current batch: 250
# Average train loss of recent 50 batches: 1.0759685498476028
#
# Total train accuarcy: 71.225
# Total train loss: 1.0123225470781327
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 63.0
# Test average loss: 1.4690483922050113
#
# [ Train epoch: 11 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.8954832324385643
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.776634219288826
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.9196676576137542
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.7525310137867928
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.83942158639431
#
# Total train accuarcy: 76.4
# Total train loss: 0.8367475419044494
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 73.3
# Test average loss: 1.0924829339224196
#
# [ Train epoch: 12 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.62352768689394
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.6125725120306015
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.5621997923403979
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.5580022349208593
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.5412512676417828
#
# Total train accuarcy: 83.075
# Total train loss: 0.5795106987655163
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 78.9
# Test average loss: 0.8523401877000218
#
# [ Train epoch: 13 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.35105532869696615
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.36430400118231776
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.3064916567504406
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.29641520738601684
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.3288331634551287
#
# Total train accuarcy: 91.4
# Total train loss: 0.329419871494174
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 83.6
# Test average loss: 0.6597086246613235
#
# [ Train epoch: 14 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.17698017410933972
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.2086273305490613
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.17835004307329655
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.19344110354781152
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.17269454941153525
#
# Total train accuarcy: 95.35
# Total train loss: 0.18601864013820887
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 85.9
# Test average loss: 0.5853545182044544
#
# [ Train epoch: 15 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.12189239282160998
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.12698102224618196
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.1283180720359087
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.12363189171999693
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.11260570069309324
#
# Total train accuarcy: 97.55
# Total train loss: 0.12268581590335816
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 85.9
# Test average loss: 0.5881514626717756

# %%
for epoch in range(num_epochs,num_epochs * 2):
    train(Resnet ,epoch,optimizer,criterion,scheduler, save_every=10)
    test(Resnet,epoch,criterion)
# Out:
# [ Train epoch: 16 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.10242531947791576
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.08772008154541254
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.13020125959068538
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.11805046802386641
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.10746150221675635
#
# Total train accuarcy: 97.75
# Total train loss: 0.10917172617092728
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 85.5
# Test average loss: 0.5819525414752582
#
# [ Train epoch: 17 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.1334283360466361
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.10039636205881834
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.1280974483676255
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.10927362374961376
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.13196940276771785
#
# Total train accuarcy: 97.55
# Total train loss: 0.1206330345980823
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 84.2
# Test average loss: 0.6504128063245426
#
# [ Train epoch: 18 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.13906008780002593
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.12870202761143446
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.207376750074327
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.21256449773907662
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.44691457152366637
#
# Total train accuarcy: 93.75
# Total train loss: 0.22692358694970607
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 74.2
# Test average loss: 1.1448493368095822
#
# [ Train epoch: 19 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.46729792073369025
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.47749267041683197
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.6962363001704216
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.748158595263958
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.8744186732172966
#
# Total train accuarcy: 81.275
# Total train loss: 0.6527208319604397
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 70.0
# Test average loss: 1.21990847161838
#
# [ Train epoch: 20 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.6532659670710563
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.743758329153061
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.6763192912936211
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.6792983669042587
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.697708095908165
#
# Total train accuarcy: 79.65
# Total train loss: 0.6900700100660324
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 74.8
# Test average loss: 1.078078650174633
#
# [ Train epoch: 21 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.5071577413380146
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.5693321102857589
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.5337832693755626
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.5442049925029278
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.4972160134464502
#
# Total train accuarcy: 84.45
# Total train loss: 0.5303388253897429
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 73.7
# Test average loss: 1.1359195028032576
#
# [ Train epoch: 22 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.400826618373394
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.3051007501780987
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.3200524927675724
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.25880441419780253
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.3250095954164863
#
# Total train accuarcy: 90.775
# Total train loss: 0.3219587741866708
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 81.0
# Test average loss: 0.7631281021805036
#
# [ Train epoch: 23 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.18047005824744702
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.18427720615640283
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.1482527244463563
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.15295516481623053
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.13783928057178854
#
# Total train accuarcy: 95.65
# Total train loss: 0.16075888684764505
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 83.6
# Test average loss: 0.6329500402604776
#
# [ Train epoch: 24 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.09195516530424357
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.08552891966886818
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.08350387233309448
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.09035620281472802
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.07675407691858709
#
# Total train accuarcy: 97.825
# Total train loss: 0.08561964740790427
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 85.9
# Test average loss: 0.5861476533528831
#
# [ Train epoch: 25 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.060252652103081346
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.04172026184387505
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.054184778183698656
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.06000448767095804
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.0638765193708241
#
# Total train accuarcy: 98.85
# Total train loss: 0.05600773983448744
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 87.6
# Test average loss: 0.5527388600647332
#
# [ Train epoch: 26 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.053873682897537946
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.04802689716219902
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.07755180353298784
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.04993340970482677
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.051559965424239636
#
# Total train accuarcy: 98.575
# Total train loss: 0.05618915174435824
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 86.9
# Test average loss: 0.5526100355126555
#
# [ Train epoch: 27 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.05338875936344266
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.07269718495663255
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.06251576145645231
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.046044292636215685
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.06559561507776379
#
# Total train accuarcy: 98.6
# Total train loss: 0.060048322698101404
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 86.0
# Test average loss: 0.5931678831961656
#
# [ Train epoch: 28 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.07387677634134888
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.06663886878639459
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.09509850533213467
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.10533516133204103
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.15380719458684325
#
# Total train accuarcy: 97.6
# Total train loss: 0.09895130127575248
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 81.2
# Test average loss: 0.8188867411679692
#
# [ Train epoch: 29 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.18139948029071093
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.25127037972211835
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.3964666037261486
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.6225017816573382
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.7507609671354294
#
# Total train accuarcy: 86.725
# Total train loss: 0.4404798425063491
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 71.0
# Test average loss: 1.3340001787458147
#
# [ Train epoch: 30 ]
#
# Current batch: 50
# Average train loss of recent 50 batches: 0.6789977252483368
#
# Current batch: 100
# Average train loss of recent 50 batches: 0.4887020143866539
#
# Current batch: 150
# Average train loss of recent 50 batches: 0.5946182984113694
#
# Current batch: 200
# Average train loss of recent 50 batches: 0.5999740567803383
#
# Current batch: 250
# Average train loss of recent 50 batches: 0.5807558320462703
#
# Total train accuarcy: 82.675
# Total train loss: 0.5886095853745937
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 74.1
# Test average loss: 1.102479593739623

# %%
## 저장이 진행되었는지 확인해 보시고 성능 그래프를 그려주세요
plt.plot(range(num_epochs*2), seq_train_loss, label="Train loss")
plt.plot(range(num_epochs*2), seq_test_loss, label="Test loss")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
print('Minimum Loss Train :', max(seq_train_loss))
print('Minimum Loss Test :', max(seq_test_loss))
plt.show()
# Out:
# Minimum Loss Train : 3.8744125537872316
# Minimum Loss Test : 2.85910970067221

# %%
plt.plot(range(num_epochs*2), seq_train_acc, label="Train Accuracy")
plt.plot(range(num_epochs*2), seq_test_acc, label="Test Accuracy")
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.ylabel('Loss')
print('Maximum Accuracy Train :', max(seq_train_acc))
print('Maximum Accuracy Test :', max(seq_test_acc))
plt.show()
# Out:
# Maximum Accuracy Train : 98.85
# Maximum Accuracy Test : 87.6

# %% [markdown]
# 수고하셨습니다!
