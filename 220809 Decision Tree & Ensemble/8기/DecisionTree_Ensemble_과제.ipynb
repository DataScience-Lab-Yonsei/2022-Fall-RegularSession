# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from subprocess import check_call

# %%
# 트리 시각화를 위한 모듈 import
# !pip install pydot

import pydot
from IPython.core.display import Image
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pydot in /usr/local/lib/python3.7/dist-packages (1.3.0)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.7/dist-packages (from pydot) (3.0.9)

# %%
iris = load_iris()
x = iris.data[:,2:] 
y = iris.target

# %%
print(f" X features -> {iris.feature_names} \n target class -> {iris.target_names} ")
# Out:
#  X features -> ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#  target class -> ['setosa' 'versicolor' 'virginica']

# %%
# 과제[1] 무엇과 무엇을 x 와 y로 설정한 것같나요? 
#x 는 꽃입의 width 와 length 를 y는 꽃의 종류를 나타냅니다.

# %%
# 과제 [2] decision tree 모형 인스턴스 생성 및 하이퍼파라미터(depth) = 3
tree_model = DecisionTreeClassifier(max_depth = 3)
# 모델을 피팅해보세요 
tree_model.fit(x,y)

# 출력해보세요 
dot_data = export_graphviz(
    tree_model, # 학습한 모형
    out_file = None, # .dot 파일 저장 위치
    feature_names = iris.feature_names[2:], # 사용한 변수 이름
    class_names = iris.target_names, # 예측할 타겟 클래스 이름
    rounded=True, # 사각형 끝을 둥글게
    filled=True # 사각형 안 색깔 채우기
)
graph = pydot.graph_from_dot_data(dot_data)[0]
image = graph.create_png()
Image(image)

# %%
# 함수로 만듦
def draw_decision_tree(clf, feature_names = None, class_names = None):
    dot_data = export_graphviz(clf, out_file = None, 
                                feature_names = feature_names,
                                class_names = class_names,
                                filled = True, 
                                rounded = True,
                                special_characters = True)
    graph = pydot.graph_from_dot_data(dot_data)[0]
    image = graph.create_png()
    return Image(image)

draw_decision_tree(tree_model,iris.feature_names[2:], iris.target_names )

# %%
#[과제3] 학습시킨 모델에서 길이가 3.1, 너비가 2 인 데이터는 어떤 클래스로 분류될지 확률값을 구해보세요 
print(tree_model.predict_proba([[3.1, 2]]))
# Out:
# [[0.         0.33333333 0.66666667]]

# %%
from sklearn.datasets import load_breast_cancer # 유방암 데이터셋

X, y = load_breast_cancer(return_X_y=True)
feature_names = load_breast_cancer().feature_names
class_names = load_breast_cancer().target_names

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
tree_not_tuned= DecisionTreeClassifier(random_state=0)

# 과제[4] 학습데이터셋에만 피팅시켜봅시다
tree_not_tuned.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn.model_selection import cross_validate
import numpy as np
scoring = ['f1','precision','recall']

#과제 [5] 학습 데이터에 대해 교차검증하세요) 

tree_scores = cross_validate(tree_not_tuned, X_train, y_train, scoring=scoring, cv=5, return_train_score = False)

print("parameter가 tuning 되지 않았을 때의 F1 Score : {:.3f}".format(np.mean(tree_scores['test_f1'])))
# Out:
# parameter가 tuning 되지 않았을 때의 F1 Score : 0.923

# %% [markdown]
# max_depth : 트리 최대 깊이
#
# max_depth 감소 => 모델 규제 증가 => 과적합 감소 min_samples_split : 분할되기 위해 노드가 가져야 하는 최소 샘플 수
#
# min_samples_split 증가 => 모델 규제 증가 => 과적합 감소 min_samples_leaf : leaf node가 가지고 있어야할 최소 샘플 수
#
# min_samples_leaf 증가 => 모델 규제 증가 => 과적합 감소 min_weight_fraction_leaf : min_samples_leaf와 비슷하지만, 가중치가 부여된 전체 샘플 수에서의 비율
#
# min_weight_fraction_leaf 증가 => 모델 규제 증가 => 과적합 감소 max_leaf_nodes : leaf node의 총 최대 개수
#
# max_leaf_nodes 감소 => 모델 규제 증가 => 과적합 감소 max_features : 최상의 분할을 찾을 때 고려할 기능의 수
#
# max_features 감소 => 모델 규제 증가 => 과적합 감소
#
# TIP : min_으로 시작하는 매개변수 증가 => 모델 규제 증가 => 과적합 감소
# TIP : max_으로 시작하는 매개변수 감소 => 모델 규제 증가 => 과적합 감소

# %%
draw_decision_tree(tree_not_tuned ,feature_names, class_names )

# %%
#과제 [6] 어떻게 가지치기를 진행할 지 스스로 계획을 세우고 gridsearch를 통해 파라미터를 조정하여 다시  f1 score 를 구해봅시다!

# %%
tree_tuned = DecisionTreeClassifier(max_depth=7, min_samples_split=4, random_state=0)

# %%
# 테스트하고자 하는 파라미터 값들을 사전타입으로 정의
# 조절하고자 하는 하이퍼파라미터들을 지정 
from sklearn.model_selection import GridSearchCV

hyperparamters = {'max_depth': list(range(2, 8)),  'min_samples_split': list(range(2, 20))}

# GridSearch 진행
GridCV = GridSearchCV(estimator=tree_not_tuned, param_grid=hyperparamters, cv=5, verbose=1)

GridCV.fit(X_train, y_train)
GridCV.best_params_ # 가장 좋은 성능을 보였을 때의 parameter
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# {'max_depth': 7, 'min_samples_split': 4}

# %%
#과제 [7] 다시 모델의 f1스코어를 비교해보세요

# %%
from sklearn.model_selection import cross_validate
import numpy as np
scoring = ['f1','precision','recall']

tree_scores = cross_validate(tree_tuned, X_train, y_train, scoring=scoring, cv=5, return_train_score = False)

print("parameter가 tuning 됐을 때의 F1 Score : {:.3f}".format(np.mean(tree_scores['test_f1'])))
# Out:
# parameter가 tuning 됐을 때의 F1 Score : 0.935

# %%
# 과제[8] 계획과 해보신 결과에 대해서 말씀해주세요 
# gridsearch를 진행한 후 가장 좋은 성능을 보였을 때의 parameter가 max_depth=7, min_samples_split=4 라는 것을 알게 되었고 해당 parameter를 사용했을때의 점수가 더 높았다

# %%
#Ensemble Method

# %%
iris = load_iris()
X = iris.data[:,2:] # 꽃잎의 길이, 너비
Y = iris.target

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2021,shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
# 모델 선정하여

# %%
#Voting

# %%
# 데이터셋 로드
iris = load_iris()
X = iris.data[:,2:] # 꽃잎의 길이, 너비
Y = iris.target
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2021,shuffle=True)

# 약한 학습기 구축
log_model = LogisticRegression() # 로지스틱회귀
rnd_model = RandomForestClassifier() #랜덤포레스트분류
svm_model = SVC() # 서포트벡터머신 
#밑에 약한학습기를 더 추가해보세요  import 하신후!

# %%
#과제 - 약한 학습기 추가로 구축해보세요! 위에 인자참고해서! 
# gradient boost, xgboost, 
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
voting_model = VotingClassifier(
    estimators=[('lr',log_model),('rf',rnd_model),('svc',svm_model),('xgb', XGBClassifier()) ], # 3개의 약한 학습기 외 한 개 더 추가해보세요 
    voting='hard' # 직접 투표(hard voting)
)

# %%
# 앙상블 모델 학습
voting_model.fit(x_train,y_train)


# 모델 비교
for model in (log_model,rnd_model,svm_model,voting_model) : 
  model.fit(x_train,y_train) #각각의 모델에 대하여 트레인 데이터 피팅 
  y_pred = model.predict(x_test)  # 예측값 
  print(model.__class__.__name__," : ",accuracy_score(y_test,y_pred))
# Out:
# LogisticRegression  :  1.0
# RandomForestClassifier  :  0.9333333333333333
# SVC  :  1.0
# VotingClassifier  :  0.9333333333333333

# %%
#내용 정리 과제

# %%
#배깅

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# 모델 구축
# BaggingClassifier에서 사용한 분류기가 클래스 확률추정(predict_proba)이 가능하면 자동으로 간접 투표 사용 
bag_model = BaggingClassifier(
    DecisionTreeClassifier(), # 약한 학습기(결정 트리)
    n_estimators=500, # 약한 학습기(결정 트리) 500개 생성
    max_samples=0.05, # 0.0~1.0 사이 실수 선택(실수 x 샘플 수) 혹은 샘플수 지정
    bootstrap=True, # True : 배깅, False : 페이스팅
    n_jobs=-1 # 훈련과 예측에 사용할 CPU 코어 수 (-1 : 가용한 모든 코어 사용)
)

# 모델 학습
bag_model.fit(x_train,y_train)

# 모델 예측
y_pred = bag_model.predict(x_test)

# 모델 평가
print(bag_model.__class__.__name__," : ",accuracy_score(y_test,y_pred))
# Out:
# BaggingClassifier  :  0.9555555555555556

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 모델 구축
bag_model = BaggingClassifier(
    base_estimator = DecisionTreeClassifier(),
    n_estimators = 500,
    bootstrap = True,
    n_jobs = -1,
    oob_score = True # oob평가를 위해 True를 지정한다.
)

# 모델 학습
bag_model.fit(x_train,y_train)

# 모델 평가(oob_score_)
print('oob_score : ',bag_model.oob_score_)

# 모델 평가
y_pred = bag_model.predict(x_test)
print('test_score : ',accuracy_score(y_test,y_pred))
# Out:
# oob_score :  0.9523809523809523
# test_score :  0.9333333333333333

# %%
#배깅-RandomForest

# %%
#랜덤 포레스트의 특징 : bootstrap 으로 뽑는다, 변수중요도를 구할 수 있다.

# %%
from sklearn.ensemble import RandomForestClassifier

# 랜덤포레스트 모델 구축
rnd_model = RandomForestClassifier(
    n_estimators = 500, # 예측기 500개
    max_leaf_nodes = 16, # 자식노드의 최대 개수 
    n_jobs = -1 # CPU 코어 구동 개수
)

# 모델 학습
rnd_model.fit(x_train,y_train)

# 모델 예측
y_pred_rf = rnd_model.predict(x_test)

# 모델 평가
print("rnd_model : ",accuracy_score(y_pred_rf,y_test))
# Out:
# rnd_model :  0.9333333333333333

# %%
#변수중요도 확인

# %%
#데이터셋 정의
x = iris.data[:,:]
y = iris.target

# 모델 구축
rnd_model = RandomForestClassifier(
    n_estimators = 500,
    n_jobs = -1
)

# 모델 학습
rnd_model.fit(x,y)

# 특성 중요도 확인 (전체 특성 중요도 합 : 1)
for feature_name,feature_imp in zip(iris['feature_names'],rnd_model.feature_importances_):
  print(feature_name,' : ',feature_imp)
# Out:
# sepal length (cm)  :  0.08976703507930597
# sepal width (cm)  :  0.025396779229092625
# petal length (cm)  :  0.4647587033568913
# petal width (cm)  :  0.42007748233471015

# %%
#부스팅

# %%
#AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
# 아다부스트 모델 구축
# 아다부스트의 학습기 : Decision Tree (max_depth =1) 사용
# 학습기 개수(n_estimators) : 200개
# SAMME(Stagewise Additive Modeling using a Multiclass Exponential loss function) 알고리즘 사용
# 기본 학습기가 확률 추정(predict_proba)이 가능하면 SAMME.R 사용 -> 일반적으로 성능이 더 좋음
ada_model = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1),
    n_estimators = 200,
    algorithm = 'SAMME.R',
    learning_rate=0.5
)

# 모델 학습
ada_model.fit(x,y)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    learning_rate=0.5, n_estimators=200)

# %%
#과제! adaboost 에 특징, 장점을 1~2 문장으로 정리해주세요

#특징: 약한 분류기의 실수를 통해 가중치를 반복적으로 수정하고 결합하여 정확도를 높일 수 있다.

#장점: 과적합 현상이 적게 발생한다

# %%
#Gradient Boost

# %%
from sklearn.tree import DecisionTreeRegressor

# 결정트리(max_depth=3) 모델 구축 및 학습
tree_reg_model_1 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_1.fit(x,y)

# 첫 번째 학습기에서 발생한 잔차를 목적함수로 모델 학습
residual_1 = y - tree_reg_model_1.predict(x)
tree_reg_model_2 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_2.fit(x,residual_1)

# 두 번째 학습기에서 발생한 잔차를 목적함수로 모델 학습
residual_2 = y - tree_reg_model_2.predict(x)
tree_reg_model_3 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_3.fit(x,residual_2)

# 새로운 데이터를 세 개의 트리를 포함한 앙상블 모델로 예측
x_new = [[1,4,0,2]]
prediction = sum(tree.predict(x_new) for tree in [tree_reg_model_1,tree_reg_model_2,tree_reg_model_3])
prediction
# Out:
# array([3.31686315])

# %%
#XGBoost

# %%
# 과제 !! XGboost 의 장점을 적어주세요

#이곳에 적어주세요: 병렬 처리를 사용하기에 학습과 분류가 빠르다, 과적합 문제가 적게 발생한다

# %%
import xgboost as xgb
from xgboost import XGBClassifier,XGBRegressor
from xgboost import plot_importance, plot_tree

# %%
from sklearn.datasets import load_breast_cancer

cancer= load_breast_cancer()
X_train, X_test , y_train, y_test = train_test_split(cancer.data, cancer.target,test_size=0.2,random_state=100)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test,label=y_test)

# %%
params = {
    'max_depth' :3 ,
    'eta' : 0.1,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'early_stopping' : 100,
    }
num_rounds=400

# %%
evals = [(dtrain,'train'),(dtest,'eval')]
xgb_model = xgb.train(params=params, dtrain=dtrain ,num_boost_round=num_rounds , early_stopping_rounds=100,evals=evals)
# Out:
# [0]	train-logloss:0.611569	eval-logloss:0.614598
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 100 rounds.
# [1]	train-logloss:0.544594	eval-logloss:0.554049
# [2]	train-logloss:0.4876	eval-logloss:0.498159
# [3]	train-logloss:0.436129	eval-logloss:0.448575
# [4]	train-logloss:0.394107	eval-logloss:0.40558
# [5]	train-logloss:0.356997	eval-logloss:0.372269
# [6]	train-logloss:0.323699	eval-logloss:0.341755
# [7]	train-logloss:0.294408	eval-logloss:0.316994
# [8]	train-logloss:0.268226	eval-logloss:0.291993
# [9]	train-logloss:0.245414	eval-logloss:0.273857
# [10]	train-logloss:0.225645	eval-logloss:0.254903
# [11]	train-logloss:0.207281	eval-logloss:0.238183
# [12]	train-logloss:0.190892	eval-logloss:0.225766
# [13]	train-logloss:0.176111	eval-logloss:0.212247
# [14]	train-logloss:0.163481	eval-logloss:0.201563
# [15]	train-logloss:0.151433	eval-logloss:0.192508
# [16]	train-logloss:0.141237	eval-logloss:0.182921
# [17]	train-logloss:0.131224	eval-logloss:0.176626
# [18]	train-logloss:0.122331	eval-logloss:0.170079
# [19]	train-logloss:0.114253	eval-logloss:0.162605
# [20]	train-logloss:0.106397	eval-logloss:0.157468
# [21]	train-logloss:0.099816	eval-logloss:0.152077
# [22]	train-logloss:0.094125	eval-logloss:0.148772
# [23]	train-logloss:0.088159	eval-logloss:0.146092
# [24]	train-logloss:0.083245	eval-logloss:0.144648
# [25]	train-logloss:0.078335	eval-logloss:0.142152
# [26]	train-logloss:0.074272	eval-logloss:0.138255
# [27]	train-logloss:0.070047	eval-logloss:0.135347
# [28]	train-logloss:0.066396	eval-logloss:0.132442
# [29]	train-logloss:0.063278	eval-logloss:0.129682
# [30]	train-logloss:0.060048	eval-logloss:0.126792
# [31]	train-logloss:0.057121	eval-logloss:0.12401
# [32]	train-logloss:0.054504	eval-logloss:0.122137
# [33]	train-logloss:0.052006	eval-logloss:0.120047
# [34]	train-logloss:0.049698	eval-logloss:0.117785
# [35]	train-logloss:0.047541	eval-logloss:0.11656
# [36]	train-logloss:0.045745	eval-logloss:0.114709
# [37]	train-logloss:0.043992	eval-logloss:0.113895
# [38]	train-logloss:0.042299	eval-logloss:0.111723
# [39]	train-logloss:0.040586	eval-logloss:0.110535
# [40]	train-logloss:0.039008	eval-logloss:0.111139
# [41]	train-logloss:0.03754	eval-logloss:0.1092
# [42]	train-logloss:0.036231	eval-logloss:0.107939
# [43]	train-logloss:0.034976	eval-logloss:0.107025
# [44]	train-logloss:0.033717	eval-logloss:0.106866
# [45]	train-logloss:0.03272	eval-logloss:0.106075
# [46]	train-logloss:0.03163	eval-logloss:0.105603
# [47]	train-logloss:0.030611	eval-logloss:0.104641
# [48]	train-logloss:0.029601	eval-logloss:0.103648
# [49]	train-logloss:0.028755	eval-logloss:0.102382
# [50]	train-logloss:0.0279	eval-logloss:0.10204
# [51]	train-logloss:0.027084	eval-logloss:0.102195
# [52]	train-logloss:0.026345	eval-logloss:0.101968
# [53]	train-logloss:0.025633	eval-logloss:0.101812
# [54]	train-logloss:0.02499	eval-logloss:0.102173
# [55]	train-logloss:0.02436	eval-logloss:0.102473
# [56]	train-logloss:0.023879	eval-logloss:0.103182
# [57]	train-logloss:0.02332	eval-logloss:0.102991
# [58]	train-logloss:0.022769	eval-logloss:0.102624
# [59]	train-logloss:0.02228	eval-logloss:0.101846
# [60]	train-logloss:0.021755	eval-logloss:0.102817
# [61]	train-logloss:0.02121	eval-logloss:0.102745
# [62]	train-logloss:0.020723	eval-logloss:0.102571
# [63]	train-logloss:0.020127	eval-logloss:0.100636
# [64]	train-logloss:0.019584	eval-logloss:0.100556
# [65]	train-logloss:0.01911	eval-logloss:0.100086
# [66]	train-logloss:0.018664	eval-logloss:0.099822
# [67]	train-logloss:0.018376	eval-logloss:0.100187
# [68]	train-logloss:0.017977	eval-logloss:0.100486
# [69]	train-logloss:0.017614	eval-logloss:0.100378
# [70]	train-logloss:0.017241	eval-logloss:0.100403
# [71]	train-logloss:0.016916	eval-logloss:0.100303
# [72]	train-logloss:0.016536	eval-logloss:0.099212
# [73]	train-logloss:0.016212	eval-logloss:0.099419
# [74]	train-logloss:0.015863	eval-logloss:0.099056
# [75]	train-logloss:0.015681	eval-logloss:0.098983
# [76]	train-logloss:0.015464	eval-logloss:0.099329
# [77]	train-logloss:0.015259	eval-logloss:0.099663
# [78]	train-logloss:0.015	eval-logloss:0.099819
# [79]	train-logloss:0.014742	eval-logloss:0.099543
# [80]	train-logloss:0.014465	eval-logloss:0.09848
# [81]	train-logloss:0.014266	eval-logloss:0.098061
# [82]	train-logloss:0.014063	eval-logloss:0.097752
# [83]	train-logloss:0.013842	eval-logloss:0.097286
# [84]	train-logloss:0.013708	eval-logloss:0.096727
# [85]	train-logloss:0.013543	eval-logloss:0.097299
# [86]	train-logloss:0.013419	eval-logloss:0.097138
# [87]	train-logloss:0.013257	eval-logloss:0.097446
# [88]	train-logloss:0.013112	eval-logloss:0.097447
# [89]	train-logloss:0.012946	eval-logloss:0.096487
# [90]	train-logloss:0.012763	eval-logloss:0.096455
# [91]	train-logloss:0.012567	eval-logloss:0.095877
# [92]	train-logloss:0.012457	eval-logloss:0.095384
# [93]	train-logloss:0.01222	eval-logloss:0.095125
# [94]	train-logloss:0.012117	eval-logloss:0.094997
# [95]	train-logloss:0.012014	eval-logloss:0.095239
# [96]	train-logloss:0.011895	eval-logloss:0.095267
# [97]	train-logloss:0.011795	eval-logloss:0.094795
# [98]	train-logloss:0.011634	eval-logloss:0.094311
# [99]	train-logloss:0.011513	eval-logloss:0.094597
# [100]	train-logloss:0.011403	eval-logloss:0.094262
# [101]	train-logloss:0.011307	eval-logloss:0.093695
# [102]	train-logloss:0.011215	eval-logloss:0.093494
# [103]	train-logloss:0.011128	eval-logloss:0.094031
# [104]	train-logloss:0.011046	eval-logloss:0.093849
# [105]	train-logloss:0.010955	eval-logloss:0.094066
# [106]	train-logloss:0.010873	eval-logloss:0.094294
# [107]	train-logloss:0.010757	eval-logloss:0.093978
# [108]	train-logloss:0.010677	eval-logloss:0.093558
# [109]	train-logloss:0.010594	eval-logloss:0.093034
# [110]	train-logloss:0.01051	eval-logloss:0.093289
# [111]	train-logloss:0.010434	eval-logloss:0.093201
# [112]	train-logloss:0.010356	eval-logloss:0.093417
# [113]	train-logloss:0.010283	eval-logloss:0.093914
# [114]	train-logloss:0.010207	eval-logloss:0.093497
# [115]	train-logloss:0.010116	eval-logloss:0.093202
# [116]	train-logloss:0.010047	eval-logloss:0.093421
# [117]	train-logloss:0.009977	eval-logloss:0.093251
# [118]	train-logloss:0.00991	eval-logloss:0.093903
# [119]	train-logloss:0.009856	eval-logloss:0.093756
# [120]	train-logloss:0.00978	eval-logloss:0.094008
# [121]	train-logloss:0.009719	eval-logloss:0.093842
# [122]	train-logloss:0.009652	eval-logloss:0.093359
# [123]	train-logloss:0.009585	eval-logloss:0.092967
# [124]	train-logloss:0.009499	eval-logloss:0.092615
# [125]	train-logloss:0.009438	eval-logloss:0.092829
# [126]	train-logloss:0.00937	eval-logloss:0.093077
# [127]	train-logloss:0.00932	eval-logloss:0.092897
# [128]	train-logloss:0.009259	eval-logloss:0.092825
# [129]	train-logloss:0.0092	eval-logloss:0.093458
# [130]	train-logloss:0.009141	eval-logloss:0.093083
# [131]	train-logloss:0.009085	eval-logloss:0.092778
# [132]	train-logloss:0.009029	eval-logloss:0.092995
# [133]	train-logloss:0.008977	eval-logloss:0.093233
# [134]	train-logloss:0.008933	eval-logloss:0.093119
# [135]	train-logloss:0.008879	eval-logloss:0.093574
# [136]	train-logloss:0.008823	eval-logloss:0.093213
# [137]	train-logloss:0.008796	eval-logloss:0.092938
# [138]	train-logloss:0.008718	eval-logloss:0.092643
# [139]	train-logloss:0.00867	eval-logloss:0.092846
# [140]	train-logloss:0.008619	eval-logloss:0.092712
# [141]	train-logloss:0.008569	eval-logloss:0.093318
# [142]	train-logloss:0.008518	eval-logloss:0.092969
# [143]	train-logloss:0.008473	eval-logloss:0.093209
# [144]	train-logloss:0.008421	eval-logloss:0.092769
# [145]	train-logloss:0.00835	eval-logloss:0.092488
# [146]	train-logloss:0.008306	eval-logloss:0.092776
# [147]	train-logloss:0.008281	eval-logloss:0.092513
# [148]	train-logloss:0.008239	eval-logloss:0.09273
# [149]	train-logloss:0.008216	eval-logloss:0.092895
# [150]	train-logloss:0.008171	eval-logloss:0.09293
# [151]	train-logloss:0.008148	eval-logloss:0.092806
# [152]	train-logloss:0.008126	eval-logloss:0.092956
# [153]	train-logloss:0.008083	eval-logloss:0.093243
# [154]	train-logloss:0.008007	eval-logloss:0.093157
# [155]	train-logloss:0.007985	eval-logloss:0.092913
# [156]	train-logloss:0.007946	eval-logloss:0.093114
# [157]	train-logloss:0.007901	eval-logloss:0.092769
# [158]	train-logloss:0.00786	eval-logloss:0.092708
# [159]	train-logloss:0.007817	eval-logloss:0.09329
# [160]	train-logloss:0.007758	eval-logloss:0.093025
# [161]	train-logloss:0.007693	eval-logloss:0.092953
# [162]	train-logloss:0.007672	eval-logloss:0.092717
# [163]	train-logloss:0.007639	eval-logloss:0.092941
# [164]	train-logloss:0.007602	eval-logloss:0.093517
# [165]	train-logloss:0.007582	eval-logloss:0.093398
# [166]	train-logloss:0.007564	eval-logloss:0.093174
# [167]	train-logloss:0.007534	eval-logloss:0.093209
# [168]	train-logloss:0.007516	eval-logloss:0.093065
# [169]	train-logloss:0.007484	eval-logloss:0.093324
# [170]	train-logloss:0.007466	eval-logloss:0.093484
# [171]	train-logloss:0.007449	eval-logloss:0.093272
# [172]	train-logloss:0.007432	eval-logloss:0.093132
# [173]	train-logloss:0.007407	eval-logloss:0.093322
# [174]	train-logloss:0.00739	eval-logloss:0.093214
# [175]	train-logloss:0.007373	eval-logloss:0.093373
# [176]	train-logloss:0.007357	eval-logloss:0.093312
# [177]	train-logloss:0.00734	eval-logloss:0.093524
# [178]	train-logloss:0.007324	eval-logloss:0.09332
# [179]	train-logloss:0.007307	eval-logloss:0.09318
# [180]	train-logloss:0.007284	eval-logloss:0.093382
# [181]	train-logloss:0.007268	eval-logloss:0.093277
# [182]	train-logloss:0.007253	eval-logloss:0.093116
# [183]	train-logloss:0.007237	eval-logloss:0.093272
# [184]	train-logloss:0.007221	eval-logloss:0.093564
# [185]	train-logloss:0.007205	eval-logloss:0.09336
# [186]	train-logloss:0.00719	eval-logloss:0.093222
# [187]	train-logloss:0.007175	eval-logloss:0.093427
# [188]	train-logloss:0.00716	eval-logloss:0.093581
# [189]	train-logloss:0.007145	eval-logloss:0.09342
# [190]	train-logloss:0.00713	eval-logloss:0.093222
# [191]	train-logloss:0.007115	eval-logloss:0.093441
# [192]	train-logloss:0.007101	eval-logloss:0.09334
# [193]	train-logloss:0.007086	eval-logloss:0.093482
# [194]	train-logloss:0.007072	eval-logloss:0.093322
# [195]	train-logloss:0.007057	eval-logloss:0.093131
# [196]	train-logloss:0.007043	eval-logloss:0.093071
# [197]	train-logloss:0.007029	eval-logloss:0.09327
# [198]	train-logloss:0.007015	eval-logloss:0.093131
# [199]	train-logloss:0.007001	eval-logloss:0.093285
# [200]	train-logloss:0.006987	eval-logloss:0.093563
# [201]	train-logloss:0.006973	eval-logloss:0.093378
# [202]	train-logloss:0.006959	eval-logloss:0.093218
# [203]	train-logloss:0.006946	eval-logloss:0.093355
# [204]	train-logloss:0.006932	eval-logloss:0.093254
# [205]	train-logloss:0.006919	eval-logloss:0.093117
# [206]	train-logloss:0.006905	eval-logloss:0.093114
# [207]	train-logloss:0.006892	eval-logloss:0.093388
# [208]	train-logloss:0.006879	eval-logloss:0.093207
# [209]	train-logloss:0.006866	eval-logloss:0.09305
# [210]	train-logloss:0.006853	eval-logloss:0.0932
# [211]	train-logloss:0.00684	eval-logloss:0.093102
# [212]	train-logloss:0.006828	eval-logloss:0.093367
# [213]	train-logloss:0.006815	eval-logloss:0.093513
# [214]	train-logloss:0.006802	eval-logloss:0.093358
# [215]	train-logloss:0.00679	eval-logloss:0.093177
# [216]	train-logloss:0.006777	eval-logloss:0.093038
# [217]	train-logloss:0.006765	eval-logloss:0.093229
# [218]	train-logloss:0.006752	eval-logloss:0.093364
# [219]	train-logloss:0.006741	eval-logloss:0.093215
# [220]	train-logloss:0.006728	eval-logloss:0.093039
# [221]	train-logloss:0.006716	eval-logloss:0.093299
# [222]	train-logloss:0.006705	eval-logloss:0.093444
# [223]	train-logloss:0.006693	eval-logloss:0.093347
# [224]	train-logloss:0.006681	eval-logloss:0.09321
# [225]	train-logloss:0.006669	eval-logloss:0.093043
# [226]	train-logloss:0.006658	eval-logloss:0.092894
# [227]	train-logloss:0.006646	eval-logloss:0.093029
# [228]	train-logloss:0.006635	eval-logloss:0.092885
# [229]	train-logloss:0.006624	eval-logloss:0.092718
# [230]	train-logloss:0.006613	eval-logloss:0.092862
# [231]	train-logloss:0.006601	eval-logloss:0.092728
# [232]	train-logloss:0.00659	eval-logloss:0.092912
# [233]	train-logloss:0.006579	eval-logloss:0.093167
# [234]	train-logloss:0.006569	eval-logloss:0.093077
# [235]	train-logloss:0.006558	eval-logloss:0.093222
# [236]	train-logloss:0.006547	eval-logloss:0.093081
# [237]	train-logloss:0.006536	eval-logloss:0.092917
# [238]	train-logloss:0.006526	eval-logloss:0.093048
# [239]	train-logloss:0.006515	eval-logloss:0.092915
# [240]	train-logloss:0.006505	eval-logloss:0.093164
# [241]	train-logloss:0.006495	eval-logloss:0.093007
# [242]	train-logloss:0.006484	eval-logloss:0.092866
# [243]	train-logloss:0.006474	eval-logloss:0.093008
# [244]	train-logloss:0.006464	eval-logloss:0.092919
# [245]	train-logloss:0.006454	eval-logloss:0.092919
# Stopping. Best iteration:
# [145]	train-logloss:0.00835	eval-logloss:0.092488

# %%
predicts = xgb_model.predict(dtest)
print(np.round(predicts[:10],3))
# Out:
# [0.    0.916 0.013 1.    0.997 0.997 0.014 0.    0.994 0.989]

# %%
import matplotlib.pyplot as plt

# %%
#변수간 중요도 확인

# %%
fig ,ax =plt.subplots(figsize=(10,12))
plot_importance(xgb_model , ax=ax)
