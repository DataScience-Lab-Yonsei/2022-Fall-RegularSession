# %% [markdown]
# #라이브러리 import
# - 참조코드
#
#
# 1.   https://velog.io/@changhtun1/Python-Decision-Tree-%EC%9D%B4%EB%A1%A0-%EB%B0%8F-%EC%8B%A4%EC%8A%B5
# 2.   https://velog.io/@changhtun1/ensemble
# 3.  https://www.youtube.com/watch?v=4Jz4_IOgS4c

# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
from subprocess import check_call

# %%
# 트리 시각화를 위한 모듈 import
# !pip install pydot

import pydot
from IPython.core.display import Image

# %% [markdown]
# ## iris 붖꽃데이터를 사용합니다

# %%
iris = load_iris()
x = iris.data[:,2:] 
y = iris.target

# %%
print(f" X features -> {iris.feature_names} \n target class -> {iris.target_names} ")
# Out:
#  X features -> ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#  target class -> ['setosa' 'versicolor' 'virginica']

# %% [markdown]
# # 과제[1] 무엇과 무엇을 x 와 y로 설정한 것같나요?
#
# x는 petal의 길이와 넓이를 사용하고, y는 iris의 종류에 해당한다.

# %% [markdown]
# ## Model 생성 의사결정트리 분류모델

# %%
# 과제 [2] decision tree 모형 인스턴스 생성 및 하이퍼파라미터(depth) = 3
tree_model =  DecisionTreeClassifier(max_depth=3)
# 모델을 피팅해보세요 
tree_model.fit(x,y)

# 출력해보세요 
dot_data = export_graphviz(
    tree_model, # 학습한 모형
    out_file = None, # .dot 파일 저장 위치
    feature_names = iris.feature_names[2:], # 사용한 변수 이름
    class_names = iris.target_names, # 예측할 타겟 클래스 이름
    rounded=True, # 사각형 끝을 둥글게
    filled=True # 사각형 안 색깔 채우기
)
graph = pydot.graph_from_dot_data(dot_data)[0]
image = graph.create_png()
Image(image)

# %%
# 함수로 만듦
def draw_decision_tree(clf, feature_names = None, class_names = None):
    dot_data = export_graphviz(clf, out_file = None, 
                                feature_names = feature_names,
                                class_names = class_names,
                                filled = True, 
                                rounded = True,
                                special_characters = True)
    graph = pydot.graph_from_dot_data(dot_data)[0]
    image = graph.create_png()
    return Image(image)

draw_decision_tree(tree_model,iris.feature_names[2:], iris.target_names )

# %%
#[과제3] 학습시킨 모델에서 길이가 3.1, 너비가 2 인 데이터는 어떤 클래스로 분류될지 확률값을 구해보세요 

tree_model.predict_proba([[3.1, 2]])
# Out:
# array([[0.        , 0.33333333, 0.66666667]])

# %% [markdown]
# ##가지치기

# %%
from sklearn.datasets import load_breast_cancer # 유방암 데이터셋

X, y = load_breast_cancer(return_X_y=True)
feature_names = load_breast_cancer().feature_names
class_names = load_breast_cancer().target_names

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

# %%
tree_not_tuned= DecisionTreeClassifier(random_state=0)

# 과제[4] 학습데이터셋에만 피팅시켜봅시다
tree_not_tuned.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn.model_selection import cross_validate
import numpy as np
scoring = ['f1','precision','recall']

#과제 [5] 학습 데이터에 대해 교차검증하세요) 

tree_scores = cross_validate(tree_not_tuned, X_train, y_train, scoring=scoring)

print("parameter가 tuning 되지 않았을 때의 F1 Score : {:.3f}".format(np.mean(tree_scores['test_f1'])))
# Out:
# parameter가 tuning 되지 않았을 때의 F1 Score : 0.923

# %% [markdown]
# max_depth : 트리 최대 깊이
#
# max_depth 감소 => 모델 규제 증가 => 과적합 감소
# min_samples_split : 분할되기 위해 노드가 가져야 하는 최소 샘플 수
#
# min_samples_split 증가 => 모델 규제 증가 => 과적합 감소
# min_samples_leaf : leaf node가 가지고 있어야할 최소 샘플 수
#
# min_samples_leaf 증가 => 모델 규제 증가 => 과적합 감소
# min_weight_fraction_leaf : min_samples_leaf와 비슷하지만, 가중치가 부여된 전체 샘플 수에서의 비율
#
# min_weight_fraction_leaf 증가 => 모델 규제 증가 => 과적합 감소
# max_leaf_nodes : leaf node의 총 최대 개수
#
# max_leaf_nodes 감소 => 모델 규제 증가 => 과적합 감소
# max_features : 최상의 분할을 찾을 때 고려할 기능의 수
#
# max_features 감소 => 모델 규제 증가 => 과적합 감소

# %% [markdown]
# ```
# TIP : min_으로 시작하는 매개변수 증가 => 모델 규제 증가 => 과적합 감소
# TIP : max_으로 시작하는 매개변수 감소 => 모델 규제 증가 => 과적합 감소
# ```

# %%
draw_decision_tree(tree_not_tuned ,feature_names, class_names )

# %% [markdown]
# #과제 [6] 어떻게 가지치기를 진행할 지 스스로 계획을 세우고 gridsearch를 통해 파라미터를 조정하여 다시  f1 score 를 구해봅시다!
#
# 지금 비슷한 feature가 여러번 사용되면서 분기되기 때문에 leaf가 많아진다고 봐서 max_leaf_nodes를 조절하고, min_samples_split으로 자주 나눠지지 않도록 한다.

# %%
from sklearn.model_selection import GridSearchCV

# %%
tree_tuned = DecisionTreeClassifier()

# %%
# 테스트하고자 하는 파라미터 값들을 사전타입으로 정의
# 조절하고자 하는 하이퍼파라미터들을 지정 
hyperparamters = {'max_leaf_nodes': list(range(2, 8)),  'min_samples_split': list(range(2, 20))}

# GridSearch 진행
GridCV = GridSearchCV(estimator=tree_not_tuned, param_grid=hyperparamters, cv=5, verbose=1)

GridCV.fit(X_train, y_train)
GridCV.best_params_ # 가장 좋은 성능을 보였을 때의 parameter
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# {'max_leaf_nodes': 5, 'min_samples_split': 18}

# %%
#과제 [7] 다시 모델의 f1스코어를 비교해보세요

# %%
from sklearn.model_selection import cross_validate
import numpy as np
scoring = ['f1','precision','recall']
#
tree_scores = cross_validate(tree_tuned, X_train, y_train, scoring=scoring)

print("parameter가 tuning 됐을 때의 F1 Score : {:.3f}".format(np.mean(tree_scores['test_f1'])))
# Out:
# parameter가 tuning 됐을 때의 F1 Score : 0.934

# %% [markdown]
# 과제[8] 계획과 해보신 결과에 대해서 말씀해주세요
#
# F1 score가 0.923보다 개선된 0.934이기 때문에 실제로 최적의 값을 찾았고 그것이 성능 개선으로 이어진 것으로 보인다.

# %% [markdown]
# #Ensemble Method

# %%
iris = load_iris()
X = iris.data[:,2:] # 꽃잎의 길이, 너비
Y = iris.target

from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2021,shuffle=True)

# %%
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
# 모델 선정하여

# %% [markdown]
# ##voting

# %%
# 데이터셋 로드
iris = load_iris()
X = iris.data[:,2:] # 꽃잎의 길이, 너비
Y = iris.target
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.3,random_state=2021,shuffle=True)

# 약한 학습기 구축
log_model = LogisticRegression() # 로지스틱회귀
rnd_model = RandomForestClassifier() #랜덤포레스트분류
svm_model = SVC() # 서포트벡터머신 
#밑에 약한학습기를 더 추가해보세요  import 하신후!

# %% [markdown]
# ```
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, ExtraTreesClassifier, BaggingClassifier, GradientBoostingClassifier
# from sklearn.svm import SVC
# from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
# from sklearn.neighbors import KNeighborsClassifier
# from sklearn.linear_model import LogisticRegressionCV, RidgeClassifier
# # VotingClassifier
# from sklearn.ensemble import VotingClassifier
#
# # ensemble 할 model 정의
# models = [
#     ('ada', AdaBoostClassifier()),
#     ('bc', BaggingClassifier()),
#     ('etc',ExtraTreesClassifier()),
#     ('gbc', GradientBoostingClassifier()),
#     ('rfc', RandomForestClassifier()),
#     ('knn', KNeighborsClassifier()),
#     ('svc', SVC(probability=True)),
#     ('xgb', XGBClassifier()),
#     ('lgbm', LGBMClassifier()),
#     ('dtc', DecisionTreeClassifier()),
#     ('lr', LogisticRegressionCV()),
#     ('ridge', RidgeClassifier()),
# ]
# ```

# %% [markdown]
# ```
# # 앙상블 모델 구축
# # 만약에 모든 모델이 predict_proba() 메서드가 있으면, 예측의 평균을 내어 soft voting(간접 투표)도 할수 있다.
# # 간접 투표 방식은 확률이 높은 투표에 비중을 두기 때문에 성능이 더 높다. (voting='soft' 사용)
# # svc는 기본적으로 predict_proba를 제공하지 않아, probability = True 지정 해야 사용 가능
# # 대신 svc에서 probability = True를 지정하면 교차 검증을 사용해서 확률을 추정하기 때문에 훈련 속도 느려짐
# # 대신 성능을 올라감
# ```

# %%
#과제 - 약한 학습기 추가로 구축해보세요! 위에 인자참고해서! 
# gradient boost, xgboost, 
from sklearn.neighbors import KNeighborsClassifier

kn_model = KNeighborsClassifier()

# %%
voting_model = VotingClassifier(
    estimators=[('lr',log_model),('rf',rnd_model),('svc',svm_model) ,('kn', kn_model)], # 3개의 약한 학습기 외 한 개 더 추가해보세요 
    voting='hard' # 직접 투표(hard voting)
)

# %%
# 앙상블 모델 학습
voting_model.fit(x_train,y_train)


# 모델 비교
for model in (log_model,rnd_model,svm_model,voting_model) : 
  model.fit(x_train,y_train) #각각의 모델에 대하여 트레인 데이터 피팅 
  y_pred = model.predict(x_test)  # 예측값 
  print(model.__class__.__name__," : ",accuracy_score(y_test,y_pred))
# Out:
# LogisticRegression  :  1.0
# RandomForestClassifier  :  0.9555555555555556
# SVC  :  1.0
# VotingClassifier  :  0.9777777777777777

# %% [markdown]
# #---- 아래로 부터는 내용정리 과제입니다---

# %% [markdown]
# ##배깅

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# 모델 구축
# BaggingClassifier에서 사용한 분류기가 클래스 확률추정(predict_proba)이 가능하면 자동으로 간접 투표 사용 
bag_model = BaggingClassifier(
    DecisionTreeClassifier(), # 약한 학습기(결정 트리)
    n_estimators=500, # 약한 학습기(결정 트리) 500개 생성
    max_samples=0.05, # 0.0~1.0 사이 실수 선택(실수 x 샘플 수) 혹은 샘플수 지정
    bootstrap=True, # True : 배깅, False : 페이스팅
    n_jobs=-1 # 훈련과 예측에 사용할 CPU 코어 수 (-1 : 가용한 모든 코어 사용)
)

# 모델 학습
bag_model.fit(x_train,y_train)

# 모델 예측
y_pred = bag_model.predict(x_test)

# 모델 평가
print(bag_model.__class__.__name__," : ",accuracy_score(y_test,y_pred))
# Out:
# BaggingClassifier  :  0.9777777777777777

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 모델 구축
bag_model = BaggingClassifier(
    base_estimator = DecisionTreeClassifier(),
    n_estimators = 500,
    bootstrap = True,
    n_jobs = -1,
    oob_score = True # oob평가를 위해 True를 지정한다.
)

# 모델 학습
bag_model.fit(x_train,y_train)

# 모델 평가(oob_score_)
print('oob_score : ',bag_model.oob_score_)

# 모델 평가
y_pred = bag_model.predict(x_test)
print('test_score : ',accuracy_score(y_test,y_pred))
# Out:
# oob_score :  0.9523809523809523
# test_score :  0.9555555555555556

# %% [markdown]
# ##배깅- RandomForest

# %% [markdown]
# ###랜덤 포레스트의 특징 : bootstrap 으로 뽑는다, 변수중요도를 구할 수 있다.

# %%
from sklearn.ensemble import RandomForestClassifier

# 랜덤포레스트 모델 구축
rnd_model = RandomForestClassifier(
    n_estimators = 500, # 예측기 500개
    max_leaf_nodes = 16, # 자식노드의 최대 개수 
    n_jobs = -1 # CPU 코어 구동 개수
)

# 모델 학습
rnd_model.fit(x_train,y_train)

# 모델 예측
y_pred_rf = rnd_model.predict(x_test)

# 모델 평가
print("rnd_model : ",accuracy_score(y_pred_rf,y_test))
# Out:
# rnd_model :  0.9333333333333333

# %% [markdown]
# ###변수중요도 확인

# %%
#  데이터셋 정의
x = iris.data[:,:]
y = iris.target

# 모델 구축
rnd_model = RandomForestClassifier(
    n_estimators = 500,
    n_jobs = -1
)

# 모델 학습
rnd_model.fit(x,y)

# 특성 중요도 확인 (전체 특성 중요도 합 : 1)
for feature_name,feature_imp in zip(iris['feature_names'],rnd_model.feature_importances_):
  print(feature_name,' : ',feature_imp)
# Out:
# sepal length (cm)  :  0.10623694682942976
# sepal width (cm)  :  0.02477121550872006
# petal length (cm)  :  0.40173190474564985
# petal width (cm)  :  0.4672599329162005

# %% [markdown]
# ##부스팅

# %% [markdown]
# ###AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
# 아다부스트 모델 구축
# 아다부스트의 학습기 : Decision Tree (max_depth =1) 사용
# 학습기 개수(n_estimators) : 200개
# SAMME(Stagewise Additive Modeling using a Multiclass Exponential loss function) 알고리즘 사용
# 기본 학습기가 확률 추정(predict_proba)이 가능하면 SAMME.R 사용 -> 일반적으로 성능이 더 좋음
ada_model = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1),
    n_estimators = 200,
    algorithm = 'SAMME.R',
    learning_rate=0.5
)

# 모델 학습
ada_model.fit(x,y)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=1),
#                    learning_rate=0.5, n_estimators=200)

# %% [markdown]
# ###과제! adaboost 에 특징, 장점을 1~2 문장으로 정리해주세요
#
# 특징: 여러개의 estimator를 사용해서 update를 하면서도 하나의 bootstrap할 때 확률값을 조정한다.
#
# 장점: 그렇기 때문에  잘 못푸는 문제를 더 잘 풀 수 있도록 한다.

# %% [markdown]
# ###Gradient Boost

# %%
from sklearn.tree import DecisionTreeRegressor

# 결정트리(max_depth=3) 모델 구축 및 학습
tree_reg_model_1 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_1.fit(x,y)

# 첫 번째 학습기에서 발생한 잔차를 목적함수로 모델 학습
residual_1 = y - tree_reg_model_1.predict(x)
tree_reg_model_2 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_2.fit(x,residual_1)

# 두 번째 학습기에서 발생한 잔차를 목적함수로 모델 학습
residual_2 = y - tree_reg_model_2.predict(x)
tree_reg_model_3 = DecisionTreeRegressor(max_depth=3)
tree_reg_model_3.fit(x,residual_2)
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
# 새로운 데이터를 세 개의 트리를 포함한 앙상블 모델로 예측
x_new = [[1.4,0.2, 1.8, 0.5]]
prediction = sum(tree.predict(x_new) for tree in [tree_reg_model_1,tree_reg_model_2,tree_reg_model_3])
prediction
# Out:
# array([0.])

# %% [markdown]
# ###XGBoost

# %% [markdown]
# ### 과제 !! XGboost 의 장점을 적어주세요

# %% [markdown]
# 이곳에 적어주세요 : 병렬처리가 가능하다

# %%
import xgboost as xgb
from xgboost import XGBClassifier,XGBRegressor
from xgboost import plot_importance, plot_tree

# %%
from sklearn.datasets import load_breast_cancer

cancer= load_breast_cancer()
X_train, X_test , y_train, y_test = train_test_split(cancer.data, cancer.target,test_size=0.2,random_state=100)

dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test,label=y_test)

# %%
params = {
    'max_depth' :3 ,
    'eta' : 0.1,
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'early_stopping' : 100,
    }
num_rounds=400

# %%
evals = [(dtrain,'train'),(dtest,'eval')]
xgb_model = xgb.train(params=params, dtrain=dtrain ,num_boost_round=num_rounds , early_stopping_rounds=100,evals=evals)
# Out:
# [23:20:03] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.6.0/src/learner.cc:627:
# Parameters: { "early_stopping" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [0]	train-logloss:0.61157	eval-logloss:0.61460
# [1]	train-logloss:0.54459	eval-logloss:0.55405
# [2]	train-logloss:0.48760	eval-logloss:0.49816
# [3]	train-logloss:0.43613	eval-logloss:0.44858
# [4]	train-logloss:0.39411	eval-logloss:0.40558
# [5]	train-logloss:0.35700	eval-logloss:0.37227
# [6]	train-logloss:0.32370	eval-logloss:0.34176
# [7]	train-logloss:0.29441	eval-logloss:0.31699
# [8]	train-logloss:0.26823	eval-logloss:0.29199
# [9]	train-logloss:0.24541	eval-logloss:0.27386
# [10]	train-logloss:0.22565	eval-logloss:0.25490
# [11]	train-logloss:0.20728	eval-logloss:0.23818
# [12]	train-logloss:0.19089	eval-logloss:0.22577
# [13]	train-logloss:0.17611	eval-logloss:0.21225
# [14]	train-logloss:0.16348	eval-logloss:0.20156
# [15]	train-logloss:0.15143	eval-logloss:0.19251
# [16]	train-logloss:0.14124	eval-logloss:0.18292
# [17]	train-logloss:0.13122	eval-logloss:0.17663
# [18]	train-logloss:0.12233	eval-logloss:0.17008
# [19]	train-logloss:0.11425	eval-logloss:0.16261
# [20]	train-logloss:0.10640	eval-logloss:0.15747
# [21]	train-logloss:0.09982	eval-logloss:0.15208
# [22]	train-logloss:0.09412	eval-logloss:0.14877
# [23]	train-logloss:0.08816	eval-logloss:0.14609
# [24]	train-logloss:0.08324	eval-logloss:0.14465
# [25]	train-logloss:0.07833	eval-logloss:0.14215
# [26]	train-logloss:0.07427	eval-logloss:0.13825
# [27]	train-logloss:0.07005	eval-logloss:0.13535
# [28]	train-logloss:0.06640	eval-logloss:0.13244
# [29]	train-logloss:0.06328	eval-logloss:0.12968
# [30]	train-logloss:0.06005	eval-logloss:0.12679
# [31]	train-logloss:0.05712	eval-logloss:0.12401
# [32]	train-logloss:0.05450	eval-logloss:0.12214
# [33]	train-logloss:0.05201	eval-logloss:0.12005
# [34]	train-logloss:0.04970	eval-logloss:0.11779
# [35]	train-logloss:0.04754	eval-logloss:0.11656
# [36]	train-logloss:0.04575	eval-logloss:0.11471
# [37]	train-logloss:0.04399	eval-logloss:0.11389
# [38]	train-logloss:0.04230	eval-logloss:0.11172
# [39]	train-logloss:0.04059	eval-logloss:0.11054
# [40]	train-logloss:0.03901	eval-logloss:0.11114
# [41]	train-logloss:0.03754	eval-logloss:0.10920
# [42]	train-logloss:0.03623	eval-logloss:0.10794
# [43]	train-logloss:0.03498	eval-logloss:0.10702
# [44]	train-logloss:0.03372	eval-logloss:0.10687
# [45]	train-logloss:0.03272	eval-logloss:0.10608
# [46]	train-logloss:0.03163	eval-logloss:0.10560
# [47]	train-logloss:0.03061	eval-logloss:0.10464
# [48]	train-logloss:0.02960	eval-logloss:0.10365
# [49]	train-logloss:0.02876	eval-logloss:0.10238
# [50]	train-logloss:0.02790	eval-logloss:0.10204
# [51]	train-logloss:0.02708	eval-logloss:0.10219
# [52]	train-logloss:0.02635	eval-logloss:0.10197
# [53]	train-logloss:0.02563	eval-logloss:0.10181
# [54]	train-logloss:0.02499	eval-logloss:0.10217
# [55]	train-logloss:0.02436	eval-logloss:0.10247
# [56]	train-logloss:0.02388	eval-logloss:0.10318
# [57]	train-logloss:0.02332	eval-logloss:0.10299
# [58]	train-logloss:0.02277	eval-logloss:0.10262
# [59]	train-logloss:0.02228	eval-logloss:0.10185
# [60]	train-logloss:0.02175	eval-logloss:0.10282
# [61]	train-logloss:0.02121	eval-logloss:0.10275
# [62]	train-logloss:0.02072	eval-logloss:0.10257
# [63]	train-logloss:0.02013	eval-logloss:0.10064
# [64]	train-logloss:0.01958	eval-logloss:0.10056
# [65]	train-logloss:0.01911	eval-logloss:0.10009
# [66]	train-logloss:0.01866	eval-logloss:0.09982
# [67]	train-logloss:0.01838	eval-logloss:0.10019
# [68]	train-logloss:0.01798	eval-logloss:0.10049
# [69]	train-logloss:0.01761	eval-logloss:0.10038
# [70]	train-logloss:0.01724	eval-logloss:0.10040
# [71]	train-logloss:0.01692	eval-logloss:0.10030
# [72]	train-logloss:0.01654	eval-logloss:0.09921
# [73]	train-logloss:0.01621	eval-logloss:0.09942
# [74]	train-logloss:0.01586	eval-logloss:0.09906
# [75]	train-logloss:0.01568	eval-logloss:0.09898
# [76]	train-logloss:0.01546	eval-logloss:0.09933
# [77]	train-logloss:0.01526	eval-logloss:0.09966
# [78]	train-logloss:0.01500	eval-logloss:0.09982
# [79]	train-logloss:0.01474	eval-logloss:0.09954
# [80]	train-logloss:0.01446	eval-logloss:0.09848
# [81]	train-logloss:0.01427	eval-logloss:0.09806
# [82]	train-logloss:0.01406	eval-logloss:0.09775
# [83]	train-logloss:0.01384	eval-logloss:0.09729
# [84]	train-logloss:0.01371	eval-logloss:0.09673
# [85]	train-logloss:0.01354	eval-logloss:0.09730
# [86]	train-logloss:0.01342	eval-logloss:0.09714
# [87]	train-logloss:0.01326	eval-logloss:0.09745
# [88]	train-logloss:0.01311	eval-logloss:0.09745
# [89]	train-logloss:0.01295	eval-logloss:0.09649
# [90]	train-logloss:0.01276	eval-logloss:0.09645
# [91]	train-logloss:0.01257	eval-logloss:0.09588
# [92]	train-logloss:0.01246	eval-logloss:0.09538
# [93]	train-logloss:0.01222	eval-logloss:0.09512
# [94]	train-logloss:0.01212	eval-logloss:0.09500
# [95]	train-logloss:0.01201	eval-logloss:0.09524
# [96]	train-logloss:0.01189	eval-logloss:0.09527
# [97]	train-logloss:0.01180	eval-logloss:0.09479
# [98]	train-logloss:0.01163	eval-logloss:0.09431
# [99]	train-logloss:0.01151	eval-logloss:0.09460
# [100]	train-logloss:0.01140	eval-logloss:0.09426
# [101]	train-logloss:0.01131	eval-logloss:0.09369
# [102]	train-logloss:0.01121	eval-logloss:0.09349
# [103]	train-logloss:0.01113	eval-logloss:0.09403
# [104]	train-logloss:0.01105	eval-logloss:0.09385
# [105]	train-logloss:0.01096	eval-logloss:0.09407
# [106]	train-logloss:0.01087	eval-logloss:0.09429
# [107]	train-logloss:0.01076	eval-logloss:0.09398
# [108]	train-logloss:0.01068	eval-logloss:0.09356
# [109]	train-logloss:0.01059	eval-logloss:0.09303
# [110]	train-logloss:0.01051	eval-logloss:0.09329
# [111]	train-logloss:0.01043	eval-logloss:0.09320
# [112]	train-logloss:0.01036	eval-logloss:0.09342
# [113]	train-logloss:0.01028	eval-logloss:0.09391
# [114]	train-logloss:0.01021	eval-logloss:0.09350
# [115]	train-logloss:0.01012	eval-logloss:0.09320
# [116]	train-logloss:0.01005	eval-logloss:0.09342
# [117]	train-logloss:0.00998	eval-logloss:0.09325
# [118]	train-logloss:0.00991	eval-logloss:0.09390
# [119]	train-logloss:0.00986	eval-logloss:0.09376
# [120]	train-logloss:0.00978	eval-logloss:0.09401
# [121]	train-logloss:0.00972	eval-logloss:0.09384
# [122]	train-logloss:0.00965	eval-logloss:0.09336
# [123]	train-logloss:0.00959	eval-logloss:0.09297
# [124]	train-logloss:0.00950	eval-logloss:0.09261
# [125]	train-logloss:0.00944	eval-logloss:0.09283
# [126]	train-logloss:0.00937	eval-logloss:0.09308
# [127]	train-logloss:0.00932	eval-logloss:0.09290
# [128]	train-logloss:0.00926	eval-logloss:0.09282
# [129]	train-logloss:0.00920	eval-logloss:0.09346
# [130]	train-logloss:0.00914	eval-logloss:0.09308
# [131]	train-logloss:0.00908	eval-logloss:0.09278
# [132]	train-logloss:0.00903	eval-logloss:0.09299
# [133]	train-logloss:0.00898	eval-logloss:0.09323
# [134]	train-logloss:0.00893	eval-logloss:0.09312
# [135]	train-logloss:0.00888	eval-logloss:0.09357
# [136]	train-logloss:0.00882	eval-logloss:0.09321
# [137]	train-logloss:0.00880	eval-logloss:0.09294
# [138]	train-logloss:0.00872	eval-logloss:0.09264
# [139]	train-logloss:0.00867	eval-logloss:0.09285
# [140]	train-logloss:0.00862	eval-logloss:0.09271
# [141]	train-logloss:0.00857	eval-logloss:0.09332
# [142]	train-logloss:0.00852	eval-logloss:0.09297
# [143]	train-logloss:0.00847	eval-logloss:0.09321
# [144]	train-logloss:0.00842	eval-logloss:0.09277
# [145]	train-logloss:0.00835	eval-logloss:0.09249
# [146]	train-logloss:0.00831	eval-logloss:0.09278
# [147]	train-logloss:0.00828	eval-logloss:0.09251
# [148]	train-logloss:0.00824	eval-logloss:0.09273
# [149]	train-logloss:0.00822	eval-logloss:0.09290
# [150]	train-logloss:0.00817	eval-logloss:0.09293
# [151]	train-logloss:0.00815	eval-logloss:0.09281
# [152]	train-logloss:0.00813	eval-logloss:0.09296
# [153]	train-logloss:0.00808	eval-logloss:0.09324
# [154]	train-logloss:0.00801	eval-logloss:0.09316
# [155]	train-logloss:0.00799	eval-logloss:0.09291
# [156]	train-logloss:0.00795	eval-logloss:0.09311
# [157]	train-logloss:0.00790	eval-logloss:0.09277
# [158]	train-logloss:0.00786	eval-logloss:0.09271
# [159]	train-logloss:0.00782	eval-logloss:0.09329
# [160]	train-logloss:0.00776	eval-logloss:0.09302
# [161]	train-logloss:0.00769	eval-logloss:0.09295
# [162]	train-logloss:0.00767	eval-logloss:0.09272
# [163]	train-logloss:0.00764	eval-logloss:0.09294
# [164]	train-logloss:0.00760	eval-logloss:0.09352
# [165]	train-logloss:0.00758	eval-logloss:0.09340
# [166]	train-logloss:0.00756	eval-logloss:0.09317
# [167]	train-logloss:0.00753	eval-logloss:0.09321
# [168]	train-logloss:0.00752	eval-logloss:0.09307
# [169]	train-logloss:0.00748	eval-logloss:0.09332
# [170]	train-logloss:0.00747	eval-logloss:0.09348
# [171]	train-logloss:0.00745	eval-logloss:0.09327
# [172]	train-logloss:0.00743	eval-logloss:0.09313
# [173]	train-logloss:0.00741	eval-logloss:0.09332
# [174]	train-logloss:0.00739	eval-logloss:0.09321
# [175]	train-logloss:0.00737	eval-logloss:0.09337
# [176]	train-logloss:0.00736	eval-logloss:0.09331
# [177]	train-logloss:0.00734	eval-logloss:0.09352
# [178]	train-logloss:0.00732	eval-logloss:0.09332
# [179]	train-logloss:0.00731	eval-logloss:0.09318
# [180]	train-logloss:0.00728	eval-logloss:0.09338
# [181]	train-logloss:0.00727	eval-logloss:0.09328
# [182]	train-logloss:0.00725	eval-logloss:0.09312
# [183]	train-logloss:0.00724	eval-logloss:0.09327
# [184]	train-logloss:0.00722	eval-logloss:0.09356
# [185]	train-logloss:0.00721	eval-logloss:0.09336
# [186]	train-logloss:0.00719	eval-logloss:0.09322
# [187]	train-logloss:0.00718	eval-logloss:0.09343
# [188]	train-logloss:0.00716	eval-logloss:0.09358
# [189]	train-logloss:0.00715	eval-logloss:0.09342
# [190]	train-logloss:0.00713	eval-logloss:0.09322
# [191]	train-logloss:0.00712	eval-logloss:0.09344
# [192]	train-logloss:0.00710	eval-logloss:0.09334
# [193]	train-logloss:0.00709	eval-logloss:0.09348
# [194]	train-logloss:0.00707	eval-logloss:0.09332
# [195]	train-logloss:0.00706	eval-logloss:0.09313
# [196]	train-logloss:0.00704	eval-logloss:0.09307
# [197]	train-logloss:0.00703	eval-logloss:0.09327
# [198]	train-logloss:0.00701	eval-logloss:0.09313
# [199]	train-logloss:0.00700	eval-logloss:0.09328
# [200]	train-logloss:0.00699	eval-logloss:0.09356
# [201]	train-logloss:0.00697	eval-logloss:0.09338
# [202]	train-logloss:0.00696	eval-logloss:0.09322
# [203]	train-logloss:0.00695	eval-logloss:0.09336
# [204]	train-logloss:0.00693	eval-logloss:0.09325
# [205]	train-logloss:0.00692	eval-logloss:0.09312
# [206]	train-logloss:0.00691	eval-logloss:0.09311
# [207]	train-logloss:0.00689	eval-logloss:0.09339
# [208]	train-logloss:0.00688	eval-logloss:0.09321
# [209]	train-logloss:0.00687	eval-logloss:0.09305
# [210]	train-logloss:0.00685	eval-logloss:0.09320
# [211]	train-logloss:0.00684	eval-logloss:0.09310
# [212]	train-logloss:0.00683	eval-logloss:0.09337
# [213]	train-logloss:0.00681	eval-logloss:0.09351
# [214]	train-logloss:0.00680	eval-logloss:0.09336
# [215]	train-logloss:0.00679	eval-logloss:0.09318
# [216]	train-logloss:0.00678	eval-logloss:0.09304
# [217]	train-logloss:0.00676	eval-logloss:0.09323
# [218]	train-logloss:0.00675	eval-logloss:0.09336
# [219]	train-logloss:0.00674	eval-logloss:0.09321
# [220]	train-logloss:0.00673	eval-logloss:0.09304
# [221]	train-logloss:0.00672	eval-logloss:0.09330
# [222]	train-logloss:0.00670	eval-logloss:0.09344
# [223]	train-logloss:0.00669	eval-logloss:0.09335
# [224]	train-logloss:0.00668	eval-logloss:0.09321
# [225]	train-logloss:0.00667	eval-logloss:0.09304
# [226]	train-logloss:0.00666	eval-logloss:0.09289
# [227]	train-logloss:0.00665	eval-logloss:0.09303
# [228]	train-logloss:0.00663	eval-logloss:0.09289
# [229]	train-logloss:0.00662	eval-logloss:0.09272
# [230]	train-logloss:0.00661	eval-logloss:0.09286
# [231]	train-logloss:0.00660	eval-logloss:0.09273
# [232]	train-logloss:0.00659	eval-logloss:0.09291
# [233]	train-logloss:0.00658	eval-logloss:0.09317
# [234]	train-logloss:0.00657	eval-logloss:0.09308
# [235]	train-logloss:0.00656	eval-logloss:0.09322
# [236]	train-logloss:0.00655	eval-logloss:0.09308
# [237]	train-logloss:0.00654	eval-logloss:0.09292
# [238]	train-logloss:0.00653	eval-logloss:0.09305
# [239]	train-logloss:0.00652	eval-logloss:0.09292
# [240]	train-logloss:0.00650	eval-logloss:0.09316
# [241]	train-logloss:0.00649	eval-logloss:0.09301
# [242]	train-logloss:0.00648	eval-logloss:0.09287
# [243]	train-logloss:0.00647	eval-logloss:0.09301
# [244]	train-logloss:0.00646	eval-logloss:0.09292
# [245]	train-logloss:0.00645	eval-logloss:0.09292

# %%
predicts = xgb_model.predict(dtest)
print(np.round(predicts[:10],3))
# Out:
# [0.    0.916 0.013 1.    0.997 0.997 0.014 0.    0.994 0.989]

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ###변수간 중요도 확인 가능!

# %%
fig ,ax =plt.subplots(figsize=(10,12))
plot_importance(xgb_model , ax=ax)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
