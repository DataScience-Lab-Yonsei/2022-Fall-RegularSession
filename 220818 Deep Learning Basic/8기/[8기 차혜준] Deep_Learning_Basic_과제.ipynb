# %%
import numpy as np
from torchvision import transforms, datasets
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %% [markdown]
# ## 과제 1
# ReLu activation function과 derivative function을 구현해보세요
# - Hint : np.maximum 함수 사용하면 편리합니다
# - 다른 방법 사용하셔도 무방합니다

# %%
def relu(x):
  return np.maximum(0, x)

# %%
def d_relu(x):
  if np.maximum(0, x) == x:
    return 1
  else:
    return 0

# %% [markdown]
# ## 과제 2
# Deep Learning Basic 코드 파일의 MLP implementation with Numpy library using MNIST dataset 코드 참고해서
# Three layer MLP 일 때의 backward_pass 함수를 완성해주세요.
# - Hint : 코드 파일의 예시는 Two layer MLP

# %%
def backward_pass(x, y_true, params):
  dS3 = params["A3"] - y_true

  grads = {}

  grads["dW3"] =  np.dot(dS3, params["A2"].T)/x.shape[1]
  grads["db3"] =  (1/x.shape[1])*np.sum(dS3, axis=1, keepdims=True)/x.shape[1]

  dA2 = np.dot(params["W3"].T, dS3)
  dS2 = dA2 * d_relu(params["S2"])

  grads["dW2"] =  np.dot(dS2, params["A1"].T)/x.shape[1]
  grads["db2"] =  (1/x.shape[1])*np.sum(dS2, axis=1, keepdims=True)/x.shape[1]

  dA1 = np.dot(params["W2"].T, dS2)
  dS1 = dA1 * d_relu(params["S1"])

  grads["dW1"] = np.dot(dS1, x.T)/x.shape[1]
  grads["db1"] = np.sum(dS1, axis=1, keepdims=True)/x.shape[1]

  return grads

# %% [markdown]
# ## 과제 3
# Deep Learning Basic 코드 파일의 MLP implementation with Pytorch library using MNIST dataset 코드 참고해서
# Three layer MLP를 구한후, 학습을 돌려 보세요
#
# hyperparameter는 다음과 같이 설정
#
# - epochs : 100
# - hiddensize : 128, 64 (two layer)
# - learning_rate : 0.5

# %%
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
trainset = datasets.MNIST(
    root      = './.data/', 
    train     = True,
    download  = True,
    transform = transform
)
testset = datasets.MNIST(
    root      = './.data/', 
    train     = False,
    download  = True,
    transform = transform
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./.data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw

# %%
BATCH_SIZE = 512
# train set과 test set 각각에 대하여 DataLoader를 생성합니다.
# shuffle=True 매개변수를 넣어 데이터를 섞어주세요.
train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
test_loader =  DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# Assignment 3 구현은 여기서 ()]
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer1 = nn.Linear(784,128) # 이미지 크기 28*28=784, 중간층 노드 개수 64 임의 지정
        self.layer2 = nn.Linear(128,64)
        self.layer3 = nn.Linear(64,10)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.relu(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.layer3(out)
        out = self.relu(out)

        return out

# %%
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.5)

# %%
def train(model, train_loader, optimizer):
    model.train()
    # 배치 당 loss 값을 담을 리스트 생성
    batch_losses = []

    for data, target in train_loader:
        # 옵티마이저의 기울기 초기화
        optimizer.zero_grad()

        # y pred 값 산출
        output = model(data)
        # loss 계산
        # 정답 데이터와의 cross entropy loss 계산
        # 이 loss를 배치 당 loss로 보관
        loss = criterion(output, target)
        batch_losses.append(loss)

        # 기울기 계산
        loss.backward()

        # 가중치 업데이트!
        optimizer.step()
        
    # 배치당 평균 loss 계산
    avg_loss = sum(batch_losses) / len(batch_losses)
    
    return avg_loss

def evaluate(model, test_loader):
    # 모델을 평가 모드로 전환
    model.eval()

    batch_losses = []
    correct = 0 

    with torch.no_grad(): 
        for data, target in test_loader:
            # 예측값 생성
            output = model(data)

            # loss 계산 (이전과 동일)
            loss = criterion(output, target)
            batch_losses.append(loss)

           # Accuracy 계산
           # y pred와 y가 일치하면 correct에 1을 더해주기
            pred = output.max(1, keepdim=True)[1]

            # eq() 함수는 값이 일치하면 1을, 아니면 0을 출력.
            correct += pred.eq(target.view_as(pred)).sum().item()

    # 배치 당 평균 loss 계산 
    avg_loss =  sum(batch_losses) / len(batch_losses)

    #정확도 계산
    accuracy = 100. * correct / len(test_loader.dataset)

    return avg_loss, accuracy

# %%
EPOCHS = 100

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 0.7185	Test Loss: 0.4924	Accuracy: 89.00%
# [2] Train Loss: 0.4162	Test Loss: 0.8240	Accuracy: 78.17%
# [3] Train Loss: 0.3874	Test Loss: 0.3585	Accuracy: 94.88%
# [4] Train Loss: 0.3436	Test Loss: 0.3440	Accuracy: 95.30%
# [5] Train Loss: 0.3266	Test Loss: 0.3447	Accuracy: 95.46%
# [6] Train Loss: 0.3132	Test Loss: 0.4219	Accuracy: 92.56%
# [7] Train Loss: 0.3028	Test Loss: 0.3434	Accuracy: 95.71%
# [8] Train Loss: 0.2913	Test Loss: 0.3176	Accuracy: 96.16%
# [9] Train Loss: 0.2873	Test Loss: 0.4452	Accuracy: 92.02%
# [10] Train Loss: 0.3384	Test Loss: 0.3039	Accuracy: 96.97%
# [11] Train Loss: 0.2797	Test Loss: 0.4140	Accuracy: 93.61%
# [12] Train Loss: 0.2791	Test Loss: 0.2988	Accuracy: 97.21%
# [13] Train Loss: 0.2672	Test Loss: 0.3287	Accuracy: 96.11%
# [14] Train Loss: 0.2655	Test Loss: 0.2936	Accuracy: 97.27%
# [15] Train Loss: 0.2596	Test Loss: 0.2947	Accuracy: 97.35%
# [16] Train Loss: 0.2578	Test Loss: 0.3115	Accuracy: 97.11%
# [17] Train Loss: 0.2543	Test Loss: 0.3054	Accuracy: 97.15%
# [18] Train Loss: 0.2516	Test Loss: 0.2952	Accuracy: 97.44%
# [19] Train Loss: 0.2493	Test Loss: 0.3363	Accuracy: 96.43%
# [20] Train Loss: 0.2474	Test Loss: 0.2895	Accuracy: 97.85%
# [21] Train Loss: 0.2453	Test Loss: 0.2940	Accuracy: 97.77%
# [22] Train Loss: 0.2430	Test Loss: 0.2863	Accuracy: 97.95%
# [23] Train Loss: 0.2422	Test Loss: 0.2922	Accuracy: 97.72%
# [24] Train Loss: 0.2402	Test Loss: 0.3023	Accuracy: 97.63%
# [25] Train Loss: 0.2389	Test Loss: 0.3419	Accuracy: 96.38%
# [26] Train Loss: 3.4061	Test Loss: 0.1772	Accuracy: 94.73%
# [27] Train Loss: 0.1644	Test Loss: 0.1934	Accuracy: 94.22%
# [28] Train Loss: 0.1107	Test Loss: 0.1385	Accuracy: 96.00%
# [29] Train Loss: 0.0890	Test Loss: 0.1183	Accuracy: 96.37%
# [30] Train Loss: 0.0787	Test Loss: 0.1472	Accuracy: 95.40%
# [31] Train Loss: 0.0696	Test Loss: 0.1142	Accuracy: 96.72%
# [32] Train Loss: 0.0604	Test Loss: 0.1450	Accuracy: 95.74%
# [33] Train Loss: 0.2001	Test Loss: 0.1542	Accuracy: 95.57%
# [34] Train Loss: 0.0736	Test Loss: 0.1523	Accuracy: 95.52%
# [35] Train Loss: 0.0618	Test Loss: 0.1223	Accuracy: 96.45%
# [36] Train Loss: 0.0555	Test Loss: 0.1192	Accuracy: 96.44%
# [37] Train Loss: 0.0499	Test Loss: 0.1427	Accuracy: 95.93%
# [38] Train Loss: 0.0446	Test Loss: 0.3995	Accuracy: 90.79%
# [39] Train Loss: 0.0458	Test Loss: 0.1064	Accuracy: 96.79%
# [40] Train Loss: 0.0386	Test Loss: 0.2569	Accuracy: 93.11%
# [41] Train Loss: 0.0382	Test Loss: 0.1966	Accuracy: 94.87%
# [42] Train Loss: 0.0394	Test Loss: 0.1340	Accuracy: 96.30%
# [43] Train Loss: 0.0304	Test Loss: 0.0946	Accuracy: 97.48%
# [44] Train Loss: 0.3243	Test Loss: 0.3385	Accuracy: 90.04%
# [45] Train Loss: 0.1340	Test Loss: 0.1299	Accuracy: 95.98%
# [46] Train Loss: 0.0841	Test Loss: 0.1538	Accuracy: 95.26%
# [47] Train Loss: 0.0675	Test Loss: 0.1736	Accuracy: 94.98%
# [48] Train Loss: 0.0583	Test Loss: 0.1440	Accuracy: 95.73%
# [49] Train Loss: 0.0504	Test Loss: 0.1102	Accuracy: 96.80%
# [50] Train Loss: 0.0454	Test Loss: 0.1389	Accuracy: 96.12%
# [51] Train Loss: 0.0413	Test Loss: 0.1160	Accuracy: 96.73%
# [52] Train Loss: 0.0368	Test Loss: 0.1005	Accuracy: 97.32%
# [53] Train Loss: 0.0340	Test Loss: 0.1099	Accuracy: 97.14%
# [54] Train Loss: 0.0303	Test Loss: 0.1023	Accuracy: 97.24%
# [55] Train Loss: 0.0283	Test Loss: 0.4518	Accuracy: 90.98%
# [56] Train Loss: 0.4402	Test Loss: 0.1639	Accuracy: 95.07%
# [57] Train Loss: 0.0952	Test Loss: 0.1444	Accuracy: 95.80%
# [58] Train Loss: 0.0735	Test Loss: 0.1646	Accuracy: 94.91%
# [59] Train Loss: 0.0634	Test Loss: 0.1460	Accuracy: 95.77%
# [60] Train Loss: 0.0541	Test Loss: 0.1118	Accuracy: 96.65%
# [61] Train Loss: 0.0499	Test Loss: 0.1396	Accuracy: 96.05%
# [62] Train Loss: 0.0461	Test Loss: 0.1387	Accuracy: 96.17%
# [63] Train Loss: 0.0418	Test Loss: 0.1213	Accuracy: 96.78%
# [64] Train Loss: 0.0381	Test Loss: 0.1765	Accuracy: 95.42%
# [65] Train Loss: 0.0365	Test Loss: 0.1502	Accuracy: 96.21%
# [66] Train Loss: 0.0341	Test Loss: 0.1296	Accuracy: 96.68%
# [67] Train Loss: 0.0308	Test Loss: 0.1598	Accuracy: 95.89%
# [68] Train Loss: 0.0303	Test Loss: 0.1586	Accuracy: 95.92%
# [69] Train Loss: 0.0285	Test Loss: 0.1295	Accuracy: 96.59%
# [70] Train Loss: 0.0262	Test Loss: 0.1168	Accuracy: 96.94%
# [71] Train Loss: 0.0245	Test Loss: 0.2796	Accuracy: 92.99%
# [72] Train Loss: 0.1814	Test Loss: 0.1478	Accuracy: 96.08%
# [73] Train Loss: 0.0513	Test Loss: 0.1258	Accuracy: 96.81%
# [74] Train Loss: 0.0400	Test Loss: 0.2547	Accuracy: 94.02%
# [75] Train Loss: 0.0361	Test Loss: 0.1462	Accuracy: 96.09%
# [76] Train Loss: 0.0297	Test Loss: 0.1286	Accuracy: 96.72%
# [77] Train Loss: 0.0257	Test Loss: 0.1408	Accuracy: 96.38%
# [78] Train Loss: 0.0228	Test Loss: 0.1277	Accuracy: 97.09%
# [79] Train Loss: 0.0205	Test Loss: 0.1280	Accuracy: 97.02%
# [80] Train Loss: 0.0190	Test Loss: 0.1275	Accuracy: 97.08%
# [81] Train Loss: 0.0172	Test Loss: 0.1429	Accuracy: 96.56%
# [82] Train Loss: 0.0160	Test Loss: 0.1343	Accuracy: 96.92%
# [83] Train Loss: 0.0144	Test Loss: 0.1320	Accuracy: 97.09%
# [84] Train Loss: 0.0133	Test Loss: 0.1328	Accuracy: 96.98%
# [85] Train Loss: 0.0121	Test Loss: 0.1341	Accuracy: 96.91%
# [86] Train Loss: 0.0114	Test Loss: 0.1348	Accuracy: 97.11%
# [87] Train Loss: 0.0104	Test Loss: 0.1338	Accuracy: 96.97%
# [88] Train Loss: 0.0098	Test Loss: 0.1387	Accuracy: 97.04%
# [89] Train Loss: 0.0095	Test Loss: 0.2393	Accuracy: 95.10%
# [90] Train Loss: 0.7506	Test Loss: 0.3258	Accuracy: 91.93%
# [91] Train Loss: 0.1041	Test Loss: 0.1949	Accuracy: 94.66%
# [92] Train Loss: 0.0766	Test Loss: 0.1432	Accuracy: 96.06%
# [93] Train Loss: 0.0639	Test Loss: 0.1695	Accuracy: 95.14%
# [94] Train Loss: 0.0558	Test Loss: 0.1311	Accuracy: 96.45%
# [95] Train Loss: 0.0488	Test Loss: 0.1326	Accuracy: 96.57%
# [96] Train Loss: 0.0446	Test Loss: 0.1364	Accuracy: 96.50%
# [97] Train Loss: 0.0421	Test Loss: 0.1234	Accuracy: 96.81%
# [98] Train Loss: 0.0374	Test Loss: 0.1286	Accuracy: 96.65%
# [99] Train Loss: 0.0358	Test Loss: 0.1374	Accuracy: 96.40%
# [100] Train Loss: 0.0334	Test Loss: 0.1253	Accuracy: 96.68%

# %% [markdown]
# ## 과제 4
# 과제 3 부분의 성능을 지금까지 배운 지식을 바탕으로 향상시켜보세요
#
# - Hint : Activation function, hyperparameter setting

# %%
# Assignment 4 구현은 여기서 ()
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01)

EPOCHS = 100

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 2.3012	Test Loss: 2.2980	Accuracy: 13.45%
# [2] Train Loss: 2.2933	Test Loss: 2.2881	Accuracy: 21.71%
# [3] Train Loss: 2.2789	Test Loss: 2.2654	Accuracy: 31.69%
# [4] Train Loss: 2.2461	Test Loss: 2.2225	Accuracy: 36.41%
# [5] Train Loss: 2.1912	Test Loss: 2.1524	Accuracy: 36.86%
# [6] Train Loss: 2.1048	Test Loss: 2.0454	Accuracy: 38.81%
# [7] Train Loss: 1.9811	Test Loss: 1.9091	Accuracy: 49.07%
# [8] Train Loss: 1.8431	Test Loss: 1.7651	Accuracy: 53.51%
# [9] Train Loss: 1.7040	Test Loss: 1.6307	Accuracy: 54.91%
# [10] Train Loss: 1.5752	Test Loss: 1.5106	Accuracy: 56.62%
# [11] Train Loss: 1.4728	Test Loss: 1.4214	Accuracy: 58.15%
# [12] Train Loss: 1.3979	Test Loss: 1.3608	Accuracy: 59.43%
# [13] Train Loss: 1.3442	Test Loss: 1.3114	Accuracy: 60.78%
# [14] Train Loss: 1.2996	Test Loss: 1.2677	Accuracy: 61.32%
# [15] Train Loss: 1.2608	Test Loss: 1.2355	Accuracy: 61.72%
# [16] Train Loss: 1.2297	Test Loss: 1.2056	Accuracy: 62.26%
# [17] Train Loss: 1.2023	Test Loss: 1.1792	Accuracy: 62.75%
# [18] Train Loss: 1.1782	Test Loss: 1.1578	Accuracy: 62.83%
# [19] Train Loss: 1.1562	Test Loss: 1.1357	Accuracy: 63.08%
# [20] Train Loss: 1.1365	Test Loss: 1.1175	Accuracy: 63.13%
# [21] Train Loss: 1.1199	Test Loss: 1.1006	Accuracy: 63.31%
# [22] Train Loss: 1.1056	Test Loss: 1.0873	Accuracy: 63.38%
# [23] Train Loss: 1.0911	Test Loss: 1.0754	Accuracy: 63.47%
# [24] Train Loss: 1.0801	Test Loss: 1.0629	Accuracy: 63.66%
# [25] Train Loss: 1.0698	Test Loss: 1.0483	Accuracy: 63.82%
# [26] Train Loss: 1.0592	Test Loss: 1.0423	Accuracy: 63.79%
# [27] Train Loss: 1.0509	Test Loss: 1.0331	Accuracy: 64.00%
# [28] Train Loss: 1.0441	Test Loss: 1.0313	Accuracy: 64.02%
# [29] Train Loss: 1.0358	Test Loss: 1.0198	Accuracy: 64.04%
# [30] Train Loss: 1.0295	Test Loss: 1.0145	Accuracy: 64.14%
# [31] Train Loss: 1.0237	Test Loss: 1.0065	Accuracy: 64.17%
# [32] Train Loss: 1.0174	Test Loss: 0.9984	Accuracy: 64.28%
# [33] Train Loss: 1.0118	Test Loss: 1.0013	Accuracy: 64.32%
# [34] Train Loss: 1.0082	Test Loss: 0.9932	Accuracy: 64.40%
# [35] Train Loss: 1.0030	Test Loss: 0.9860	Accuracy: 64.51%
# [36] Train Loss: 0.9973	Test Loss: 0.9838	Accuracy: 64.51%
# [37] Train Loss: 0.9960	Test Loss: 0.9781	Accuracy: 64.58%
# [38] Train Loss: 0.9911	Test Loss: 0.9773	Accuracy: 64.55%
# [39] Train Loss: 0.9868	Test Loss: 0.9719	Accuracy: 64.76%
# [40] Train Loss: 0.9843	Test Loss: 0.9731	Accuracy: 64.73%
# [41] Train Loss: 0.9810	Test Loss: 0.9654	Accuracy: 64.83%
# [42] Train Loss: 0.9784	Test Loss: 0.9618	Accuracy: 64.82%
# [43] Train Loss: 0.9731	Test Loss: 0.9604	Accuracy: 64.93%
# [44] Train Loss: 0.9714	Test Loss: 0.9613	Accuracy: 64.96%
# [45] Train Loss: 0.9683	Test Loss: 0.9544	Accuracy: 64.93%
# [46] Train Loss: 0.9644	Test Loss: 0.9523	Accuracy: 65.01%
# [47] Train Loss: 0.9627	Test Loss: 0.9536	Accuracy: 65.07%
# [48] Train Loss: 0.9586	Test Loss: 0.9466	Accuracy: 65.11%
# [49] Train Loss: 0.9552	Test Loss: 0.9443	Accuracy: 65.08%
# [50] Train Loss: 0.9544	Test Loss: 0.9449	Accuracy: 65.07%
# [51] Train Loss: 0.9519	Test Loss: 0.9436	Accuracy: 65.21%
# [52] Train Loss: 0.9525	Test Loss: 0.9391	Accuracy: 65.23%
# [53] Train Loss: 0.9470	Test Loss: 0.9385	Accuracy: 65.35%
# [54] Train Loss: 0.9436	Test Loss: 0.9366	Accuracy: 65.22%
# [55] Train Loss: 0.9424	Test Loss: 0.9308	Accuracy: 65.30%
# [56] Train Loss: 0.9400	Test Loss: 0.9343	Accuracy: 65.35%
# [57] Train Loss: 0.9380	Test Loss: 0.9316	Accuracy: 65.25%
# [58] Train Loss: 0.9358	Test Loss: 0.9227	Accuracy: 65.37%
# [59] Train Loss: 0.9327	Test Loss: 0.9268	Accuracy: 65.36%
# [60] Train Loss: 0.9316	Test Loss: 0.9234	Accuracy: 65.53%
# [61] Train Loss: 0.9288	Test Loss: 0.9228	Accuracy: 65.34%
# [62] Train Loss: 0.9276	Test Loss: 0.9193	Accuracy: 65.46%
# [63] Train Loss: 0.9261	Test Loss: 0.9164	Accuracy: 65.58%
# [64] Train Loss: 0.9239	Test Loss: 0.9169	Accuracy: 65.43%
# [65] Train Loss: 0.9223	Test Loss: 0.9147	Accuracy: 65.57%
# [66] Train Loss: 0.9192	Test Loss: 0.9163	Accuracy: 65.57%
# [67] Train Loss: 0.9181	Test Loss: 0.9126	Accuracy: 65.58%
# [68] Train Loss: 0.9150	Test Loss: 0.9122	Accuracy: 65.61%
# [69] Train Loss: 0.9152	Test Loss: 0.9112	Accuracy: 65.64%
# [70] Train Loss: 0.9134	Test Loss: 0.9037	Accuracy: 65.67%
# [71] Train Loss: 0.9094	Test Loss: 0.9061	Accuracy: 65.64%
# [72] Train Loss: 0.9085	Test Loss: 0.9035	Accuracy: 65.63%
# [73] Train Loss: 0.9079	Test Loss: 0.9020	Accuracy: 65.69%
# [74] Train Loss: 0.9042	Test Loss: 0.8990	Accuracy: 65.73%
# [75] Train Loss: 0.9034	Test Loss: 0.9036	Accuracy: 65.71%
# [76] Train Loss: 0.9019	Test Loss: 0.8994	Accuracy: 65.75%
# [77] Train Loss: 0.8993	Test Loss: 0.8951	Accuracy: 65.78%
# [78] Train Loss: 0.8972	Test Loss: 0.8913	Accuracy: 65.81%
# [79] Train Loss: 0.8971	Test Loss: 0.8915	Accuracy: 65.84%
# [80] Train Loss: 0.8951	Test Loss: 0.8922	Accuracy: 65.84%
# [81] Train Loss: 0.8927	Test Loss: 0.8892	Accuracy: 65.88%
# [82] Train Loss: 0.8916	Test Loss: 0.8903	Accuracy: 65.82%
# [83] Train Loss: 0.8891	Test Loss: 0.8869	Accuracy: 65.86%
# [84] Train Loss: 0.8884	Test Loss: 0.8886	Accuracy: 65.89%
# [85] Train Loss: 0.8890	Test Loss: 0.8887	Accuracy: 65.92%
# [86] Train Loss: 0.8855	Test Loss: 0.8828	Accuracy: 65.95%
# [87] Train Loss: 0.8844	Test Loss: 0.8806	Accuracy: 65.94%
# [88] Train Loss: 0.8824	Test Loss: 0.8798	Accuracy: 65.99%
# [89] Train Loss: 0.8801	Test Loss: 0.8779	Accuracy: 65.99%
# [90] Train Loss: 0.8783	Test Loss: 0.8768	Accuracy: 66.05%
# [91] Train Loss: 0.8776	Test Loss: 0.8775	Accuracy: 65.99%
# [92] Train Loss: 0.8753	Test Loss: 0.8752	Accuracy: 66.01%
# [93] Train Loss: 0.8747	Test Loss: 0.8746	Accuracy: 66.12%
# [94] Train Loss: 0.8737	Test Loss: 0.8707	Accuracy: 66.14%
# [95] Train Loss: 0.8728	Test Loss: 0.8746	Accuracy: 66.14%
# [96] Train Loss: 0.8712	Test Loss: 0.8708	Accuracy: 66.12%
# [97] Train Loss: 0.8702	Test Loss: 0.8691	Accuracy: 66.19%
# [98] Train Loss: 0.8671	Test Loss: 0.8693	Accuracy: 66.18%
# [99] Train Loss: 0.8653	Test Loss: 0.8660	Accuracy: 66.17%
# [100] Train Loss: 0.8655	Test Loss: 0.8649	Accuracy: 66.23%

# %% [markdown]
# **무엇을 보완하였고, 왜 보완되었는지에 대한 자유 서술 (아래에)**

# %% [markdown]
# - Learning Rate가 0.5였을 때 loss가 수렴하지 않고 계속 움직이는 경향을 보였다.
# - Learning Rate가 너무 커서 발생하는 현상이라 판단하고, Learning Rate를 0.01로 줄여 진행하였다.
# - 결과적으로 loss가 잘 수렴하였다.
# - 하지만, 정확도가 떨어진 것이 아쉬워 ReLu 대신 LeakyRelu를 사용하고, momentum을 지정해 다시 시도해 보았다.
# - 결과적으로 이전보다 정확도가 높게 나타났다.

# %%
BATCH_SIZE = 512
# train set과 test set 각각에 대하여 DataLoader를 생성합니다.
# shuffle=True 매개변수를 넣어 데이터를 섞어주세요.
train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
test_loader =  DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)

# %%
# Assignment 3 구현은 여기서 ()]
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer1 = nn.Linear(784,128) # 이미지 크기 28*28=784, 중간층 노드 개수 64 임의 지정
        self.layer2 = nn.Linear(128,64)
        self.layer3 = nn.Linear(64,10)
        self.leakyrelu = nn.LeakyReLU()
        
    def forward(self, x):
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.leakyrelu(out)
        out = self.layer2(out)
        out = self.leakyrelu(out)
        out = self.layer3(out)
        out = self.leakyrelu(out)

        return out

# %%
model = Net()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

# %%
EPOCHS = 50

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 0.0720	Test Loss: 0.0917	Accuracy: 97.27%
# [2] Train Loss: 0.0693	Test Loss: 0.0914	Accuracy: 97.20%
# [3] Train Loss: 0.0666	Test Loss: 0.0902	Accuracy: 97.35%
# [4] Train Loss: 0.0648	Test Loss: 0.0906	Accuracy: 97.27%
# [5] Train Loss: 0.0629	Test Loss: 0.0886	Accuracy: 97.28%
# [6] Train Loss: 0.0608	Test Loss: 0.0841	Accuracy: 97.31%
# [7] Train Loss: 0.0584	Test Loss: 0.0873	Accuracy: 97.39%
# [8] Train Loss: 0.0566	Test Loss: 0.0856	Accuracy: 97.42%
# [9] Train Loss: 0.0546	Test Loss: 0.0827	Accuracy: 97.44%
# [10] Train Loss: 0.0531	Test Loss: 0.0837	Accuracy: 97.50%
# [11] Train Loss: 0.0517	Test Loss: 0.0796	Accuracy: 97.51%
# [12] Train Loss: 0.0497	Test Loss: 0.0803	Accuracy: 97.52%
# [13] Train Loss: 0.0489	Test Loss: 0.0786	Accuracy: 97.60%
# [14] Train Loss: 0.0466	Test Loss: 0.0787	Accuracy: 97.57%
# [15] Train Loss: 0.0453	Test Loss: 0.0775	Accuracy: 97.65%
# [16] Train Loss: 0.0441	Test Loss: 0.0772	Accuracy: 97.59%
# [17] Train Loss: 0.0430	Test Loss: 0.0768	Accuracy: 97.74%
# [18] Train Loss: 0.0419	Test Loss: 0.0770	Accuracy: 97.62%
# [19] Train Loss: 0.0405	Test Loss: 0.0738	Accuracy: 97.63%
# [20] Train Loss: 0.0391	Test Loss: 0.0767	Accuracy: 97.72%
# [21] Train Loss: 0.0377	Test Loss: 0.0762	Accuracy: 97.81%
# [22] Train Loss: 0.0371	Test Loss: 0.0744	Accuracy: 97.72%
# [23] Train Loss: 0.0354	Test Loss: 0.0763	Accuracy: 97.71%
# [24] Train Loss: 0.0350	Test Loss: 0.0749	Accuracy: 97.73%
# [25] Train Loss: 0.0337	Test Loss: 0.0734	Accuracy: 97.80%
# [26] Train Loss: 0.0342	Test Loss: 0.0728	Accuracy: 97.77%
# [27] Train Loss: 0.0319	Test Loss: 0.0715	Accuracy: 97.80%
# [28] Train Loss: 0.0307	Test Loss: 0.0731	Accuracy: 97.68%
# [29] Train Loss: 0.0300	Test Loss: 0.0723	Accuracy: 97.72%
# [30] Train Loss: 0.0290	Test Loss: 0.0719	Accuracy: 97.70%
# [31] Train Loss: 0.0283	Test Loss: 0.0730	Accuracy: 97.65%
# [32] Train Loss: 0.0276	Test Loss: 0.0711	Accuracy: 97.82%
# [33] Train Loss: 0.0263	Test Loss: 0.0718	Accuracy: 97.76%
# [34] Train Loss: 0.0254	Test Loss: 0.0723	Accuracy: 97.78%
# [35] Train Loss: 0.0254	Test Loss: 0.0693	Accuracy: 97.85%
# [36] Train Loss: 0.0241	Test Loss: 0.0700	Accuracy: 97.87%
# [37] Train Loss: 0.0236	Test Loss: 0.0743	Accuracy: 97.78%
# [38] Train Loss: 0.0229	Test Loss: 0.0700	Accuracy: 97.79%
# [39] Train Loss: 0.0223	Test Loss: 0.0701	Accuracy: 97.76%
# [40] Train Loss: 0.0216	Test Loss: 0.0705	Accuracy: 97.85%
# [41] Train Loss: 0.0209	Test Loss: 0.0717	Accuracy: 97.83%
# [42] Train Loss: 0.0206	Test Loss: 0.0711	Accuracy: 97.82%
# [43] Train Loss: 0.0203	Test Loss: 0.0692	Accuracy: 97.82%
# [44] Train Loss: 0.0196	Test Loss: 0.0712	Accuracy: 97.80%
# [45] Train Loss: 0.0192	Test Loss: 0.0703	Accuracy: 97.90%
# [46] Train Loss: 0.0182	Test Loss: 0.0719	Accuracy: 97.94%
# [47] Train Loss: 0.0179	Test Loss: 0.0696	Accuracy: 97.94%
# [48] Train Loss: 0.0173	Test Loss: 0.0703	Accuracy: 97.84%
# [49] Train Loss: 0.0170	Test Loss: 0.0698	Accuracy: 97.88%
# [50] Train Loss: 0.0163	Test Loss: 0.0707	Accuracy: 97.87%
