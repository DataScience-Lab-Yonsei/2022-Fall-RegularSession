# %% [markdown]
# ## 과제 1
# ReLu activation function과 derivative function을 구현해보세요
# - Hint : np.maximum 함수 사용하면 편리합니다
# - 다른 방법 사용하셔도 무방합니다

# %%
import numpy as np

def relu(x):

  return np.maximum(0,x)

print(relu(3))
print(relu(-3))
# Out:
# 3
# 0

# %%
def d_relu(x):
  if x>0:
    return 1
  else:
    return 0

print(d_relu(3))
print(d_relu(-3))
# Out:
# 1
# 0

# %% [markdown]
# ## 과제 2
# Deep Learning Basic 코드 파일의 MLP implementation with Numpy library using MNIST dataset 코드 참고해서
# Three layer MLP 일 때의 backward_pass 함수를 완성해주세요.
# - Hint : 코드 파일의 예시는 Two layer MLP

# %%
from IPython import get_ipython
get_ipython().magic('reset -sf')

import numpy as np
import sklearn.datasets

mnist = sklearn.datasets.fetch_openml('mnist_784', data_home="mnist_784")

# %%
# data preprocessing

num_train = 60000
num_class = 10

x_train = np.float32(mnist.data[:num_train]).T
y_train_index = np.int32(mnist.target[:num_train]).T
x_test = np.float32(mnist.data[num_train:]).T
y_test_index = np.int32(mnist.target[num_train:]).T

# Normalization

x_train /= 255
x_test /= 255
x_size = x_train.shape[0]

y_train = np.zeros((num_class, y_train_index.shape[0]))
for idx in range(y_train_index.shape[0]):
  y_train[y_train_index[idx], idx] = 1

y_test = np.zeros((num_class, y_test_index.shape[0]))
for idx in range(y_test_index.shape[0]):
  y_test[y_test_index[idx], idx] = 1

# %%
x_train.shape
# Out:
# (784, 60000)

# %%
#parameter initialization

hidden_size1 = 128 # hidden unit 1 size
hidden_size2 = 64  # hidden unit 2 size

# three-layer neural network

params = {"W1": np.random.randn(hidden_size1, x_size) * np.sqrt(1/ x_size),
          "b1": np.zeros((hidden_size1, 1)) * np.sqrt(1/ x_size),
          "W2": np.random.randn(hidden_size2, hidden_size1) * np.sqrt(1/ hidden_size1),
          "b2": np.zeros((hidden_size2, 1)) * np.sqrt(1/ hidden_size1),
          "W3": np.random.randn(num_class, hidden_size2) * np.sqrt(1/ hidden_size2),
          "b3": np.zeros((num_class, 1)) * np.sqrt(1/ hidden_size2)
          }
# Xavier initialization: https://reniew.github.io/13/

# %%
def sigmoid(x):
  return 1/(1+np.exp(-x))

def d_sigmoid(x):
  # derivative of sigmoid
  exp = np.exp(-x)
  return (exp)/((1+exp)**2)

def softmax(x):
  exp = np.exp(x)
  return exp/np.sum(exp, axis=0)

# %%
def compute_loss(y_true, y_pred):
  # loss calculation

  num_sample = y_true.shape[1]
  Li = -1 * np.sum(y_true * np.log(y_pred))
  
  return Li/num_sample

# %%
def foward_pass(x, params):
  
  params["S1"] = np.dot(params["W1"], x) + params["b1"]
  params["A1"] = sigmoid(params["S1"])
  params["S2"] = np.dot(params["W2"], params["A1"]) + params["b2"]
  params["A2"] = sigmoid(params["S2"])
  params["S3"] = np.dot(params["W3"], params["A2"]) + params["b3"]
  params["A3"] = softmax(params["S3"])

  return params

# %%
def foward_pass_test(x, params):

  params_test = {}
  
  params_test["S1"] = np.dot(params["W1"], x) + params["b1"]
  params_test["A1"] = sigmoid(params_test["S1"])
  params_test["S2"] = np.dot(params["W2"], params_test["A1"]) + params["b2"]
  params_test["A2"] = sigmoid(params_test["S2"])
  params_test["S3"] = np.dot(params["W3"], params_test["A2"]) + params["b3"]
  params_test["A3"] = softmax(params_test["S3"])

  return params_test

# %%
def compute_accuracy(y_true, y_pred):
  y_true_idx = np.argmax(y_true, axis = 0)
  y_pred_idx = np.argmax(y_pred, axis = 0)
  num_correct = np.sum(y_true_idx==y_pred_idx)

  accuracy = num_correct / y_true.shape[1] * 100

  return accuracy

# %%
def backward_pass(x, y_true, params):

  dS3 = params["A3"] - y_true
  # Please check http://machinelearningmechanic.com/deep_learning/2019/09/04/cross-entropy-loss-derivative.html
  # dS3 is softmax + CE loss derivative

  # https://towardsdatascience.com/lets-code-a-neural-network-in-plain-numpy-ae7e74410795
  # https://junstar92.tistory.com/76 

  grads = {}

  grads["dW3"] =  np.dot(dS3, params["A2"].T)/x.shape[1]
  grads["db3"] =  np.sum(dS3, axis=1, keepdims=True)/x.shape[1] #*(1/x.shape[1])

  dA2 = np.dot(params["W3"].T, dS3)
  dS2 = dA2 * d_sigmoid(params["S2"])

  grads["dW2"] = np.dot(dS2, params["A1"].T)/x.shape[1]
  grads["db2"] = np.sum(dS2, axis=1, keepdims=True)/x.shape[1]

  dA1 = np.dot(params["W2"].T, dS2)
  dS1 = dA1 * d_sigmoid(params["S1"])

  grads["dW1"] = np.dot(dS1, x.T)/x.shape[1]
  grads["db1"] = np.sum(dS1, axis=1, keepdims=True)/x.shape[1]

  return grads

# %%
epochs = 100
learning_rate = 0.5

for i in range(epochs):

  if i == 0:
    params = foward_pass(x_train, params)
    
  grads = backward_pass(x_train, y_train, params)

  params["W1"] -= learning_rate * grads["dW1"]
  params["b1"] -= learning_rate * grads["db1"]
  params["W2"] -= learning_rate * grads["dW2"]
  params["b2"] -= learning_rate * grads["db2"]
  params["W3"] -= learning_rate * grads["dW3"]
  params["b3"] -= learning_rate * grads["db3"]

  params = foward_pass(x_train, params)
  train_loss = compute_loss(y_train, params["A3"])
  train_acc = compute_accuracy(y_train, params["A3"])

  params_test = foward_pass_test(x_test, params)
  test_loss = compute_loss(y_test, params_test["A3"])
  test_acc = compute_accuracy(y_test, params_test["A3"])

  print("Epoch {}: training loss = {}, training acuracy = {}%, test loss = {}, testing acuracy = {}%"
  .format(i + 1, np.round(train_loss, 6), np.round(train_acc, 2), np.round(test_loss, 6), np.round(test_acc, 2)))
# Out:
# Epoch 1: training loss = 2.334616, training acuracy = 10.44%, test loss = 2.335318, testing acuracy = 10.3%
# Epoch 2: training loss = 2.300241, training acuracy = 10.5%, test loss = 2.300212, testing acuracy = 10.62%
# Epoch 3: training loss = 2.294677, training acuracy = 11.36%, test loss = 2.294348, testing acuracy = 11.42%
# Epoch 4: training loss = 2.292322, training acuracy = 11.24%, test loss = 2.291912, testing acuracy = 11.35%
# Epoch 5: training loss = 2.289997, training acuracy = 11.24%, test loss = 2.289543, testing acuracy = 11.35%
# Epoch 6: training loss = 2.287659, training acuracy = 11.24%, test loss = 2.287162, testing acuracy = 11.36%
# Epoch 7: training loss = 2.285303, training acuracy = 11.25%, test loss = 2.284763, testing acuracy = 11.36%
# Epoch 8: training loss = 2.282926, training acuracy = 11.28%, test loss = 2.282342, testing acuracy = 11.38%
# Epoch 9: training loss = 2.280522, training acuracy = 11.34%, test loss = 2.279895, testing acuracy = 11.4%
# Epoch 10: training loss = 2.278089, training acuracy = 11.46%, test loss = 2.277417, testing acuracy = 11.52%
# Epoch 11: training loss = 2.275621, training acuracy = 11.8%, test loss = 2.274904, testing acuracy = 11.94%
# Epoch 12: training loss = 2.273114, training acuracy = 12.5%, test loss = 2.272352, testing acuracy = 12.65%
# Epoch 13: training loss = 2.270564, training acuracy = 13.58%, test loss = 2.269756, testing acuracy = 13.71%
# Epoch 14: training loss = 2.267967, training acuracy = 14.88%, test loss = 2.267111, testing acuracy = 15.3%
# Epoch 15: training loss = 2.265317, training acuracy = 16.42%, test loss = 2.264414, testing acuracy = 17.34%
# Epoch 16: training loss = 2.26261, training acuracy = 18.22%, test loss = 2.261658, testing acuracy = 19.03%
# Epoch 17: training loss = 2.25984, training acuracy = 20.1%, test loss = 2.258839, testing acuracy = 21.11%
# Epoch 18: training loss = 2.257004, training acuracy = 22.02%, test loss = 2.255951, testing acuracy = 23.15%
# Epoch 19: training loss = 2.254094, training acuracy = 23.93%, test loss = 2.25299, testing acuracy = 25.09%
# Epoch 20: training loss = 2.251107, training acuracy = 25.96%, test loss = 2.249949, testing acuracy = 27.39%
# Epoch 21: training loss = 2.248035, training acuracy = 27.78%, test loss = 2.246823, testing acuracy = 28.96%
# Epoch 22: training loss = 2.244873, training acuracy = 29.62%, test loss = 2.243605, testing acuracy = 30.86%
# Epoch 23: training loss = 2.241615, training acuracy = 31.34%, test loss = 2.240289, testing acuracy = 32.54%
# Epoch 24: training loss = 2.238255, training acuracy = 32.94%, test loss = 2.236869, testing acuracy = 34.11%
# Epoch 25: training loss = 2.234784, training acuracy = 34.48%, test loss = 2.233337, testing acuracy = 35.68%
# Epoch 26: training loss = 2.231197, training acuracy = 36.02%, test loss = 2.229687, testing acuracy = 37.26%
# Epoch 27: training loss = 2.227486, training acuracy = 37.43%, test loss = 2.225911, testing acuracy = 38.45%
# Epoch 28: training loss = 2.223643, training acuracy = 38.76%, test loss = 2.222, testing acuracy = 39.48%
# Epoch 29: training loss = 2.21966, training acuracy = 39.95%, test loss = 2.217947, testing acuracy = 40.66%
# Epoch 30: training loss = 2.215529, training acuracy = 41.13%, test loss = 2.213744, testing acuracy = 41.89%
# Epoch 31: training loss = 2.211241, training acuracy = 42.17%, test loss = 2.209381, testing acuracy = 42.98%
# Epoch 32: training loss = 2.206786, training acuracy = 43.2%, test loss = 2.204849, testing acuracy = 43.95%
# Epoch 33: training loss = 2.202156, training acuracy = 44.14%, test loss = 2.200138, testing acuracy = 44.84%
# Epoch 34: training loss = 2.19734, training acuracy = 45.04%, test loss = 2.195238, testing acuracy = 45.58%
# Epoch 35: training loss = 2.192328, training acuracy = 45.9%, test loss = 2.190139, testing acuracy = 46.49%
# Epoch 36: training loss = 2.187109, training acuracy = 46.6%, test loss = 2.184829, testing acuracy = 47.1%
# Epoch 37: training loss = 2.181672, training acuracy = 47.28%, test loss = 2.179298, testing acuracy = 47.62%
# Epoch 38: training loss = 2.176005, training acuracy = 47.95%, test loss = 2.173534, testing acuracy = 48.09%
# Epoch 39: training loss = 2.170097, training acuracy = 48.56%, test loss = 2.167524, testing acuracy = 48.73%
# Epoch 40: training loss = 2.163936, training acuracy = 49.15%, test loss = 2.161256, testing acuracy = 49.16%
# Epoch 41: training loss = 2.157508, training acuracy = 49.73%, test loss = 2.154718, testing acuracy = 49.56%
# Epoch 42: training loss = 2.1508, training acuracy = 50.18%, test loss = 2.147895, testing acuracy = 50.06%
# Epoch 43: training loss = 2.143801, training acuracy = 50.62%, test loss = 2.140776, testing acuracy = 50.55%
# Epoch 44: training loss = 2.136496, training acuracy = 51.09%, test loss = 2.133346, testing acuracy = 51.0%
# Epoch 45: training loss = 2.128872, training acuracy = 51.5%, test loss = 2.125592, testing acuracy = 51.51%
# Epoch 46: training loss = 2.120916, training acuracy = 51.87%, test loss = 2.1175, testing acuracy = 51.69%
# Epoch 47: training loss = 2.112614, training acuracy = 52.22%, test loss = 2.109057, testing acuracy = 52.06%
# Epoch 48: training loss = 2.103953, training acuracy = 52.56%, test loss = 2.100249, testing acuracy = 52.35%
# Epoch 49: training loss = 2.094921, training acuracy = 52.88%, test loss = 2.091065, testing acuracy = 52.8%
# Epoch 50: training loss = 2.085504, training acuracy = 53.18%, test loss = 2.08149, testing acuracy = 53.0%
# Epoch 51: training loss = 2.075693, training acuracy = 53.45%, test loss = 2.071514, testing acuracy = 53.44%
# Epoch 52: training loss = 2.065475, training acuracy = 53.69%, test loss = 2.061126, testing acuracy = 53.74%
# Epoch 53: training loss = 2.054841, training acuracy = 53.93%, test loss = 2.050315, testing acuracy = 53.97%
# Epoch 54: training loss = 2.043782, training acuracy = 54.13%, test loss = 2.039074, testing acuracy = 54.2%
# Epoch 55: training loss = 2.032291, training acuracy = 54.37%, test loss = 2.027395, testing acuracy = 54.41%
# Epoch 56: training loss = 2.020363, training acuracy = 54.57%, test loss = 2.015273, testing acuracy = 54.63%
# Epoch 57: training loss = 2.007993, training acuracy = 54.79%, test loss = 2.002704, testing acuracy = 54.72%
# Epoch 58: training loss = 1.995181, training acuracy = 55.02%, test loss = 1.989686, testing acuracy = 54.99%
# Epoch 59: training loss = 1.981926, training acuracy = 55.27%, test loss = 1.976221, testing acuracy = 55.25%
# Epoch 60: training loss = 1.96823, training acuracy = 55.5%, test loss = 1.962311, testing acuracy = 55.51%
# Epoch 61: training loss = 1.954099, training acuracy = 55.73%, test loss = 1.947961, testing acuracy = 55.86%
# Epoch 62: training loss = 1.939541, training acuracy = 55.99%, test loss = 1.93318, testing acuracy = 56.11%
# Epoch 63: training loss = 1.924563, training acuracy = 56.29%, test loss = 1.917977, testing acuracy = 56.45%
# Epoch 64: training loss = 1.90918, training acuracy = 56.56%, test loss = 1.902365, testing acuracy = 56.84%
# Epoch 65: training loss = 1.893405, training acuracy = 56.82%, test loss = 1.886359, testing acuracy = 57.13%
# Epoch 66: training loss = 1.877254, training acuracy = 57.15%, test loss = 1.869976, testing acuracy = 57.49%
# Epoch 67: training loss = 1.860746, training acuracy = 57.45%, test loss = 1.853236, testing acuracy = 57.74%
# Epoch 68: training loss = 1.843902, training acuracy = 57.71%, test loss = 1.836159, testing acuracy = 58.02%
# Epoch 69: training loss = 1.826744, training acuracy = 58.03%, test loss = 1.818768, testing acuracy = 58.25%
# Epoch 70: training loss = 1.809294, training acuracy = 58.39%, test loss = 1.801088, testing acuracy = 58.55%
# Epoch 71: training loss = 1.791577, training acuracy = 58.72%, test loss = 1.783143, testing acuracy = 58.83%
# Epoch 72: training loss = 1.773618, training acuracy = 59.03%, test loss = 1.764959, testing acuracy = 59.2%
# Epoch 73: training loss = 1.755444, training acuracy = 59.37%, test loss = 1.746563, testing acuracy = 59.67%
# Epoch 74: training loss = 1.737082, training acuracy = 59.7%, test loss = 1.727983, testing acuracy = 60.08%
# Epoch 75: training loss = 1.718557, training acuracy = 60.07%, test loss = 1.709246, testing acuracy = 60.43%
# Epoch 76: training loss = 1.699898, training acuracy = 60.46%, test loss = 1.69038, testing acuracy = 60.74%
# Epoch 77: training loss = 1.681131, training acuracy = 60.84%, test loss = 1.671413, testing acuracy = 61.11%
# Epoch 78: training loss = 1.662284, training acuracy = 61.23%, test loss = 1.652372, testing acuracy = 61.47%
# Epoch 79: training loss = 1.643384, training acuracy = 61.61%, test loss = 1.633285, testing acuracy = 61.86%
# Epoch 80: training loss = 1.624457, training acuracy = 62.06%, test loss = 1.614179, testing acuracy = 62.46%
# Epoch 81: training loss = 1.605531, training acuracy = 62.42%, test loss = 1.595081, testing acuracy = 62.82%
# Epoch 82: training loss = 1.586631, training acuracy = 62.82%, test loss = 1.576018, testing acuracy = 63.28%
# Epoch 83: training loss = 1.567782, training acuracy = 63.17%, test loss = 1.557014, testing acuracy = 63.62%
# Epoch 84: training loss = 1.54901, training acuracy = 63.58%, test loss = 1.538096, testing acuracy = 63.97%
# Epoch 85: training loss = 1.530338, training acuracy = 64.06%, test loss = 1.519286, testing acuracy = 64.43%
# Epoch 86: training loss = 1.51179, training acuracy = 64.42%, test loss = 1.500609, testing acuracy = 64.85%
# Epoch 87: training loss = 1.493387, training acuracy = 64.78%, test loss = 1.482087, testing acuracy = 65.09%
# Epoch 88: training loss = 1.475151, training acuracy = 65.18%, test loss = 1.46374, testing acuracy = 65.43%
# Epoch 89: training loss = 1.457102, training acuracy = 65.53%, test loss = 1.445587, testing acuracy = 65.85%
# Epoch 90: training loss = 1.439258, training acuracy = 65.99%, test loss = 1.427649, testing acuracy = 66.26%
# Epoch 91: training loss = 1.421635, training acuracy = 66.38%, test loss = 1.40994, testing acuracy = 66.7%
# Epoch 92: training loss = 1.404249, training acuracy = 66.74%, test loss = 1.392476, testing acuracy = 67.22%
# Epoch 93: training loss = 1.387114, training acuracy = 67.13%, test loss = 1.37527, testing acuracy = 67.48%
# Epoch 94: training loss = 1.370243, training acuracy = 67.46%, test loss = 1.358335, testing acuracy = 67.9%
# Epoch 95: training loss = 1.353644, training acuracy = 67.83%, test loss = 1.34168, testing acuracy = 68.27%
# Epoch 96: training loss = 1.337329, training acuracy = 68.18%, test loss = 1.325313, testing acuracy = 68.71%
# Epoch 97: training loss = 1.321303, training acuracy = 68.51%, test loss = 1.309243, testing acuracy = 68.99%
# Epoch 98: training loss = 1.305572, training acuracy = 68.87%, test loss = 1.293474, testing acuracy = 69.38%
# Epoch 99: training loss = 1.290142, training acuracy = 69.18%, test loss = 1.27801, testing acuracy = 69.82%
# Epoch 100: training loss = 1.275014, training acuracy = 69.47%, test loss = 1.262854, testing acuracy = 70.1%

# %% [markdown]
# ## 과제 3
# Deep Learning Basic 코드 파일의 MLP implementation with Pytorch library using MNIST dataset 코드 참고해서
# Three layer MLP를 구한후, 학습을 돌려 보세요
#
# hyperparameter는 다음과 같이 설정
#
# - epochs : 100
# - hiddensize : 128, 64 (two layer)
# - learning_rate : 0.5

# %%
from torchvision import transforms, datasets
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# 이미지를 텐서로 변경
transform = transforms.Compose([
    transforms.ToTensor()
])

trainset = datasets.MNIST(
    root      = './.data/', 
    train     = True,
    download  = True,
    transform = transform
)
testset = datasets.MNIST(
    root      = './.data/', 
    train     = False,
    download  = True,
    transform = transform
)

BATCH_SIZE = 512
# train set과 test set 각각에 대하여 DataLoader를 생성합니다.
# shuffle=True 매개변수를 넣어 데이터를 섞어주세요.
train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
test_loader =  DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./.data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__() #forward
        self.layer1 = nn.Linear(784,128) #이미지의 크기가 28*28. 색 흑백이기 때문임.
        self.layer2 = nn.Linear(128,64)  
        self.layer3 = nn.Linear(64,10)  #classification을 할 때 0~9까지 볼 것이기 때문에 10개임.
        self.relu = nn.ReLU()
        
    def forward(self, x): #이미 있는 것들을 곱해주는 .. 
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.relu(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.layer3(out)

        return out


model = Net()
model

criterion = nn.CrossEntropyLoss() #손실함수
optimizer = optim.SGD(model.parameters(), lr=0.5)

def train(model, train_loader, optimizer):
    model.train() #train은 backward를 실행하는 반면, test는 forward를 진행함.

    # 배치 당 loss 값을 담을 리스트 생성
    batch_losses = []

    for data, target in train_loader:
        # 옵티마이저의 기울기 초기화
        optimizer.zero_grad()

        # y pred 값 산출
        output = model(data)

        # loss 계산
        # 정답 데이터(target)와의 cross entropy loss 계산
        # 이 loss를 배치 당 loss로 보관
        loss = criterion(output, target)
        batch_losses.append(loss)

        # 기울기 계산 - 가중치 업데이트.
        loss.backward()

        # 가중치 업데이트!
        optimizer.step()
        
    # 배치당 평균 loss 계산
    avg_loss = sum(batch_losses) / len(batch_losses)
    
    return avg_loss

def evaluate(model, test_loader):
    # 모델을 평가 모드로 전환
    model.eval()

    batch_losses = []
    correct = 0 

    with torch.no_grad(): #가중치를 업데이트하는 것이 아님.
        for data, target in test_loader:
            # 예측값 생성
            output = model(data)

            # loss 계산 (이전과 동일)
            loss = criterion(output, target)
            batch_losses.append(loss)

           # Accuracy 계산
           # y pred와 y가 일치하면 correct에 1을 더해주기
            pred = output.max(1, keepdim=True)[1]

            # eq() 함수는 값이 일치하면 1을, 아니면 0을 출력.
            correct += pred.eq(target.view_as(pred)).sum().item()

    # 배치 당 평균 loss 계산 
    avg_loss =  sum(batch_losses) / len(batch_losses)

    #정확도 계산
    accuracy = 100. * correct / len(test_loader.dataset)

    return avg_loss, accuracy

# %%
EPOCHS = 100

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss:
# [93] Train Loss: 0.0138	Test Loss: 0.0709	Accuracy: 98.03%
# [94] Train Loss: 0.0132	Test Loss: 0.0729	Accuracy: 98.00%
# [95] Train Loss: 0.0131	Test Loss: 0.0730	Accuracy: 97.99%
# [96] Train Loss: 0.0128	Test Loss: 0.0731	Accuracy: 98.04%
# [97] Train Loss: 0.0128	Test Loss: 0.0731	Accuracy: 98.04%
# [98] Train Loss: 0.0122	Test Loss: 0.0726	Accuracy: 98.03%
# [99] Train Loss: 0.0117	Test Loss: 0.0734	Accuracy: 98.03%
# [100] Train Loss: 0.0114	Test Loss: 0.0734	Accuracy: 97.99%

# %%
# Assignment 4 구현은 여기서 ()
## 두번째 시도
class NewNet(nn.Module):
    def __init__(self):
        super(NewNet, self).__init__() #forward
        self.layer1 = nn.Linear(784,128) #이미지의 크기가 28*28. 색 흑백이기 때문임.
        self.layer2 = nn.Linear(128,64)  
        self.layer3 = nn.Linear(64,10)  #classification을 할 때 0~9까지 볼 것이기 때문에 10개임.
        self.leakyrelu = nn.LeakyReLU(0.1)
        
    def forward(self, x): #이미 있는 것들을 곱해주는 .. 
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.leakyrelu(out)
        out = self.layer2(out)
        out = self.leakyrelu(out)
        out = self.layer3(out)

        return out

model_new = NewNet()

EPOCHS = 50
new_optimizer = optim.SGD(model_new.parameters(), lr=0.01, momentum=0.9) #optimizer, learning rate 정의
criterion = nn.CrossEntropyLoss()

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model_new, train_loader, new_optimizer)
    test_loss, test_accuracy = evaluate(model_new, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 1.7028	Test Loss: 0.6934	Accuracy: 80.10%
# [2] Train Loss: 0.5068	Test Loss: 0.3845	Accuracy: 89.09%
# [3] Train Loss: 0.3710	Test Loss: 0.3247	Accuracy: 90.51%
# [4] Train Loss: 0.3266	Test Loss: 0.2967	Accuracy: 91.53%
# [5] Train Loss: 0.2987	Test Loss: 0.2777	Accuracy: 92.06%
# [6] Train Loss: 0.2762	Test Loss: 0.2565	Accuracy: 92.72%
# [7] Train Loss: 0.2577	Test Loss: 0.2399	Accuracy: 93.20%
# [8] Train Loss: 0.2418	Test Loss: 0.2315	Accuracy: 93.29%
# [9] Train Loss: 0.2277	Test Loss: 0.2143	Accuracy: 93.92%
# [10] Train Loss: 0.2136	Test Loss: 0.2019	Accuracy: 94.29%
# [11] Train Loss: 0.2022	Test Loss: 0.1918	Accuracy: 94.41%
# [12] Train Loss: 0.1914	Test Loss: 0.1840	Accuracy: 94.59%
# [13] Train Loss: 0.1806	Test Loss: 0.1780	Accuracy: 94.91%
# [14] Train Loss: 0.1712	Test Loss: 0.1687	Accuracy: 94.96%
# [15] Train Loss: 0.1640	Test Loss: 0.1599	Accuracy: 95.22%
# [16] Train Loss: 0.1554	Test Loss: 0.1549	Accuracy: 95.42%
# [17] Train Loss: 0.1491	Test Loss: 0.1503	Accuracy: 95.54%
# [18] Train Loss: 0.1413	Test Loss: 0.1419	Accuracy: 95.89%
# [19] Train Loss: 0.1346	Test Loss: 0.1378	Accuracy: 96.03%
# [20] Train Loss: 0.1295	Test Loss: 0.1343	Accuracy: 96.13%
# [21] Train Loss: 0.1247	Test Loss: 0.1293	Accuracy: 96.23%
