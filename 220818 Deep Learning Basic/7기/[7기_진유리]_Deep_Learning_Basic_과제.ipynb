# %% [markdown]
# ## 과제 1
# ReLu activation function과 derivative function을 구현해보세요
# - Hint : np.maximum 함수 사용하면 편리합니다
# - 다른 방법 사용하셔도 무방합니다

# %%
def relu(x):
  
  x = np.maximum(0,x)

  return x

# %%
def d_relu(x):

  if x <= 0:
    x = 0

  else:
    x = 1

  return x

# %% [markdown]
# ## 과제 2
# Deep Learning Basic 코드 파일의 MLP implementation with Numpy library using MNIST dataset 코드 참고해서
# Three layer MLP 일 때의 backward_pass 함수를 완성해주세요.
# - Hint : 코드 파일의 예시는 Two layer MLP

# %%
def backward_pass(x, y_true, params):

  dS3 = params["A3"] - y_true

  grads = {}

  grads["dW3"] =  np.dot(dS3, params["A2"].T)/x.shape[1]
  grads["db3"] =  (1/x.shape[1])*np.sum(dS3, axis=1, keepdims=True)/x.shape[1]

  dA2 = np.dot(params["W3"].T, dS3)
  dS2 = dA2 * d_sigmoid(params["S2"])

  grads["dW2"] = np.dot(dS2, x.T)/x.shape[1]
  grads["db2"] = np.sum(dS2, axis=1, keepdims=True)/x.shape[1]

  dA1 = np.dot(params["W1"].T, dS2)
  dS1 = dA1 * d_sigmoid(params["S1"])

  grads["dW1"] = np.dot(dS1, x.T)/x.shape[1]
  grads["db1"] = np.sum(dS1, axis=1, keepdims=True)/x.shape[1]

  return grads

# %% [markdown]
# ## 과제 3
# Deep Learning Basic 코드 파일의 MLP implementation with Pytorch library using MNIST dataset 코드 참고해서
# Three layer MLP를 구한후, 학습을 돌려 보세요
#
# hyperparameter는 다음과 같이 설정
#
# - epochs : 100
# - hiddensize : 128, 64 (two layer)
# - learning_rate : 0.5

# %%
from torchvision import transforms, datasets
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# 이미지를 텐서로 변경
transform = transforms.Compose([
    transforms.ToTensor()
])

# %%
trainset = datasets.MNIST(
    root      = './.data/', 
    train     = True,
    download  = True,
    transform = transform
)
testset = datasets.MNIST(
    root      = './.data/', 
    train     = False,
    download  = True,
    transform = transform
)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./.data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/train-labels-idx1-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./.data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting ./.data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./.data/MNIST/raw

# %%
BATCH_SIZE = 512
# train set과 test set 각각에 대하여 DataLoader를 생성합니다.
# shuffle=True 매개변수를 넣어 데이터를 섞어주세요.
train_loader = DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True)
test_loader =  DataLoader(testset, batch_size=BATCH_SIZE, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.layer1 = nn.Linear(784,128)
        self.layer2 = nn.Linear(128,64)
        self.layer3 = nn.Linear(64,10)
        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.relu(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.layer3(out)

        return out

# %%
model = Net()
model
# Out:
# Net(
#   (layer1): Linear(in_features=784, out_features=128, bias=True)
#   (layer2): Linear(in_features=128, out_features=64, bias=True)
#   (layer3): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
list(model.parameters()) # 행렬들을 직접 살펴볼 수 있음
                         # require_true 얘는 학습되는 애구나 알 수 있음
# Out:
# [Parameter containing:
#  tensor([[ 0.0131, -0.0290, -0.0187,  ..., -0.0097, -0.0266, -0.0163],
#          [ 0.0160, -0.0062,  0.0294,  ..., -0.0193,  0.0204,  0.0228],
#          [ 0.0336, -0.0245,  0.0248,  ..., -0.0152,  0.0268, -0.0094],
#          ...,
#          [-0.0229,  0.0304,  0.0052,  ..., -0.0214, -0.0232,  0.0064],
#          [-0.0351, -0.0026, -0.0058,  ..., -0.0138,  0.0144,  0.0233],
#          [-0.0109,  0.0106, -0.0098,  ...,  0.0133, -0.0051, -0.0356]],
#           -4.7968e-02,  1.0451e-01, -5.8444e-02,  3.2295e-02,  9.6915e-02,
#           -2.4163e-02,  7.0883e-02, -3.3035e-02, -2.2785e-02],
#          [ 9.1757e-02, -6.7218e-02, -6.0694e-02, -1.3517e-03, -1.1094e-01,
#            1.7936e-03, -1.0028e-01,  4.8439e-02,  8.6426e-02, -4.4523e-02,
#            2.0953e-02, -1.2066e-02, -6.2164e-02, -2.4602e-02,  8.0760e-02,
#           -7.7475e-02, -4.8076e-02, -2.6405e-02, -2.0670e-02,  2.7612e-02,
#            2.7825e-02, -1.0918e-02,  1.4995e-02,  4.5093e-03,  1.1197e-01,
#            3.7556e-02, -2.4285e-02, -7.6834e-02,  6.5210e-02,  1.0495e-01,
#           -5.7653e-02,  1.1609e-01, -1.1272e-01,  4.7401e-02, -9.7785e-02,
#           -2.5161e-02,  7.2388e-02,  6.7776e-03, -6.1087e-02, -2.6651e-02,
#           -7.0781e-02,  3.3973e-02, -2.1823e-02, -1.0948e-01,  6.2385e-02,
#           -6.4497e-02,  3.5306e-02,  1.3258e-02, -4.7355e-02,  2.7847e-02,
#            8.8547e-02,  8.4978e-02,  7.9253e-02,  1.0485e-01,  1.1928e-01,
#           -7.3024e-02,  7.5255e-02, -4.8981e-02, -1.0365e-01, -3.7969e-02,
#            3.9488e-02, -1.5096e-02, -5.5962e-02,  5.7435e-03],
#          [-1.0564e-01, -9.5532e-02, -5.6021e-02, -8.1972e-03, -6.5558e-02,
#            6.0921e-02,  1.2244e-01,  7.2208e-02, -1.1626e-02,  6.4908e-02,
#            1.2492e-01,  8.7269e-02, -1.0778e-02,  6.2682e-02, -6.0992e-02,
#           -1.0987e-01, -3.0130e-03, -2.1276e-02,  8.5353e-02,  1.0575e-01,
#           -1.1356e-01,  4.9878e-02, -6.7881e-02,  3.6110e-02, -9.9547e-02,
#            6.7860e-02,  1.2179e-01,  8.3023e-02, -5.7541e-03,  1.1951e-01,
#            8.7255e-02, -1.0064e-01, -3.1106e-02, -1.0622e-01,  2.3812e-02,
#            3.9659e-02,  8.8746e-02,  1.8068e-03,  2.5165e-02,  4.3730e-02,
#            1.2500e-01,  1.1478e-01, -3.0358e-02,  9.4693e-02, -5.7714e-02,
#            7.9329e-02, -9.3968e-02, -6.5887e-02, -1.1822e-01, -6.6205e-02,
#            5.3022e-02, -1.2014e-01, -7.7838e-02,  8.2777e-03,  4.0543e-02,
#            8.7072e-02,  1.0486e-01, -8.1897e-02,  6.7311e-02, -3.0668e-02,
#            2.1679e-03, -9.2958e-02, -4.9568e-02, -1.0568e-01]],
#         requires_grad=True), Parameter containing:
#  tensor([-0.0810,  0.0172, -0.1241, -0.0791,  0.0900, -0.1091,  0.0936, -0.0274,
#          -0.1077,  0.0071], requires_grad=True)]

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.5)

# %%
def train(model, train_loader, optimizer):
    model.train()
    # 배치 당 loss 값을 담을 리스트 생성
    batch_losses = []

    for data, target in train_loader:
        # 옵티마이저의 기울기 초기화
        optimizer.zero_grad()

        # y pred 값 산출
        output = model(data)
        # loss 계산
        # 정답 데이터와의 cross entropy loss 계산
        # 이 loss를 배치 당 loss로 보관
        loss = criterion(output, target)
        batch_losses.append(loss)

        # 기울기 계산
        loss.backward()

        # 가중치 업데이트!
        optimizer.step()
        
    # 배치당 평균 loss 계산
    avg_loss = sum(batch_losses) / len(batch_losses)
    
    return avg_loss

# %%
def evaluate(model, test_loader):
    # 모델을 평가 모드로 전환
    model.eval()

    batch_losses = []
    correct = 0 

    with torch.no_grad(): 
        for data, target in test_loader:
            # 예측값 생성
            output = model(data)

            # loss 계산 (이전과 동일)
            loss = criterion(output, target)
            batch_losses.append(loss)

           # Accuracy 계산
           # y pred와 y가 일치하면 correct에 1을 더해주기
            pred = output.max(1, keepdim=True)[1]

            # eq() 함수는 값이 일치하면 1을, 아니면 0을 출력.
            correct += pred.eq(target.view_as(pred)).sum().item()

    # 배치 당 평균 loss 계산 
    avg_loss =  sum(batch_losses) / len(batch_losses)

    #정확도 계산
    accuracy = 100. * correct / len(test_loader.dataset)

    return avg_loss, accuracy

# %%
EPOCHS = 100

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 0.8697	Test Loss: 0.3300	Accuracy: 89.95%
# [2] Train Loss: 0.2476	Test Loss: 0.1815	Accuracy: 94.63%
# [3] Train Loss: 0.1674	Test Loss: 0.1603	Accuracy: 95.06%
# [4] Train Loss: 0.1349	Test Loss: 0.1516	Accuracy: 95.05%
# [5] Train Loss: 0.1066	Test Loss: 0.1037	Accuracy: 96.85%
# [6] Train Loss: 0.1511	Test Loss: 0.2037	Accuracy: 93.42%
# [7] Train Loss: 0.0930	Test Loss: 0.0933	Accuracy: 97.16%
# [8] Train Loss: 0.0736	Test Loss: 0.0979	Accuracy: 96.79%
# [9] Train Loss: 0.0637	Test Loss: 0.1437	Accuracy: 95.24%
# [10] Train Loss: 0.0573	Test Loss: 0.1128	Accuracy: 96.61%
# [11] Train Loss: 0.0511	Test Loss: 0.1200	Accuracy: 96.26%
# [12] Train Loss: 0.0445	Test Loss: 0.1320	Accuracy: 96.06%
# [13] Train Loss: 0.0421	Test Loss: 0.0788	Accuracy: 97.48%
# [14] Train Loss: 0.0348	Test Loss: 0.0783	Accuracy: 97.64%
# [15] Train Loss: 0.0313	Test Loss: 0.0781	Accuracy: 97.64%
# [16] Train Loss: 0.0282	Test Loss: 0.0860	Accuracy: 97.36%
# [17] Train Loss: 0.0259	Test Loss: 0.0778	Accuracy: 97.67%
# [18] Train Loss: 0.0223	Test Loss: 0.0776	Accuracy: 97.73%
# [19] Train Loss: 0.0204	Test Loss: 0.0781	Accuracy: 97.68%
# [20] Train Loss: 0.0173	Test Loss: 0.0838	Accuracy: 97.49%
# [21] Train Loss: 0.0151	Test Loss: 0.0759	Accuracy: 97.82%
# [22] Train Loss: 0.0136	Test Loss: 0.1282	Accuracy: 96.47%
# [23] Train Loss: 0.0139	Test Loss: 0.0790	Accuracy: 97.85%
# [24] Train Loss: 0.0106	Test Loss: 0.0777	Accuracy: 97.78%
# [25] Train Loss: 0.0103	Test Loss: 0.1579	Accuracy: 95.72%
# [26] Train Loss: 0.0097	Test Loss: 0.0838	Accuracy: 97.85%
# [27] Train Loss: 0.0077	Test Loss: 0.0971	Accuracy: 97.48%
# [28] Train Loss: 0.0069	Test Loss: 0.0807	Accuracy: 97.76%
# [29] Train Loss: 0.0057	Test Loss: 0.0802	Accuracy: 97.82%

        self.relu = nn.ReLU()
        
    def forward(self, x):
        x = x.view(-1, 784)
        out = self.layer1(x)
        out = self.relu(out)
        out = self.layer2(out)
        out = self.relu(out)
        out = self.layer3(out)

        return out

# %%
model = Net()
model
# Out:
# Net(
#   (layer1): Linear(in_features=784, out_features=256, bias=True)
#   (layer2): Linear(in_features=256, out_features=64, bias=True)
#   (layer3): Linear(in_features=64, out_features=10, bias=True)
#   (relu): ReLU()
# )

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.25)

# %%
def train(model, train_loader, optimizer):
    model.train()
    # 배치 당 loss 값을 담을 리스트 생성
    batch_losses = []

    for data, target in train_loader:
        # 옵티마이저의 기울기 초기화
        optimizer.zero_grad()

        # y pred 값 산출
        output = model(data)
        # loss 계산
        # 정답 데이터와의 cross entropy loss 계산
        # 이 loss를 배치 당 loss로 보관
        loss = criterion(output, target)
        batch_losses.append(loss)

        # 기울기 계산
        loss.backward()

        # 가중치 업데이트!
        optimizer.step()
        
    # 배치당 평균 loss 계산
    avg_loss = sum(batch_losses) / len(batch_losses)
    
    return avg_loss

# %%
def evaluate(model, test_loader):
    # 모델을 평가 모드로 전환
    model.eval()

    batch_losses = []
    correct = 0 

    with torch.no_grad(): 
        for data, target in test_loader:
            # 예측값 생성
            output = model(data)

            # loss 계산 (이전과 동일)
            loss = criterion(output, target)
            batch_losses.append(loss)

           # Accuracy 계산
           # y pred와 y가 일치하면 correct에 1을 더해주기
            pred = output.max(1, keepdim=True)[1]

            # eq() 함수는 값이 일치하면 1을, 아니면 0을 출력.
            correct += pred.eq(target.view_as(pred)).sum().item()

    # 배치 당 평균 loss 계산 
    avg_loss =  sum(batch_losses) / len(batch_losses)

    #정확도 계산
    accuracy = 100. * correct / len(test_loader.dataset)

    return avg_loss, accuracy

# %%
EPOCHS = 50

for epoch in range(1, EPOCHS + 1):
    train_loss = train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)
    
    print('[{}] Train Loss: {:.4f}\tTest Loss: {:.4f}\tAccuracy: {:.2f}%'.format(
          epoch, train_loss, test_loss, test_accuracy))
# Out:
# [1] Train Loss: 0.9695	Test Loss: 0.3811	Accuracy: 88.71%
# [2] Train Loss: 0.3282	Test Loss: 0.2943	Accuracy: 91.41%
# [3] Train Loss: 0.2477	Test Loss: 0.2492	Accuracy: 92.23%
# [4] Train Loss: 0.2009	Test Loss: 0.1785	Accuracy: 94.57%
# [5] Train Loss: 0.1650	Test Loss: 0.1600	Accuracy: 95.23%
# [6] Train Loss: 0.1386	Test Loss: 0.1317	Accuracy: 96.18%
# [7] Train Loss: 0.1220	Test Loss: 0.1355	Accuracy: 95.95%
# [8] Train Loss: 0.1080	Test Loss: 0.1343	Accuracy: 95.78%
# [9] Train Loss: 0.0952	Test Loss: 0.1217	Accuracy: 96.13%
# [10] Train Loss: 0.0861	Test Loss: 0.1063	Accuracy: 96.81%
# [11] Train Loss: 0.0786	Test Loss: 0.1045	Accuracy: 96.64%
# [12] Train Loss: 0.0716	Test Loss: 0.1258	Accuracy: 96.02%
# [13] Train Loss: 0.0642	Test Loss: 0.0848	Accuracy: 97.29%
# [14] Train Loss: 0.0587	Test Loss: 0.1106	Accuracy: 96.41%
# [15] Train Loss: 0.0541	Test Loss: 0.0797	Accuracy: 97.45%
# [16] Train Loss: 0.0500	Test Loss: 0.0868	Accuracy: 97.11%
# [17] Train Loss: 0.0464	Test Loss: 0.0811	Accuracy: 97.41%
# [18] Train Loss: 0.0425	Test Loss: 0.0737	Accuracy: 97.71%
