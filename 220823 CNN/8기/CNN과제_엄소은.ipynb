# %% [markdown]
# # 1. 폴더 정리
#
# * 제공해드린 animals10.zip의 압축을 풀어 그 내용을 살펴보시고, 폴더 구조를 학습에 알맞도록 재구성해주세요
# * 특히 각 클래스마다 약 30% 정도의 이미지를 test 폴더에 할당해주세요
# * 중간중간 헷갈리다면 이것저것 확인하는 코드를 거쳐보세요 (ex. flat_test[:5]로 앞의 다섯값 확인)
# * 궁금한 점이 있을 경우, 슬랙 질문 채널 활용을 적극 권장합니다.

# %%
import os
import glob
import shutil

# %% [markdown]
# ## 압축 해제

# %%
### Guideline for convenience ###
# 압축 풀기
# !unzip -qq "/Users/soeun-uhm/Downloads/[0823] CNN/animals10.zip"

# %% [markdown]
# ## 파일 개수 확인

# %%
# 각 클래스별 파일 개수 확인 -> 변수로 해당 개수 저장
# Tip) 클래스가 10개이므로 각 클래스마다 똑같은 내용의 코드를 계속 써야할까요? 클래스 이름을 리스트로 저장해 for문을 돌리면서 코드를 재사용하는건 어떨까요?
class_names = ['butterfly', 'cat', 'chicken', 'cow', 'dog', 'elephant', 'horse', 'sheep', 'spider', 'squirrel']

# %%
# 좀더 다루기 쉽도록 dictionary를 정의
tot_file_count = {}
tot_filename_list = {}

# %%
for each_class in class_names:
  file_jpg = glob.glob(f'./Animals-10/{each_class}/*.jpg')
  file_jpeg = glob.glob(f'./Animals-10/{each_class}/*.jpeg')
  file_png = glob.glob(f'./Animals-10/{each_class}/*.png')

  file_list = []
  file_list.extend(file_jpg) # append가 아닌 extend 함수를 활용
  file_list.extend(file_jpeg)
  file_list.extend(file_png)

  tot_file_count[each_class] = len(file_list)
  tot_filename_list[each_class] = file_list

  print(f'{each_class}: {tot_file_count[each_class]}')
# Out:
# butterfly: 2112
# cat: 1668
# chicken: 3098
# cow: 1866
# dog: 4863
# elephant: 1446
# horse: 2623
# sheep: 1820
# spider: 4821
# squirrel: 1862

# %% [markdown]
# 클래스 간 이미지 개수 차이가 꽤 유의미하게 존재한다 -> imbalance 문제 위험성 생각해볼수 있음 (= 너무 특정 클래스에 데이터가 편중되었을 때의 문제)

# %%
tot_file_count
# Out:
# {'butterfly': 2112,
#  'cat': 1668,
#  'chicken': 3098,
#  'cow': 1866,
#  'dog': 4863,
#  'elephant': 1446,
#  'horse': 2623,
#  'sheep': 1820,
#  'spider': 4821,
#  'squirrel': 1862}

# %% [markdown]
# ## test 넣을 이미지수 계산

# %%
# test에 넣을 이미지 개수 계산
# 30%의 이미지를 test로 활용하자
test_file_count = {}

# %%
for each_class in class_names:
  test_file_count[each_class] = round(tot_file_count[each_class] * 0.3)

# %%
test_file_count
# Out:
# {'butterfly': 634,
#  'cat': 500,
#  'chicken': 929,
#  'cow': 560,
#  'dog': 1459,
#  'elephant': 434,
#  'horse': 787,
#  'sheep': 546,
#  'spider': 1446,
#  'squirrel': 559}

# %%
# train, test 폴더 경로 선언 & 만들기
for each_class in class_names:
  os.makedirs(f'./train/{each_class}', exist_ok=True)
  os.makedirs(f'./test/{each_class}', exist_ok=True)

# %%
# train, test 폴더로 이미지 split해서 알맞게 집어넣기
import random

def split(img_list, test_count, train_path, test_path):
  # img_list : 이미지 경로 리스트
  # test_count : test에 할당할 이미지 개수
  # train_path : train 데이터 넣을 경로
  # test_path : test 데이터 넣을 경로
  
  # 랜덤으로 test_count만큼 이미지 img_list에서 고르기
  # test 담을 이미지 리스트 저장
  test_files=[]
  for i in random.sample(img_list, test_count):
    test_files.append(i)

  # 위에서 고르지 않은 이미지들을 train 담을 이미지 리스트로 저장
  train_files = [x for x in img_list if x not in test_files]

  # 고른 이미지를 train_path, test_path폴더에 폭사
  for k in train_files:
    shutil.copy(k, train_path)
  
  for c in test_files:
    shutil.copy(c, test_path)

  print('train 폴더 이미지 개수 : {}\ntest 폴더 이미지 개수 : {}'.format(len(glob.glob(train_path+'/*')),len(glob.glob(test_path+'/*'))))

# %%
for each_class in class_names:
  split(tot_filename_list[each_class], test_file_count[each_class], f'./train/{each_class}', f'./test/{each_class}')
# Out:
# train 폴더 이미지 개수 : 1478
# test 폴더 이미지 개수 : 634
# train 폴더 이미지 개수 : 1168
# test 폴더 이미지 개수 : 500
# train 폴더 이미지 개수 : 2169
# test 폴더 이미지 개수 : 929
# train 폴더 이미지 개수 : 1306
# test 폴더 이미지 개수 : 560
# train 폴더 이미지 개수 : 3404
# test 폴더 이미지 개수 : 1459
# train 폴더 이미지 개수 : 1012
# test 폴더 이미지 개수 : 434
# train 폴더 이미지 개수 : 1836
# test 폴더 이미지 개수 : 787
# train 폴더 이미지 개수 : 1274
# test 폴더 이미지 개수 : 546
# train 폴더 이미지 개수 : 3375
# test 폴더 이미지 개수 : 1446
# train 폴더 이미지 개수 : 1303
# test 폴더 이미지 개수 : 559

# %%
butterfly_test = sorted(glob.glob('./test/butterfly/*'))
butterfly_test[:5]
# Out:
# ['./test/butterfly/butterfly (1).png',
#  './test/butterfly/butterfly (10).jpg',
#  './test/butterfly/butterfly (100).jpeg',
#  './test/butterfly/butterfly (100).jpg',
#  './test/butterfly/butterfly (1002).jpeg']

# %% [markdown]
# # 2. CNN 모델
# 수업 코드에 '모델 성능에 대한 고민!!' 부분을 참고해서 **test 이미지 기준 최소 80% 이상**의 모델이 나올 수 있도록 학습을 진행해주세요.
# * 중간중간 헷갈리다면 이것저것 확인하는 코드를 거쳐보세요
# * 90% 이상의 모델이 이상적이긴 합니다
# * 궁금한 점이 있을 경우, 슬랙 질문 채널 활용을 적극 권장합니다.

# %% [markdown]
# 전반적으로 수업 코드와 비슷하게 짜면 되는데, 생각해봐야 할 것은
# * 모든 이미지를 내가 정의하는 하나의 모델에 넣어야함
# * 그말은 input 데이터의 차원이 항상 동일해야 된다는 말
# * 그런데 과연 내가 가지고 있는 이미지들의 사이즈가 모두 같을까? - 대략 얼마정도 사이즈 가지고 있는지 코드로 확인해보면 더 좋음 (shape 확인)
# * 이미지 사이즈를 통일시키기 위해서는 어떻게 해야할까? - transforms의 Resize, RandomCrop, CenterCrop 써볼까?
# * 동물 이미지에 적합한 Augmentation은 무엇이 있을까?

# %%
# img들 대략 확인해보기
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow

# %% [markdown]
# ## 이미지 살펴보기

# %%
test_img_path = './Animals-10/butterfly/butterfly (1).png' # 바꿔보면서 확인
test_img = Image.open(test_img_path)

# %%
test_img_np = np.array(test_img)
imshow(test_img_np)
print(test_img_np.shape)
# Out:
# (533, 640, 4)

# %% [markdown]
# ## transforms function 정의

# %%
# train, test 이미지를 위한 transforms function 정의
# 위에서 말한 포인트들 생각해보기 - 차원에 유의하자!
import torch
import torchvision
import torchvision.transforms as transforms

# %%
transform_train = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224), # 모든 이미지 사이즈를 224*224로 통일
    transforms.ColorJitter(brightness=0.2),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(20),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
transform_test = transforms.Compose([
    transforms.Resize(224),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %% [markdown]
# ## Dataset 정의 및 확인

# %%
# ImageFolder와 앞서 정의한 transforms function을 활용해 Dataset 객체 (train, test에 대해) 선언
train_dataset = torchvision.datasets.ImageFolder(
    root = './train',
    transform = transform_train
)
test_dataset = torchvision.datasets.ImageFolder(
    root = './test',
    transform = transform_test
)

# %%
# Dataset 확인 과정
len(train_dataset)
# Out:
# 18325

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
train_dataset[1][0].shape # 모두 224*244로 통일된 것 확인
# Out:
# torch.Size([3, 224, 224])

# %%
train_dataset[0][1]
# Out:
# 0

# %%
train_dataset[10000][1]
# Out:
# 5

# %% [markdown]
# ## DataLoader 정의

# %%
# train, test에 대해 DataLoader 정의
train_dataloader = torch.utils.data.DataLoader(
    train_dataset,
    batch_size = 32,
    shuffle=True,
    num_workers=2
)

# %%
test_dataloader = torch.utils.data.DataLoader(
    test_dataset,
    batch_size = 32,
    shuffle=False,
    num_workers=2
)

# %%
### Model 클래스 정의 - 차원에 유의하자!
# 10개의 클래스를 분류해야 하는 꽤나 복잡한 task - 모델 구조를 어느 정도로 복잡하게 짜볼까?
# 가장 마지막 Linear의 out_features는 얼마로 해야할까?
import torch.nn as nn

# %% [markdown]
# ## ResNet 코드 예시
# 이걸로도 돌릴수 있음
#
# 참고) https://yhkim4504.tistory.com/3

# %%
# ResNet18 구조 활용
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1, downsample=None):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.relu = nn.ReLU(inplace=True)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        
        self.downsample = downsample

    def forward(self, x):
        identity = x

        out = self.conv1(x)
        out = self.bn1(out)
        out = self.relu(out)

        out = self.conv2(out)
        out = self.bn2(out)

        if self.downsample is not None:
            identity = self.downsample(x)
        
        out += identity # skip connection
        out = self.relu(out)

        return out

# %%
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, self.in_planes, kernel_size=7, stride=2, padding=3, bias=False) # 64개의 3x3 필터(filter)를 사용
        self.bn1 = nn.BatchNorm2d(self.in_planes)
        self.relu = nn.ReLU(inplace=True)
        self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)

        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)

        self.avgpool = nn.AdaptiveAvgPool2d((1,1))
        self.fc = nn.Linear(512, num_classes)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode="fan_out", nonlinearity="relu")
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)

    def _make_layer(self, block, planes, num_blocks, stride):
        downsample = None
        if stride != 1 or self.in_planes != planes:
            downsample = nn.Sequential(
                nn.Conv2d(self.in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

        layers = []
        layers.append(
            block(self.in_planes, planes, stride, downsample)
        )
        self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        for _ in range(1, num_blocks):
            layers.append(
                block(self.in_planes, planes)
            )
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.maxpool(self.relu(self.bn1(self.conv1(x))))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)
        out = self.fc(out)
        return out

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
resnet18 = ResNet(BasicBlock, [2, 2, 2, 2], 10).to(device)
resnet18
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
from torchsummary import summary
summary(resnet18, input_size=(3, 224, 224), batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [32, 64, 112, 112]           9,408
#        BatchNorm2d-2         [32, 64, 112, 112]             128
#               ReLU-3         [32, 64, 112, 112]               0
#          MaxPool2d-4           [32, 64, 56, 56]               0
#             Conv2d-5           [32, 64, 56, 56]          36,864
#        BatchNorm2d-6           [32, 64, 56, 56]             128
#               ReLU-7           [32, 64, 56, 56]               0
#             Conv2d-8           [32, 64, 56, 56]          36,864
#        BatchNorm2d-9           [32, 64, 56, 56]             128
#              ReLU-10           [32, 64, 56, 56]               0
#        BasicBlock-11           [32, 64, 56, 56]               0
#            Conv2d-12           [32, 64, 56, 56]          36,864
#       BatchNorm2d-13           [32, 64, 56, 56]             128
#              ReLU-14           [32, 64, 56, 56]               0
#            Conv2d-15           [32, 64, 56, 56]          36,864
#       BatchNorm2d-16           [32, 64, 56, 56]             128
#              ReLU-17           [32, 64, 56, 56]               0
#        BasicBlock-18           [32, 64, 56, 56]               0
#            Conv2d-19          [32, 128, 28, 28]          73,728
#       BatchNorm2d-20          [32, 128, 28, 28]             256
#              ReLU-21          [32, 128, 28, 28]               0
#            Conv2d-22          [32, 128, 28, 28]         147,456
#       BatchNorm2d-23          [32, 128, 28, 28]             256
#            Conv2d-24          [32, 128, 28, 28]           8,192
#       BatchNorm2d-25          [32, 128, 28, 28]             256
#              ReLU-26          [32, 128, 28, 28]               0
#        BasicBlock-27          [32, 128, 28, 28]               0
#            Conv2d-28          [32, 128, 28, 28]         147,456
#       BatchNorm2d-29          [32, 128, 28, 28]             256
#              ReLU-30          [32, 128, 28, 28]               0
#            Conv2d-31          [32, 128, 28, 28]         147,456
#       BatchNorm2d-32          [32, 128, 28, 28]             256
#              ReLU-33          [32, 128, 28, 28]               0
#        BasicBlock-34          [32, 128, 28, 28]               0
#            Conv2d-35          [32, 256, 14, 14]         294,912
#       BatchNorm2d-36          [32, 256, 14, 14]             512
#              ReLU-37          [32, 256, 14, 14]               0
#            Conv2d-38          [32, 256, 14, 14]         589,824
#       BatchNorm2d-39          [32, 256, 14, 14]             512
#            Conv2d-40          [32, 256, 14, 14]          32,768
#       BatchNorm2d-41          [32, 256, 14, 14]             512
#              ReLU-42          [32, 256, 14, 14]               0
#        BasicBlock-43          [32, 256, 14, 14]               0
#            Conv2d-44          [32, 256, 14, 14]         589,824
#       BatchNorm2d-45          [32, 256, 14, 14]             512
#              ReLU-46          [32, 256, 14, 14]               0
#            Conv2d-47          [32, 256, 14, 14]         589,824
#       BatchNorm2d-48          [32, 256, 14, 14]             512
#              ReLU-49          [32, 256, 14, 14]               0
#        BasicBlock-50          [32, 256, 14, 14]               0
#            Conv2d-51            [32, 512, 7, 7]       1,179,648
#       BatchNorm2d-52            [32, 512, 7, 7]           1,024
#              ReLU-53            [32, 512, 7, 7]               0
#            Conv2d-54            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-55            [32, 512, 7, 7]           1,024
#            Conv2d-56            [32, 512, 7, 7]         131,072
#       BatchNorm2d-57            [32, 512, 7, 7]           1,024
#              ReLU-58            [32, 512, 7, 7]               0
#        BasicBlock-59            [32, 512, 7, 7]               0
#            Conv2d-60            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-61            [32, 512, 7, 7]           1,024
#              ReLU-62            [32, 512, 7, 7]               0
#            Conv2d-63            [32, 512, 7, 7]       2,359,296
#       BatchNorm2d-64            [32, 512, 7, 7]           1,024
#              ReLU-65            [32, 512, 7, 7]               0
#        BasicBlock-66            [32, 512, 7, 7]               0
# AdaptiveAvgPool2d-67            [32, 512, 1, 1]               0
#            Linear-68                   [32, 10]           5,130
# ================================================================
# Total params: 11,181,642
# Trainable params: 11,181,642
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 2009.13
# Params size (MB): 42.65
# Estimated Total Size (MB): 2070.16
# ----------------------------------------------------------------

# %% [markdown]
# ## My Model

# %%
# VGG idea 차용 (3x3 conv layer로 구성)
class MyModel(nn.Module):
    def __init__(self):
        super(MyModel, self).__init__()

        self.convnet = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1, stride=1), # [batch_size, 3, 224, 224] -> [batch_size, 32, 224, 224]
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1, stride=1), # [batch_size, 32, 224, 224] -> [batch_size, 32, 224, 224]
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 32, 224, 224] -> [batch_size, 32, 112, 112]
            
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1, stride=1), # [batch_size, 32, 112, 112] -> [batch_size, 64, 112, 112]
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=64, out_channels=64, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 64, 112, 112] -> [batch_size, 64, 56, 56]

            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1, stride=1), # [batch_size, 64, 56, 56] -> [batch_size, 128, 56, 56]
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 128, 56, 56] -> [batch_size, 128, 28, 28]

            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1, stride=1), # [batch_size, 128, 28, 28] -> [batch_size, 256, 28, 28]
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 256, 28, 28] -> [batch_size, 256, 14, 14]

            nn.Conv2d(in_channels=256, out_channels=512, kernel_size=3, padding=1, stride=1), # [batch_size, 256, 14, 14] -> [batch_size, 512, 14, 14]
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=512, out_channels=512, kernel_size=3, padding=1, stride=1),
            nn.BatchNorm2d(512),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2), # [batch_size, 512, 14, 14] -> [batch_size, 512, 7, 7]
        )

        self.fclayer = nn.Sequential(
            nn.Linear(512*7*7, 4096),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(4096, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(0.3),
            nn.Linear(1024, 10)
        )

        # weight initialization (not necessary, but for better result)
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(
                    m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

    def forward(self,x) :
        x = self.convnet(x)
        x = x.view(x.size(0), -1)
        x = self.fclayer(x)
        return x

# %%
# torchsummary로 모델 차원 어떻게 나오는지 돌려보기
test_model = MyModel().to(device) # 모델 객체 선언
summary(test_model, (3,224,224), batch_size=32)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [32, 32, 224, 224]             896
#        BatchNorm2d-2         [32, 32, 224, 224]              64
#               ReLU-3         [32, 32, 224, 224]               0
#             Conv2d-4         [32, 32, 224, 224]           9,248
#        BatchNorm2d-5         [32, 32, 224, 224]              64
#               ReLU-6         [32, 32, 224, 224]               0
#          MaxPool2d-7         [32, 32, 112, 112]               0
#             Conv2d-8         [32, 64, 112, 112]          18,496
#        BatchNorm2d-9         [32, 64, 112, 112]             128
#              ReLU-10         [32, 64, 112, 112]               0
#            Conv2d-11         [32, 64, 112, 112]          36,928
#       BatchNorm2d-12         [32, 64, 112, 112]             128
#              ReLU-13         [32, 64, 112, 112]               0
#         MaxPool2d-14           [32, 64, 56, 56]               0
#            Conv2d-15          [32, 128, 56, 56]          73,856
#       BatchNorm2d-16          [32, 128, 56, 56]             256
#              ReLU-17          [32, 128, 56, 56]               0
#            Conv2d-18          [32, 128, 56, 56]         147,584
#       BatchNorm2d-19          [32, 128, 56, 56]             256
#              ReLU-20          [32, 128, 56, 56]               0
#         MaxPool2d-21          [32, 128, 28, 28]               0
#            Conv2d-22          [32, 256, 28, 28]         295,168
#       BatchNorm2d-23          [32, 256, 28, 28]             512
#              ReLU-24          [32, 256, 28, 28]               0
#            Conv2d-25          [32, 256, 28, 28]         590,080
#       BatchNorm2d-26          [32, 256, 28, 28]             512
#              ReLU-27          [32, 256, 28, 28]               0
#         MaxPool2d-28          [32, 256, 14, 14]               0
#            Conv2d-29          [32, 512, 14, 14]       1,180,160
#       BatchNorm2d-30          [32, 512, 14, 14]           1,024
#              ReLU-31          [32, 512, 14, 14]               0
#            Conv2d-32          [32, 512, 14, 14]       2,359,808
#       BatchNorm2d-33          [32, 512, 14, 14]           1,024
#              ReLU-34          [32, 512, 14, 14]               0
#         MaxPool2d-35            [32, 512, 7, 7]               0
#            Linear-36                 [32, 4096]     102,764,544
#              ReLU-37                 [32, 4096]               0
#           Dropout-38                 [32, 4096]               0
#            Linear-39                 [32, 1024]       4,195,328
#              ReLU-40                 [32, 1024]               0
#           Dropout-41                 [32, 1024]               0
#            Linear-42                   [32, 10]          10,250
# ================================================================
# Total params: 111,686,314
# Trainable params: 111,686,314
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 4750.63
# Params size (MB): 426.05
# Estimated Total Size (MB): 5195.05
# ----------------------------------------------------------------

# %%
# Device 선언 (GPU 권장)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
# 모델 객체 선언
mymodel = MyModel().to(device)
mymodel
# Out:
# MyModel(
#   (convnet): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
#     (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (14): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU(inplace=True)
#     (17): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU(inplace=True)
#     (20): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (21): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (23): ReLU(inplace=True)
#     (24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (30): ReLU(inplace=True)
#     (31): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (32): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (33): ReLU(inplace=True)
#     (34): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (fclayer): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=4096, out_features=1024, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=1024, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ## Criterion, Optimizer

# %%
# loss func, optimizer 정의
criterion = nn.CrossEntropyLoss().to(device) # criterion (loss func)도 device 위에서
optimizer = torch.optim.Adam(mymodel.parameters(), lr=0.001)

# %% [markdown]
# ## Train & Test function

# %%
seq_train_loss = []
seq_test_loss = []
seq_train_acc = []
seq_test_acc = []

# %%
# train 함수 정의
def train(epoch):
    print(f'\n[ Train epoch: {epoch+1} ]')

    mymodel.train() # train은 항상 이걸 지정하고 시작! - Dropout, Batch Normalization 등의 효과를 적용하고 진행하기 위함

    running_loss = 0.0
    batch_losses = []
    total = 0
    correct = 0

    for batch_idx, (inputs, targets) in enumerate(train_dataloader):
        inputs, targets = inputs.to(device), targets.to(device) # dataloader의 input image와 label도 device에 넣어줘야됨
        
        # DL 학습 기본 코드
        optimizer.zero_grad() # gradient 초기화
        outputs = mymodel(inputs) # 현재 batch의 inputs을 모델에 넣어 outputs 추출 (확률값)
        loss = criterion(outputs, targets) # 추출한 outputs와 원래 label인 targets 사이 loss 계산
        loss.backward() # 계산한 loss 기반으로 gradient 값 계산
        optimizer.step() # weight parameter update

        total += targets.size(0) # batch 데이터 개수 더하기
        running_loss += loss.item()
        batch_losses.append(loss.item())
        
        _, predicted = outputs.max(1) # 확률값 가장 높게 나타난 클래스
        correct += (predicted == targets).sum().item() # 현재 batch 내에서 알맞게 분류한 이미지 개수 더하기
        
        if batch_idx % 100 == 99:
            print(f'\nCurrent batch: {str(batch_idx+1)}')
            print(f'Average train loss of recent 100 batches: {running_loss / 100}') # 이렇게 출력하는 것이 꼭 필요한 것은 아니지만, 중간중간 확인을 위해 매우 권장
            running_loss = 0.0

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_train_loss.append(avg_loss)
    seq_train_acc.append(100*correct/total)
    print('\nTotal train accuarcy:', 100. * correct / total) # 전체 데이터 개수에서 맞게 예측한 비율
    print('Total train loss:', avg_loss)

# %%
# test 함수 정의
def test(epoch):
    print(f'\n[ Test epoch: {epoch+1} ]')

    mymodel.eval() # eval은 항상 이걸 지정하고 시작! - Dropout, Batch Normalization 등의 효과를 적용하지 않기 위함!
                   # ex. evaluation 할때는 Dropout 없이 지금까지 학습한 모든 node를 활용해서 진행해야됨

    loss = 0
    batch_losses = []
    correct = 0
    total = 0

    with torch.no_grad(): # gradient update 안함 - eval과 torch.no_grad는 하나의 세트
        for batch_idx, (inputs, targets) in enumerate(test_dataloader):
            inputs, targets = inputs.to(device), targets.to(device)

            outputs = mymodel(inputs)
            loss = criterion(outputs, targets)
            batch_losses.append(loss.item())

            total += targets.size(0)
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()

    avg_loss = sum(batch_losses) / len(batch_losses)
    seq_test_loss.append(avg_loss)
    seq_test_acc.append(100 * correct / total)
    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', avg_loss)

# %% [markdown]
# ## Train

# %%
# training
num_epoch = 30

for epoch in range(0, num_epoch):
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 1 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 3.0416414296627043
#
# Current batch: 200
# Average train loss of recent 100 batches: 2.2120328903198243
#
# Current batch: 300
# Average train loss of recent 100 batches: 2.1698315155506136
#
# Current batch: 400
# Average train loss of recent 100 batches: 2.106651964187622
#
# Current batch: 500
# Average train loss of recent 100 batches: 2.069770556688309
#
# Total train accuarcy: 24.458390177353344
# Total train loss: 2.284087793365199
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 33.00229182582124
# Test average loss: 1.9414523709111098
#
# [ Train epoch: 2 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 2.025408629179001
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.9733602130413055
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.9822174608707428
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.8960801899433135
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.9272929728031158
#
# Total train accuarcy: 32.76944065484311
# Total train loss: 1.9518875041765276
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 38.93557422969187
# Test average loss: 1.791026869925057
#
# [ Train epoch: 3 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.883598906993866
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.8643617570400237
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.8398392748832704
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.8607609140872956
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.7836930692195891
#
# Total train accuarcy: 36.6493860845839
# Total train loss: 1.8356031682894909
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 42.6279602750191
# Test average loss: 1.6851305336487004
#
# [ Train epoch: 4 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.750355771780014
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.7782216799259185
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.7824748289585113
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.7306961870193482
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.6993300795555115
#
# Total train accuarcy: 40.780354706684854
# Total train loss: 1.7391144653057344
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 47.86096256684492
# Test average loss: 1.5443584451345893
#
# [ Train epoch: 5 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.6851990282535554
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.63223078250885
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.654496772289276
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.6490397715568543
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.6011601090431213
#
# Total train accuarcy: 44.851296043656205
# Total train loss: 1.6370255572633594
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 49.898141074611665
# Test average loss: 1.4830571127131702
#
# [ Train epoch: 6 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.5780994081497193
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.57121027469635
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.5200788831710816
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.5216586899757385
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.4990295922756196
#
# Total train accuarcy: 48.26193724420191
# Total train loss: 1.5273126690383565
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 53.74331550802139
# Test average loss: 1.3284249389316978
#
# [ Train epoch: 7 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.422505737543106
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.3989749586582183
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.4922039306163788
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.3882886672019958
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.3652525144815444
#
# Total train accuarcy: 52.327421555252386
# Total train loss: 1.405238760495477
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 60.35141329258976
# Test average loss: 1.1994038827535582
#
# [ Train epoch: 8 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.3420337152481079
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.3248961871862412
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.254034293293953
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.3016920018196105
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.3005231934785844
#
# Total train accuarcy: 56.16371077762619
# Total train loss: 1.2983061767997541
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 63.318054494525086
# Test average loss: 1.0791868286404183
#
# [ Train epoch: 9 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.2034346103668212
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.2478943222761154
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.168345308303833
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.2013124215602875
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.1777290189266205
#
# Total train accuarcy: 59.60163710777626
# Total train loss: 1.1958150008586064
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 64.13292589763178
# Test average loss: 1.0638645113241383
#
# [ Train epoch: 10 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.1211240428686142
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.0970886427164077
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.1160647213459014
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.0692671042680741
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.1158130532503128
#
# Total train accuarcy: 62.86493860845839
# Total train loss: 1.0967568454526067
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 66.14463967405143
# Test average loss: 0.9889108175790406
#
# [ Train epoch: 11 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 1.0616257786750793
#
# Current batch: 200
# Average train loss of recent 100 batches: 1.0260591220855713
#
# Current batch: 300
# Average train loss of recent 100 batches: 1.0460500320792199
#
# Current batch: 400
# Average train loss of recent 100 batches: 1.0285132783651352
#
# Current batch: 500
# Average train loss of recent 100 batches: 1.0033016377687454
#
# Total train accuarcy: 65.44611186903138
# Total train loss: 1.0286548458052764
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 70.29539088362618
# Test average loss: 0.8900354689941173
#
# [ Train epoch: 12 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.965572609603405
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.9759309387207031
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.8979581117630004
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.9298462849855423
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.9588014882802963
#
# Total train accuarcy: 68.39290586630287
# Total train loss: 0.945345146493762
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 71.8105423987777
# Test average loss: 0.8391767016998152
#
# [ Train epoch: 13 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.9491811388731003
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.8843293219804764
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.8920391845703125
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.8513542452454567
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.9181565335392952
#
# Total train accuarcy: 69.97544338335607
# Total train loss: 0.9016232132183528
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 72.72727272727273
# Test average loss: 0.8120019168146257
#
# [ Train epoch: 14 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.8489294043183326
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.843008679151535
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.8281368744373322
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.8246004295349121
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.8678206533193589
#
# Total train accuarcy: 72.01637107776261
# Total train loss: 0.8421035382448067
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 74.05143875732111
# Test average loss: 0.7738660555484334
#
# [ Train epoch: 15 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.771707880795002
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.7528783762454987
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.7666698303818703
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.7973828959465027
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.7797151082754135
#
# Total train accuarcy: 74.15552523874489
# Total train loss: 0.7731642121835945
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 76.2541380188439
# Test average loss: 0.724885310765689
#
# [ Train epoch: 16 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.7549459049105645
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.6940982636809349
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.7087667265534401
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.7445923855900765
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.7352516105771065
#
# Total train accuarcy: 76.0600272851296
# Total train loss: 0.7287725214870813
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 77.43824802648332
# Test average loss: 0.6871734863010849
#
# [ Train epoch: 17 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.6613378593325615
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.7209617874026298
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.6874537962675095
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.6593260398507118
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.6600027765333653
#
# Total train accuarcy: 77.70804911323329
# Total train loss: 0.6767088186522429
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 78.34224598930481
# Test average loss: 0.6589449068788833
#
# [ Train epoch: 18 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.6133904336392879
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.660693744122982
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.6539102265238762
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.6236715352535248
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.6494987881183625
#
# Total train accuarcy: 78.89768076398363
# Total train loss: 0.6404817910510624
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 78.66055513114337
# Test average loss: 0.6498573189828454
#
# [ Train epoch: 19 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.597389870584011
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.5953968931734562
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.6132314473390579
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.627575471997261
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.5820670887827873
#
# Total train accuarcy: 80.01637107776261
# Total train loss: 0.6038247506811981
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 79.3990323402088
# Test average loss: 0.6155812326000958
#
# [ Train epoch: 20 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.5759820973873139
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.5525261272490024
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.5342219381034374
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.5937750862538814
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.5884872645139694
#
# Total train accuarcy: 81.20600272851296
# Total train loss: 0.5682496295601493
#
# [ Test epoch: 20 ]
#
# Test accuarcy: 80.95238095238095
# Test average loss: 0.5895842879261004
#
# [ Train epoch: 21 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.5121684296429158
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.542246934324503
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.555486752986908
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.6003971979022026
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.549442637115717
#
# Total train accuarcy: 81.83356070941338
# Total train loss: 0.5514821752151685
#
# [ Test epoch: 21 ]
#
# Test accuarcy: 81.99643493761141
# Test average loss: 0.5560866088977432
#
# [ Train epoch: 22 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.49700290471315384
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.4818174600601196
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.5217578862607479
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.5113166379928589
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.5115126031637192
#
# Total train accuarcy: 83.3724420190996
# Total train loss: 0.5090082046717249
#
# [ Test epoch: 22 ]
#
# Test accuarcy: 83.11688311688312
# Test average loss: 0.5330150453449507
#
# [ Train epoch: 23 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.4621077002584934
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.4631886097788811
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.49913151368498804
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.5083265165984631
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.45385087504982946
#
# Total train accuarcy: 84.06548431105048
# Total train loss: 0.4863808161041083
#
# [ Test epoch: 23 ]
#
# Test accuarcy: 83.04048892284186
# Test average loss: 0.5306708811350712
#
# [ Train epoch: 24 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.43346237316727637
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.43754212349653243
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.4622052229940891
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.4527786995470524
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.43458557009696963
#
# Total train accuarcy: 85.39699863574351
# Total train loss: 0.4483672255100796
#
# [ Test epoch: 24 ]
#
# Test accuarcy: 82.79857397504456
# Test average loss: 0.535285999256421
#
# [ Train epoch: 25 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.42081569343805314
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.3991502086818218
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.4211879078298807
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.41663200423121455
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.4442127160727978
#
# Total train accuarcy: 86.18281036834925
# Total train loss: 0.4213864838031574
#
# [ Test epoch: 25 ]
#
# Test accuarcy: 83.86809269162211
# Test average loss: 0.5195972676184483
#
# [ Train epoch: 26 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.3803591886907816
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.3861976663768292
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.3828676789999008
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.4040105184912682
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.4029416359215975
#
# Total train accuarcy: 87.4324693042292
# Total train loss: 0.3889983367779492
#
# [ Test epoch: 26 ]
#
# Test accuarcy: 83.68983957219251
# Test average loss: 0.5451476028401071
#
# [ Train epoch: 27 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.3500880175828934
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.35789932794868945
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.3990343898162246
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.3832496130466461
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.37289330072700977
#
# Total train accuarcy: 87.78171896316508
# Total train loss: 0.37451695296490795
#
# [ Test epoch: 27 ]
#
# Test accuarcy: 83.85536032594857
# Test average loss: 0.5127287849072155
#
# [ Train epoch: 28 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.46553146369755266
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.46015782132744787
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.3825174289941788
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.3833461683988571
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.3848778672516346
#
# Total train accuarcy: 86.9031377899045
# Total train loss: 0.40838128602681567
#
# [ Test epoch: 28 ]
#
# Test accuarcy: 84.58110516934046
# Test average loss: 0.4878612494898763
#
# [ Train epoch: 29 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.29949029073119166
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.33545071583241226
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.31289418585598466
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.34102919299155476
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.33921764716506003
#
# Total train accuarcy: 89.20054570259208
# Total train loss: 0.3278581382118387
#
# [ Test epoch: 29 ]
#
# Test accuarcy: 84.53017570664629
# Test average loss: 0.5149906431741225
#
# [ Train epoch: 30 ]
#
# Current batch: 100
# Average train loss of recent 100 batches: 0.318746891990304
#
# Current batch: 200
# Average train loss of recent 100 batches: 0.30617426365613937
#
# Current batch: 300
# Average train loss of recent 100 batches: 0.3077917804569006
#
# Current batch: 400
# Average train loss of recent 100 batches: 0.3082193839363754
#
# Current batch: 500
# Average train loss of recent 100 batches: 0.33851302579045295
#
# Total train accuarcy: 89.7680763983629
# Total train loss: 0.3178147304426053
#
# [ Test epoch: 30 ]
#
# Test accuarcy: 85.47237076648841
# Test average loss: 0.4748001311474094

# %% [markdown]
# 이전에 훈련하던게 남아서 리스트의 첫번째 원소 제거

# %%
del seq_train_loss[0]
del seq_test_loss[0]
del seq_train_acc[0]
del seq_test_acc[0]

# %%
# loss, accuracy 추이 확인 with plt.plot
plt.plot(range(0, num_epoch), seq_train_loss, label="Train loss")
plt.plot(range(0, num_epoch), seq_test_loss, label="Test loss")
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
plt.plot(range(num_epoch), seq_train_acc, label="Train Accuracy")
plt.plot(range(num_epoch), seq_test_acc, label="Test Accuracy")
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.show()

# %%
seq_test_acc[-1]
# Out:
# 85.47237076648841
